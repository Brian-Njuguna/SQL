# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img
#  src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/alx-courses/aice/assets/Content_page_banner_blue_dots.png"
#  alt="ALX Content Header"
#  class="full-width-image"
# />
# </div>

# %% [markdown]
# # Reading data across multiple tables

# %% [markdown]
# In this exercise, we will learn how to read data from a sample database for a digital media company called Chinook that has tables for artists, albums, media tracks, invoices, and customers.

# %% [markdown]
# ## Learning objectives
#
# By the end of this train, you should be able to:
# - Read data from a single column in a single table.
# - Read data from multiple columns in a single table.
# - Read data from multiple columns in multiple tables.

# %% [markdown]
# First, let's load our sample database: You can download the chinook zip file from [here](https://github.com/Explore-AI/Public-Data/blob/master/Data/SQL/Chinook_db.zip)

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook.
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# Load the Chinook database stored in your local machine. 
# Make sure the file is saved in the same folder as this notebook.
# %sql sqlite:///chinook.db

# %% [markdown]
# Here is a [view](https://www.lucidchart.com/pages/er-diagrams) of all of our tables in the database:

# %% [markdown]
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://github.com/Explore-AI/Pictures/blob/master/sqlite-sample-database-color.jpg?raw=true"  style="width:500px";/>
# <br>
# <br>
#     <em>Figure 1: Chinook ERD</em>
# </div>

# %% [markdown]
# [Image source](https://www.sqlitetutorial.net/sqlite-sample-database/)

# %% [markdown]
# ## Reading data from a database
#
# When reading data from a database like the Chinook database, we can read from a single column in a single table, multiple columns in a single table, or multiple columns in various tables within the database.
#
# Let's explore the differences between the above queries.

# %% [markdown]
# ### 1. Reading data from a single column in a single table in the database.
#
# Let's write a query that returns the names of all Chinook digital media store customers.
#
# For this query, we would need to read data from the `FirstName` column in the `customers` table (see ER diagram above).

# %%
# %%sql
#
# SELECT FirstName
# FROM customers
# LIMIT 10; -- Remove this line to see the full result.
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Luís',),
#  ('Leonie',),
#  ('François',),
#  ('Bjørn',),
#  ('František',),
#  ('Helena',),
#  ('Astrid',),
#  ('Daan',),
#  ('Kara',),
#  ('Eduardo',)]

# %% [markdown]
# ### 2. Reading data from multiple columns in a single table in the database.
# Let's write a query to find out when each Chinook employee was hired.
#
# Looking at the ER diagram above, for this query, we would need to read data from the `FirstName`, `LastName`, and `HireDate` column(s) in the `employees` table.

# %%
# %%sql
#
# SELECT FirstName, LastName, HireDate
# FROM employees;
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Andrew', 'Adams', '2002-08-14 00:00:00'),
#  ('Nancy', 'Edwards', '2002-05-01 00:00:00'),
#  ('Jane', 'Peacock', '2002-04-01 00:00:00'),
#  ('Margaret', 'Park', '2003-05-03 00:00:00'),
#  ('Steve', 'Johnson', '2003-10-17 00:00:00'),
#  ('Michael', 'Mitchell', '2003-10-17 00:00:00'),
#  ('Robert', 'King', '2004-01-02 00:00:00'),
#  ('Laura', 'Callahan', '2004-03-04 00:00:00')]

# %% [markdown]
# In the above query, we have specified multiple columns by **separating each column name in the list with a comma**.

# %% [markdown]
# ### 3. Reading data from multiple columns in multiple tables in the database.
#
# Let's write a query that lists album titles and the corresponding artists.
#
# Based on the ER diagram, for this query, we would need to read data from the `Title` column in the `albums` table and the `Name` column in the `artists` table where the `Artistid` in the `artists` table is the same as the `Artistid` in the `albums` table.

# %%
# %%sql
#
# SELECT albums.Title, artists.Name
# FROM albums, artists
# LIMIT 100; -- Remove this line to see the full result
# Out:
#  * sqlite:///chinook.db
# Done.
# [('For Those About To Rock We Salute You', 'AC/DC'),
#  ('For Those About To Rock We Salute You', 'Accept'),
#  ('For Those About To Rock We Salute You', 'Aerosmith'),
#  ('For Those About To Rock We Salute You', 'Alanis Morissette'),
#  ('For Those About To Rock We Salute You', 'Alice In Chains'),
#  ('For Those About To Rock We Salute You', 'Antônio Carlos Jobim'),
#  ('For Those About To Rock We Salute You', 'Apocalyptica'),
#  ('For Those About To Rock We Salute You', 'Audioslave'),
#  ('For Those About To Rock We Salute You', 'BackBeat'),
#  ('For Those About To Rock We Salute You', 'Billy Cobham'),
#  ('For Those About To Rock We Salute You', 'Black Label Society'),
#  ('For Those About To Rock We Salute You', 'Black Sabbath'),
#  ('For Those About To Rock We Salute You', 'Body Count'),
#  ('For Those About To Rock We Salute You', 'Bruce Dickinson'),
#  ('For Those About To Rock We Salute You', 'Buddy Guy'),
#  ('For Those About To Rock We Salute You', 'Caetano Veloso'),
#  ('For Those About To Rock We Salute You', 'Chico Buarque'),
#  ('For Those About To Rock We Salute You', 'Chico Science & Nação Zumbi'),
#  ('For Those About To Rock We Salute You', 'Cidade Negra'),
#  ('For Those About To Rock We Salute You', 'Cláudio Zoli'),
#  ('For Those About To Rock We Salute You', 'Various Artists'),
#  ('For Those About To Rock We Salute You', 'Led Zeppelin'),
#  ('For Those About To Rock We Salute You', 'Frank Zappa & Captain Beefheart'),
#  ('For Those About To Rock We Salute You', 'Marcos Valle'),
#  ('For Those About To Rock We Salute You', 'Milton Nascimento & Bebeto'),
#  ('For Those About To Rock We Salute You', 'Azymuth'),
#  ('For Those About To Rock We Salute You', 'Gilberto Gil'),
#  ('For Those About To Rock We Salute You', 'João Gilberto'),
#  ('For Those About To Rock We Salute You', 'Bebel Gilberto'),
#  ('For Those About To Rock We Salute You', 'Jorge Vercilo'),
#  ('For Those About To Rock We Salute You', 'Baby Consuelo'),
#  ('For Those About To Rock We Salute You', 'Ney Matogrosso'),
#  ('For Those About To Rock We Salute You', 'Luiz Melodia'),
#  ('For Those About To Rock We Salute You', 'Nando Reis'),
#  ('For Those About To Rock We Salute You', 'Pedro Luís & A Parede'),
#  ('For Those About To Rock We Salute You', 'O Rappa'),
#  ('For Those About To Rock We Salute You', 'Ed Motta'),
#  ('For Those About To Rock We Salute You', 'Banda Black Rio'),
#  ('For Those About To Rock We Salute You', 'Fernanda Porto'),
#  ('For Those About To Rock We Salute You', 'Os Cariocas'),
#  ('For Those About To Rock We Salute You', 'Elis Regina'),
#  ('For Those About To Rock We Salute You', 'Milton Nascimento'),
#  ('For Those About To Rock We Salute You', 'A Cor Do Som'),
#  ('For Those About To Rock We Salute You', 'Kid Abelha'),
#  ('For Those About To Rock We Salute You', 'Sandra De Sá'),
#  ('For Those About To Rock We Salute You', 'Jorge Ben'),
#  ('For Those About To Rock We Salute You', 'Hermeto Pascoal'),
#  ('For Those About To Rock We Salute You', 'Barão Vermelho'),
#  ('For Those About To Rock We Salute You', 'Edson, DJ Marky & DJ Patife Featuring Fernanda Porto'),
#  ('For Those About To Rock We Salute You', 'Metallica'),
#  ('For Those About To Rock We Salute You', 'Queen'),
#  ('For Those About To Rock We Salute You', 'Kiss'),
#  ('For Those About To Rock We Salute You', 'Spyro Gyra'),
#  ('For Those About To Rock We Salute You', 'Green Day'),
#  ('For Those About To Rock We Salute You', 'David Coverdale'),
#  ('For Those About To Rock We Salute You', 'Gonzaguinha'),
#  ('For Those About To Rock We Salute You', 'Os Mutantes'),
#  ('For Those About To Rock We Salute You', 'Deep Purple'),
#  ('For Those About To Rock We Salute You', 'Santana'),
#  ('For Those About To Rock We Salute You', 'Santana Feat. Dave Matthews'),
#  ('For Those About To Rock We Salute You', 'Santana Feat. Everlast'),
#  ('For Those About To Rock We Salute You', 'Santana Feat. Rob Thomas'),
#  ('For Those About To Rock We Salute You', 'Santana Feat. Lauryn Hill & Cee-Lo'),
#  ('For Those About To Rock We Salute You', 'Santana Feat. The Project G&B'),
#  ('For Those About To Rock We Salute You', 'Santana Feat. Maná'),
#  ('For Those About To Rock We Salute You', 'Santana Feat. Eagle-Eye Cherry'),
#  ('For Those About To Rock We Salute You', 'Santana Feat. Eric Clapton'),
#  ('For Those About To Rock We Salute You', 'Miles Davis'),
#  ('For Those About To Rock We Salute You', 'Gene Krupa'),
#  ('For Those About To Rock We Salute You', 'Toquinho & Vinícius'),
#  ('For Those About To Rock We Salute You', 'Vinícius De Moraes & Baden Powell'),
#  ('For Those About To Rock We Salute You', 'Vinícius De Moraes'),
#  ('For Those About To Rock We Salute You', 'Vinícius E Qurteto Em Cy'),
#  ('For Those About To Rock We Salute You', 'Vinícius E Odette Lara'),
#  ('For Those About To Rock We Salute You', 'Vinicius, Toquinho & Quarteto Em Cy'),
#  ('For Those About To Rock We Salute You', 'Creedence Clearwater Revival'),
#  ('For Those About To Rock We Salute You', 'Cássia Eller'),
#  ('For Those About To Rock We Salute You', 'Def Leppard'),
#  ('For Those About To Rock We Salute You', 'Dennis Chambers'),
#  ('For Those About To Rock We Salute You', 'Djavan'),
#  ('For Those About To Rock We Salute You', 'Eric Clapton'),
#  ('For Those About To Rock We Salute You', 'Faith No More'),
#  ('For Those About To Rock We Salute You', 'Falamansa'),
#  ('For Those About To Rock We Salute You', 'Foo Fighters'),
#  ('For Those About To Rock We Salute You', 'Frank Sinatra'),
#  ('For Those About To Rock We Salute You', 'Funk Como Le Gusta'),
#  ('For Those About To Rock We Salute You', 'Godsmack'),
#  ('For Those About To Rock We Salute You', "Guns N' Roses"),
#  ('For Those About To Rock We Salute You', 'Incognito'),
#  ('For Those About To Rock We Salute You', 'Iron Maiden'),
#  ('For Those About To Rock We Salute You', 'James Brown'),
#  ('For Those About To Rock We Salute You', 'Jamiroquai'),
#  ('For Those About To Rock We Salute You', 'JET'),
#  ('For Those About To Rock We Salute You', 'Jimi Hendrix'),
#  ('For Those About To Rock We Salute You', 'Joe Satriani'),
#  ('For Those About To Rock We Salute You', 'Jota Quest'),
#  ('For Those About To Rock We Salute You', 'João Suplicy'),
#  ('For Those About To Rock We Salute You', 'Judas Priest'),
#  ('For Those About To Rock We Salute You', 'Legião Urbana'),
#  ('For Those About To Rock We Salute You', 'Lenny Kravitz')]

# %% [markdown]
# In the above query, we used a dot convention to tell SQL which table each selected column belongs to. This method is particularly useful in cases where the specified tables have columns with the same name. For example, the `artists` table and the `albums` table both have an `ArtistId` field.
#
# However, the query above doesn't seem to have provided what we wanted. If we take a closer look and remove the `LIMIT` keyword, we  notice that each artist has written every album in the table (despite other artists having written the same album).
#
# This is because we need to align the records between the tables, making sure that the relevant records in one table correspond to the correct records in the second table. We can achieve this by using the `WHERE` clause to connect the tables using a common field between the two tables.
#
# The query would look like this:
#
# ```SQL
# SELECT table1.field1, table2.field3
# FROM table1, table2
# WHERE table1.field1_id = table2.field1_id;
# ```
#
# Let's rewrite the above query, but this time using the `WHERE` clause to align the records **where the `Artistid` in the `artists` table is the same as the `Artistid` in the `albums` table**.

# %%
# %%sql
#
# SELECT albums.Title, artists.Name
# FROM albums, artists
# WHERE artists.Artistid = albums.Artistid
# LIMIT 10; -- Remove this line to see the full result
# Out:
#  * sqlite:///chinook.db
# Done.
# [('For Those About To Rock We Salute You', 'AC/DC'),
#  ('Balls to the Wall', 'Accept'),
#  ('Restless and Wild', 'Accept'),
#  ('Let There Be Rock', 'AC/DC'),
#  ('Big Ones', 'Aerosmith'),
#  ('Jagged Little Pill', 'Alanis Morissette'),
#  ('Facelift', 'Alice In Chains'),
#  ('Warner 25 Anos', 'Antônio Carlos Jobim'),
#  ('Plays Metallica By Four Cellos', 'Apocalyptica'),
#  ('Audioslave', 'Audioslave')]

# %% [markdown]
# Unlike before, the returned data are aligned perfectly between both tables. We were able to get all albums and the corresponding artists.

# %% [markdown]
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/refs/heads/master/ALX_banners/ALX_Navy.png"  style="width:100px"  ;/>
# </div>
