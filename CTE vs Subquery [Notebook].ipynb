# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img
#  src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/alx-courses/aice/assets/Content_page_banner_blue_dots.png"
#  alt="ALX Content Header"
#  class="full-width-image"
# />
# </div>

# %% [markdown]
# # Common Table Expressions (CTEs) vs. subqueries

# %% [markdown]
# This notebook will compare and contrast Common Table Expressions (CTEs) and subqueries in SQL. We will explore their similarities, differences, use cases, and when to choose one over the other.

# %% [markdown]
# > ⚠️ This notebook will not run on Google Colab because it cannot connect to a local database. Please make sure that this notebook is running on the same local machine as your MySQL Workbench installation and MySQL `united_nations` database.

# %% [markdown]
# ## Learning objectives
#
# - Understand the differences between CTEs and subqueries.
# - Learn how to optimise SQL queries using CTEs.
# - Write complex SQL queries using CTEs and subqueries.

# %% [markdown]
# ## Overview
#
# In this notebook, we will explore Common Table Expressions (CTEs) and subqueries in SQL. These are powerful tools that can help us simplify complex queries, enhance readability, and improve the performance of our SQL operations.
#
# We will examine these concepts in the context of a real-world problem: *Identifying Sub-Saharan African countries with underdeveloped economies that might struggle to gain access to water.*
#
# We will start by writing SQL queries using subqueries and then delve into the optimisation of these queries using CTEs.

# %% [markdown]
# ### Connecting to our MySQL database
#
# Since we have a MySQL database, we can connect to it using mysql and pymysql.

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook.

# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# Establish a connection to the local database using the '%sql' magic command.
# Replace 'password' with our connection password and `db_name` with our database name.

# %sql mysql+pymysql://root:HardThings25@localhost:3306/united_nations

# %% [markdown]
# ## Exercise
#
# We will be working with the `united_nations.Access_to_Basic_Services` table, which contains information about different countries, their access to basic services, and their estimated GDP.
#
# The tasks will involve writing and optimising SQL queries to identify Sub-Saharan African countries with an estimated GDP below the regional average and less than 60% access to managed drinking water services in 2020.

# %% [markdown]
# ### Task 1: Calculate the average GDP for each region
#
# Start by calculating the average GDP for each country’s region for 2020 using the `AVG(Est_gdp_in_billions) OVER(PARTITION BY Region)` window function.

# %%
# %%sql
# SELECT
#      Region,
#     Country_name,
#     Pct_managed_drinking_water_services,
#     Pct_managed_sanitation_services,
#     Est_gdp_in_billions,
#     AVG(Est_gdp_in_billions) OVER(PARTITION BY Region) AS Avg_gdp_for_region
# FROM united_nations.Access_to_Basic_Services
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 1048 rows affected.
# [('Central and Southern Asia', 'Kazakhstan', Decimal('94.67'), Decimal('98.00'), Decimal('184.39'), Decimal('302.746197')),
#  ('Central and Southern Asia', 'Kazakhstan', Decimal('94.67'), Decimal('98.00'), Decimal('137.28'), Decimal('302.746197')),
#  ('Central and Southern Asia', 'Kazakhstan', Decimal('95.00'), Decimal('98.00'), Decimal('166.81'), Decimal('302.746197')),
#  ('Central and Southern Asia', 'Kazakhstan', Decimal('95.00'), Decimal('98.00'), Decimal('179.34'), Decimal('302.746197')),
#  ('Central and Southern Asia', 'Kazakhstan', Decimal('95.00'), Decimal('98.00'), Decimal('181.67'), Decimal('302.746197')),
#  ('Central and Southern Asia', 'Kazakhstan', Decimal('95.00'), Decimal('98.00'), Decimal('171.08'), Decimal('302.746197')),
#  ('Central and Southern Asia', 'Kyrgyzstan', Decimal('89.67'), Decimal('96.67'), None, Decimal('302.746197')),
#  ('Central and Southern Asia', 'Kyrgyzstan', Decimal('90.33'), Decimal('96.67'), None, Decimal('302.746197')),
#  ('Central and Southern Asia', 'Kyrgyzstan', Decimal('91.00'), Decimal('97.33'), None, Decimal('302.746197')),
#  ('Central and Southern Asia', 'Kyrgyzstan', Decimal('91.33'), Decimal('97.33'), None, Decimal('302.746197')),
#  ('Central and Southern Asia', 'Kyrgyzstan', Decimal('91.67'), Decimal('97.33'), None, Decimal('302.746197')),
#  ('Central and Southern Asia', 'Kyrgyzstan', Decimal('92.67'), Decimal('97.67'), None, Decimal('302.746197')),
#  ('Central and Southern Asia', 'Tajikistan', Decimal('80.33'), Decimal('95.00'), Decimal('8.27'), Decimal('302.746197')),
#  ('Central and Southern Asia', 'Tajikistan', Decimal('81.33'), Decimal('95.33'), Decimal('6.99'), Decimal('302.746197')),
#  ('Central and Southern Asia', 'Tajikistan', Decimal('82.33'), Decimal('95.67'), Decimal('7.54'), Decimal('302.746197')),
#  ('Central and Southern Asia', 'Tajikistan', Decimal('83.33'), Decimal('95.67'), Decimal('7.77'), Decimal('302.746197')),
#  ('Central and Southern Asia', 'Tajikistan', Decimal('85.00'), Decimal('96.33'), Decimal('8.30'), Decimal('302.746197')),
#  ('Central and Southern Asia', 'Tajikistan', Decimal('85.00'), Decimal('96.33'), Decimal('8.13'), Decimal('302.746197')),
#  ('Central and Southern Asia', 'Turkmenistan', Decimal('97.67'), Decimal('97.33'), Decimal('35.80'), Decimal('302.746197')),
#  ('Central and Southern Asia', 'Turkmenistan', Decimal('98.00'), Decimal('98.00'), Decimal('36.17'), Decimal('302.746197')),
#  ('Central and Southern Asia', 'Turkmenistan', Decimal('98.67'), Decimal('98.00'), Decimal('37.93'), Decimal('302.746197')),
#  ('Central and Southern Asia', 'Turkmenistan', Decimal('99.33'), Decimal('98.67'), Decimal('40.77'), Decimal('302.746197')),
#  ('Central and Southern Asia', 'Turkmenistan', Decimal('100.00'), Decimal('99.33'), Decimal('45.23'), Decimal('302.746197')),
#  ('Central and Southern Asia', 'Turkmenistan', Decimal('100.00'), Decimal('99.33'), None, Decimal('302.746197')),
#  ('Central and Southern Asia', 'Uzbekistan', Decimal('97.67'), Decimal('100.00'), Decimal('86.20'), Decimal('302.746197')),
#  ('Central and Southern Asia', 'Uzbekistan', Decimal('97.67'), Decimal('100.00'), Decimal('86.14'), Decimal('302.746197')),
#  ('Central and Southern Asia', 'Uzbekistan', Decimal('98.00'), Decimal('100.00'), Decimal('62.08'), Decimal('302.746197')),
#  ('Central and Southern Asia', 'Uzbekistan', Decimal('98.00'), Decimal('100.00'), Decimal('52.63'), Decimal('302.746197')),
#  ('Central and Southern Asia', 'Uzbekistan', Decimal('98.00'), Decimal('100.00'), Decimal('59.91'), Decimal('302.746197')),
#  ('Central and Southern Asia', 'Uzbekistan', Decimal('98.00'), Decimal('100.00'), Decimal('59.89'), Decimal('302.746197')),
#  ('Central and Southern Asia', 'Afghanistan', Decimal('67.00'), Decimal('45.67'), Decimal('20.00'), Decimal('302.746197')),
#  ('Central and Southern Asia', 'Afghanistan', Decimal('69.67'), Decimal('47.00'), Decimal('18.02'), Decimal('302.746197')),
#  ('Central and Southern Asia', 'Afghanistan', Decimal('72.33'), Decimal('49.33'), Decimal('18.90'), Decimal('302.746197')),
#  ('Central and Southern Asia', 'Afghanistan', Decimal('75.33'), Decimal('50.67'), Decimal('18.42'), Decimal('302.746197')),
#  ('Central and Southern Asia', 'Afghanistan', Decimal('78.00'), Decimal('52.33'), Decimal('18.90'), Decimal('302.746197')),
#  ('Central and Southern Asia', 'Afghanistan', Decimal('80.33'), Decimal('54.00'), Decimal('20.14'), Decimal('302.746197')),
#  ('Central and Southern Asia', 'Bangladesh', Decimal('97.33'), Decimal('47.33'), Decimal('195.08'), Decimal('302.746197')),
#  ('Central and Southern Asia', 'Bangladesh', Decimal('97.33'), Decimal('48.67'), Decimal('265.24'), Decimal('302.746197')),
#  ('Central and Southern Asia', 'Bangladesh', Decimal('97.33'), Decimal('50.00'), Decimal('293.75'), Decimal('302.746197')),
#  ('Central and Southern Asia', 'Bangladesh', Decimal('97.33'), Decimal('51.33'), Decimal('321.38'), Decimal('302.746197')),
#  ('Central and Southern Asia', 'Bangladesh', Decimal('97.67'), Decimal('52.67'), Decimal('351.24'), Decimal('302.746197')),
#  ('Central and Southern Asia', 'Bangladesh', Decimal('97.67'), Decimal('54.00'), Decimal('373.90'), Decimal('302.746197')),
#  ('Central and Southern Asia', 'Bhutan', Decimal('96.33'), Decimal('70.67'), Decimal('2.00'), Decimal('302.746197')),
#  ('Central and Southern Asia', 'Bhutan', Decimal('97.00'), Decimal('71.67'), Decimal('2.16'), Decimal('302.746197')),
#  ('Central and Southern Asia', 'Bhutan', Decimal('97.33'), Decimal('73.33'), Decimal('2.45'), Decimal('302.746197')),
#  ('Central and Southern Asia', 'Bhutan', Decimal('97.33'), Decimal('74.33'), Decimal('2.45'), Decimal('302.746197')),
#  ('Central and Southern Asia', 'Bhutan', Decimal('97.33'), Decimal('75.00'), Decimal('2.54'), Decimal('302.746197')),
#  ('Central and Southern Asia', 'Bhutan', Decimal('97.33'), Decimal('76.67'), Decimal('2.33'), Decimal('302.746197')),
#  ('Central and Southern Asia', 'India', Decimal
), Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'South Africa', Decimal('90.00'), Decimal('73.67'), Decimal('346.71'), Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'South Africa', Decimal('90.33'), Decimal('74.67'), Decimal('323.59'), Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'South Africa', Decimal('91.00'), Decimal('75.67'), Decimal('381.45'), Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'South Africa', Decimal('91.33'), Decimal('77.00'), Decimal('404.16'), Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'South Africa', Decimal('91.67'), Decimal('78.00'), Decimal('388.53'), Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'South Africa', Decimal('92.00'), Decimal('78.67'), Decimal('337.62'), Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'Benin', Decimal('65.33'), Decimal('15.33'), Decimal('11.39'), Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'Benin', Decimal('65.33'), Decimal('15.67'), Decimal('11.82'), Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'Benin', Decimal('65.33'), Decimal('16.00'), Decimal('12.70'), Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'Benin', Decimal('65.67'), Decimal('16.33'), Decimal('14.26'), Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'Benin', Decimal('65.33'), Decimal('17.00'), Decimal('14.39'), Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'Benin', Decimal('65.33'), Decimal('17.33'), Decimal('15.65'), Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'Burkina Faso', Decimal('56.33'), Decimal('24.67'), Decimal('11.83'), Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'Burkina Faso', Decimal('56.00'), Decimal('24.67'), Decimal('12.83'), Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'Burkina Faso', Decimal('55.00'), Decimal('25.00'), Decimal('14.11'), Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'Burkina Faso', Decimal('54.33'), Decimal('25.00'), Decimal('15.89'), Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'Burkina Faso', Decimal('54.00'), Decimal('25.00'), Decimal('16.18'), Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'Burkina Faso', Decimal('53.33'), Decimal('25.00'), Decimal('17.93'), Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'Cabo Verde', Decimal('83.33'), Decimal('68.67'), Decimal('1.60'), Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'Cabo Verde', Decimal('84.33'), Decimal('70.33'), Decimal('1.66'), Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'Cabo Verde', Decimal('85.33'), Decimal('72.33'), Decimal('1.77'), Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'Cabo Verde', Decimal('86.00'), Decimal('74.67'), Decimal('1.97'), Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'Cabo Verde', Decimal('86.67'), Decimal('76.00'), Decimal('1.98'), Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'Cabo Verde', Decimal('87.33'), Decimal('78.00'), Decimal('1.70'), Decimal('36.321901')),
#  ('Sub-Saharan Africa', "Côte d'Ivoire", Decimal('71.33'), Decimal('30.67'), None, Decimal('36.321901')),
#  ('Sub-Saharan Africa', "Côte d'Ivoire", Decimal('71.00'), Decimal('31.33'), None, Decimal('36.321901')),
#  ('Sub-Saharan Africa', "Côte d'Ivoire", Decimal('71.00'), Decimal('32.00'), None, Decimal('36.321901')),
#  ('Sub-Saharan Africa', "Côte d'Ivoire", Decimal('71.00'), Decimal('33.00'), None, Decimal('36.321901')),
#  ('Sub-Saharan Africa', "Côte d'Ivoire", Decimal('70.67'), Decimal('33.67'), None, Decimal('36.321901')),
#  ('Sub-Saharan Africa', "Côte d'Ivoire", Decimal('70.67'), Decimal('34.67'), None, Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'Gambia', Decimal('78.00'), Decimal('45.00'), None, Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'Gambia', Decimal('78.33'), Decimal('45.00'), None, Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'Gambia', Decimal('78.67'), Decimal('44.67'), None, Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'Gambia', Decimal('78.67'), Decimal('44.67'), None, Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'Gambia', Decimal('79.33'), Decimal('44.33'), None, Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'Gambia', Decimal('79.33'), Decimal('44.33'), None, Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'Ghana', Decimal('79.33'), Decimal('18.67'), Decimal('49.41'), Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'Ghana', Decimal('80.33'), Decimal('19.67'), Decimal('56.17'), Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'Ghana', Decimal('81.33'), Decimal('20.67'), Decimal('60.41'), Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'Ghana', Decimal('82.67'), Decimal('21.67'), Decimal('67.30'), Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'Ghana', Decimal('83.67'), Decimal('22.67'), Decimal('68.34'), Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'Ghana', Decimal('84.67'), Decimal('23.00'), Decimal('70.04'), Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'Guinea', Decimal('67.00'), Decimal('26.00'), Decimal('8.79'), Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'Guinea', Decimal('67.00'), Decimal('27.33'), Decimal('8.60'), Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'Guinea', Decimal('67.33'), Decimal('28.33'), Decimal('10.32'), Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'Guinea', Decimal('67.00'), Decimal('29.67'), Decimal('11.86'), Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'Guinea', Decimal('67.00'), Decimal('30.67'), Decimal('13.44'), Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'Guinea', Decimal('67.33'), Decimal('32.33'), Decimal('14.18'), Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'Guinea-Bissau', Decimal('60.00'), Decimal('15.67'), Decimal('1.05'), Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'Guinea-Bissau', Decimal('60.33'), Decimal('16.33'), Decimal('1.18'), Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'Guinea-Bissau', Decimal('60.00'), Decimal('17.00'), Decimal('1.35'), Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'Guinea-Bissau', Decimal('60.00'), Decimal('18.00'), Decimal('1.50'), Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'Guinea-Bissau', Decimal('60.00'), Decimal('18.33'), Decimal('1.44'), Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'Guinea-Bissau', Decimal('60.00'), Decimal('19.33'), Decimal('1.43'), Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'Liberia', Decimal('72.67'), Decimal('17.00'), Decimal('3.23'), Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'Liberia', Decimal('73.00'), Decimal('17.33'), Decimal('3.40'), Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'Liberia', Decimal('74.00'), Decimal('17.33'), Decimal('3.39'), Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'Liberia', Decimal('74.00'), Decimal('17.67'), Decimal('3.42'), Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'Liberia', Decimal('75.00'), Decimal('17.67'), Decimal('3.32'), Decimal('36.321901')),
#  ('Sub-Saharan Africa', 'Liberia', Decimal('75.00'), Decimal('17.67'), Decimal('3.04'), Decimal('36.321901')),
#  ...]

# %% [markdown]
# ### Task 2: Filter the data
#
# Next, let’s filter the data to focus only on the Sub-Saharan African countries with underdeveloped economies and also limited access to managed drinking water services in 2020.

# %%
# %%sql
# SELECT
#     Region,
#     Country_name,
#     Pct_managed_drinking_water_services,
#     Pct_managed_sanitation_services,
#     Est_gdp_in_billions,
#     AVG(Est_gdp_in_billions) OVER(PARTITION BY Region) AS Avg_gdp_for_region
# FROM (
#     SELECT
#      Region,
#     Country_name,
#     Pct_managed_drinking_water_services,
#     Pct_managed_sanitation_services,
#     Est_gdp_in_billions,
#     AVG(Est_gdp_in_billions) OVER(PARTITION BY Region) AS Avg_gdp_for_region
# FROM united_nations.Access_to_basic_services
# WHERE
#     Time_period = 2020) AS AVG_wrld_gdp
# WHERE
#     Est_gdp_in_Billions < Avg_gdp_for_region
# AND
#    Pct_managed_drinking_water_services < 60
# AND
#     Region = 'Sub-saharan Africa'
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 6 rows affected.
# [('Sub-Saharan Africa', 'Madagascar', Decimal('56.33'), Decimal('13.00'), Decimal('13.05'), Decimal('10.775000')),
#  ('Sub-Saharan Africa', 'Somalia', Decimal('57.33'), Decimal('40.00'), Decimal('6.88'), Decimal('10.775000')),
#  ('Sub-Saharan Africa', 'Central African Republic', Decimal('38.33'), Decimal('15.00'), Decimal('2.33'), Decimal('10.775000')),
#  ('Sub-Saharan Africa', 'Chad', Decimal('52.67'), Decimal('18.67'), Decimal('10.72'), Decimal('10.775000')),
#  ('Sub-Saharan Africa', 'Burkina Faso', Decimal('53.33'), Decimal('25.00'), Decimal('17.93'), Decimal('10.775000')),
#  ('Sub-Saharan Africa', 'Niger', Decimal('57.33'), Decimal('24.67'), Decimal('13.74'), Decimal('10.775000'))]

# %% [markdown]
# Note that you get an error message:
#
# Unknown column `Avg_gdp_for_region` in `where clause`...
#
# This is because we cannot calculate *and* reference that result in the same query.

# %% [markdown]
# ### Task 3: Implement the solution using subqueries
#
# We can fix the error by using a subquery to calculate the average regional GDP, and then use those results in the main query.

# %%
# %%sql
# SELECT
#     Region,
#     Country_name,
#     Pct_managed_drinking_water_services,
#     Pct_managed_sanitation_services,
#     Est_gdp_in_billions,
#     AVG(Est_gdp_in_billions) OVER(PARTITION BY Region) AS Avg_gdp_for_region
# FROM (
#     SELECT
#      Region,
#     Country_name,
#     Pct_managed_drinking_water_services,
#     Pct_managed_sanitation_services,
#     Est_gdp_in_billions,
#     AVG(Est_gdp_in_billions) OVER(PARTITION BY Region) AS Avg_gdp_for_region
# FROM united_nations.Access_to_basic_services
# WHERE
#     Time_period = 2020) AS AVG_wrld_gdp
# WHERE
#     Est_gdp_in_Billions < Avg_gdp_for_region
# AND
#    Pct_managed_drinking_water_services < 60
# AND
#     Region = 'Sub-saharan Africa'
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 6 rows affected.
# [('Sub-Saharan Africa', 'Madagascar', Decimal('56.33'), Decimal('13.00'), Decimal('13.05'), Decimal('10.775000')),
#  ('Sub-Saharan Africa', 'Somalia', Decimal('57.33'), Decimal('40.00'), Decimal('6.88'), Decimal('10.775000')),
#  ('Sub-Saharan Africa', 'Central African Republic', Decimal('38.33'), Decimal('15.00'), Decimal('2.33'), Decimal('10.775000')),
#  ('Sub-Saharan Africa', 'Chad', Decimal('52.67'), Decimal('18.67'), Decimal('10.72'), Decimal('10.775000')),
#  ('Sub-Saharan Africa', 'Burkina Faso', Decimal('53.33'), Decimal('25.00'), Decimal('17.93'), Decimal('10.775000')),
#  ('Sub-Saharan Africa', 'Niger', Decimal('57.33'), Decimal('24.67'), Decimal('13.74'), Decimal('10.775000'))]

# %% [markdown]
# ### Task 4: Implement the solution using Common Table Expressions (CTEs)
#
# Now, let's attempt the same problem using Common Table Expressions (CTEs).

# %%
# %%sql
# WITH Avg_wld_gdp AS ( SELECT
#      Region,
#     Country_name,
#     Pct_managed_drinking_water_services,
#     Pct_managed_sanitation_services,
#     Est_gdp_in_billions,
#     AVG(Est_gdp_in_billions) OVER(PARTITION BY Region) AS Avg_gdp_for_region
# FROM united_nations.Access_to_basic_services
# WHERE
#     Time_period = 2020
# )
# SELECT
#     Region,
#     Country_name,
#     Pct_managed_drinking_water_services,
#     Pct_managed_sanitation_services,
#     Est_gdp_in_billions,
#     Avg_gdp_for_region
# FROM Avg_wld_gdp
# WHERE
#     Region = 'Sub-saharan Africa'
# AND
#      Pct_managed_drinking_water_services < 60
# AND
#     Est_gdp_in_billions < Avg_gdp_for_region
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 6 rows affected.
# [('Sub-Saharan Africa', 'Madagascar', Decimal('56.33'), Decimal('13.00'), Decimal('13.05'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', 'Somalia', Decimal('57.33'), Decimal('40.00'), Decimal('6.88'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', 'Central African Republic', Decimal('38.33'), Decimal('15.00'), Decimal('2.33'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', 'Chad', Decimal('52.67'), Decimal('18.67'), Decimal('10.72'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', 'Burkina Faso', Decimal('53.33'), Decimal('25.00'), Decimal('17.93'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', 'Niger', Decimal('57.33'), Decimal('24.67'), Decimal('13.74'), Decimal('39.041316'))]

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### Task 1: Calculate the average GDP for each region

# %%
# %%sql
# SELECT
#     Region,
#     Country_name,
#     Pct_managed_drinking_water_services,
#     Pct_managed_sanitation_services,
#     Est_gdp_in_billions,
#     AVG(Est_gdp_in_billions) OVER(PARTITION BY Region) AS Avg_gdp_for_region
# FROM united_nations.Access_to_Basic_Services
# WHERE Time_period = 2020
# Limit 10;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 10 rows affected.
# [('Central and Southern Asia', 'Kazakhstan', Decimal('95.00'), Decimal('98.00'), Decimal('171.08'), Decimal('338.738182')),
#  ('Central and Southern Asia', 'Kyrgyzstan', Decimal('92.67'), Decimal('97.67'), None, Decimal('338.738182')),
#  ('Central and Southern Asia', 'Tajikistan', Decimal('85.00'), Decimal('96.33'), Decimal('8.13'), Decimal('338.738182')),
#  ('Central and Southern Asia', 'Turkmenistan', Decimal('100.00'), Decimal('99.33'), None, Decimal('338.738182')),
#  ('Central and Southern Asia', 'Uzbekistan', Decimal('98.00'), Decimal('100.00'), Decimal('59.89'), Decimal('338.738182')),
#  ('Central and Southern Asia', 'Afghanistan', Decimal('80.33'), Decimal('54.00'), Decimal('20.14'), Decimal('338.738182')),
#  ('Central and Southern Asia', 'Bangladesh', Decimal('97.67'), Decimal('54.00'), Decimal('373.90'), Decimal('338.738182')),
#  ('Central and Southern Asia', 'Bhutan', Decimal('97.33'), Decimal('76.67'), Decimal('2.33'), Decimal('338.738182')),
#  ('Central and Southern Asia', 'India', Decimal('91.00'), Decimal('72.33'), Decimal('2667.69'), Decimal('338.738182')),
#  ('Central and Southern Asia', 'Iran (Islamic Republic of)', Decimal('96.67'), Decimal('88.33'), None, Decimal('338.738182'))]

# %% [markdown]
# ### Task 2: Filter the data

# %%
# %%sql
# SELECT
#     Region,
#     Country_name,
#     Pct_managed_drinking_water_services,
#     Pct_managed_sanitation_services,
#     Est_gdp_in_billions,
#     AVG(Est_gdp_in_billions) OVER(PARTITION BY Region) AS Avg_gdp_for_region
# FROM
#     united_nations.Access_to_Basic_Services
# WHERE
#     Region = 'Sub-Saharan Africa'
#     AND Time_period = 2020
#     AND Pct_managed_drinking_water_services < 60
#     AND Est_gdp_in_billions < Avg_gdp_for_region;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# (pymysql.err.OperationalError) (1054, "Unknown column 'Avg_gdp_for_region' in 'where clause'")
# [SQL: SELECT
#     Region,
#     Country_name,
#     Pct_managed_drinking_water_services,
#     Pct_managed_sanitation_services,
#     Est_gdp_in_billions,
#     AVG(Est_gdp_in_billions) OVER(PARTITION BY Region) AS Avg_gdp_for_region
# FROM
#     united_nations.Access_to_Basic_Services
# WHERE
#     Region = 'Sub-Saharan Africa'
#     AND Time_period = 2020
#     AND Pct_managed_drinking_water_services < 60
#     AND Est_gdp_in_billions < Avg_gdp_for_region;]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %% [markdown]
# ### Task 3: Implement the solution using subqueries

# %%
# %%sql
# SELECT
#     Country_name,
#     Region,
#     Pct_managed_drinking_water_services,
#     Pct_managed_sanitation_services,
#     Est_gdp_in_billions,
#     Avg_gdp_for_region
# FROM (
#     SELECT
#         Region,
#         Country_name,
#         Pct_managed_drinking_water_services,
#         Pct_managed_sanitation_services,
#         Est_gdp_in_billions,
#         AVG(Est_gdp_in_billions) OVER(PARTITION BY Region) AS Avg_gdp_for_region
#     FROM
#         united_nations.Access_to_Basic_Services
#     WHERE
#         Time_period = 2020
#     ) AS Avg_world_GDP_2020
# WHERE
#     Region = 'Sub-Saharan Africa'
#     AND Pct_managed_drinking_water_services < 60
#     AND Est_gdp_in_billions < Avg_gdp_for_region;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 0 rows affected.
# []

# %% [markdown]
# ### Task 4: Implement the solution using Common Table Expressions (CTEs)

# %%
# %%sql
# -- This CTE calculates the average regional GDP for each country, for the year 2020.
# WITH Avg_world_GDP_2020 AS (
#     SELECT
#         Region,
#         Country_name,
#         Pct_managed_drinking_water_services,
#         Pct_managed_sanitation_services,
#         Est_gdp_in_billions,
#         AVG(Est_gdp_in_billions) OVER(PARTITION BY Region) AS Avg_gdp_for_region
#     FROM
#         united_nations.Access_to_Basic_Services
#     WHERE
#         Time_period = 2020
# )
#
# /*
# This query filters the Avg_world_GDP_2020 CTE for
# countries that have below-average GDP, in the
# Sub-Saharan Africa region, and struggling with water access.
# */
#
# SELECT
#     Country_name
# FROM
#     Avg_world_GDP_2020
# WHERE
#     Region = 'Sub-Saharan Africa'
#     AND Pct_managed_drinking_water_services < 60
#     AND Est_gdp_in_billions < Avg_gdp_for_region;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 0 rows affected.
# []

# %% [markdown]
# Note how much easier the CTE is to read compared to the query using a subquery.

# %% [markdown]
# ## Summary
#
# In our exercises, we have seen how subqueries and Common Table Expressions (CTEs) can be used to break down complex queries into manageable parts. This not only enhances readability but also improves performance by enabling the database to process the query more efficiently.
#
# For instance, when identifying Sub-Saharan African countries with underdeveloped economies struggling to access drinking water services, we first used subqueries to combine conditions and evaluate the GDP criteria before assessing water access. We then applied the concept of Common Table Expressions as another optimised alternative, which allowed us to calculate the regional average GDP separately. This created a reusable block of code that could be referenced in the final query.
#
# By comparing the two implementations, we saw how CTEs could simplify complex queries and eliminate the need for saving intermediary tables and taking up more space in the database or using multiple subqueries.
#
# The use of CTEs and subqueries empowers us to optimise SQL queries effectively, making our data analysis more efficient and organised.
#
# Remember, the choice between subqueries and CTEs often depends on the specific requirements of your task and the complexity of your SQL queries. It's always a good idea to test different implementations and choose the one that best meets your needs.

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/refs/heads/master/ALX_banners/ALX_Navy.png"  style="width:100px"  ;/>
# </div>
