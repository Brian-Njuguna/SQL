# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img
#  src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/alx-courses/aice/assets/Content_page_banner_blue_dots.png"
#  alt="ALX Content Header"
#  class="full-width-image"
# />
# </div>

# %% [markdown]
# # Subquery in FROM

# %% [markdown]
# > ⚠️ This notebook will not run on Google Colab because it cannot connect to a local database. Please make sure that this notebook is running on the same local machine as your MySQL Workbench installation and MySQL `united_nations` database.

# %% [markdown]
# ## Description

# %% [markdown]
# In this lesson we will use a subquery like a temporary table, meaning we will do a calculation, and then reference the result of that calculation in another query.

# %% [markdown]
# ## Learning objectives
#
# In this train we will learn:
# - How to create a query using the FROM clause.

# %% [markdown]
# ## Connecting to our MySQL database
#
# Using our `Access_to_Basic_Services` table in our `united_nations` database we created in MySQL Workbench, we want to answer some questions about our dataset. We can apply the same queries we used in MySQL Workbench in this notebook if we connect to our MySQL server by running the cells below.
#
# Note that before, for this tutorial, we will already have worked through the lessons where the `united_nations.Basic_Services` table, `united_nations.Economic_Indicators` table, and the `united_nations.Geographic_Locations` table have been created.

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook. 
# If you get an error here, make sure that mysql and pymysql are installed correctly. 

# %load_ext sql

# %%
# Establish a connection to the local database using the '%sql' magic command.
# Replace 'password' with our connection password and `db_name` with our database name. 
# If you get an error here, please make sure the database name or password is correct.

# %sql mysql+pymysql://root:HardThings25@localhost:3306/united_nations

# %% [markdown]
# To make a query, we add the `%%sql` command to the start of a cell, create one open line then the query like below, and run the cell.

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     Access_to_Basic_Services
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 5 rows affected.
# [('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2015, Decimal('94.67'), Decimal('98.00'), Decimal('17.542806'), Decimal('184.39'), Decimal('2699700.00'), Decimal('4.93')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2016, Decimal('94.67'), Decimal('98.00'), Decimal('17.794055'), Decimal('137.28'), Decimal('2699700.00'), Decimal('4.96')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2017, Decimal('95.00'), Decimal('98.00'), Decimal('18.037776'), Decimal('166.81'), Decimal('2699700.00'), Decimal('4.90')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2018, Decimal('95.00'), Decimal('98.00'), Decimal('18.276452'), Decimal('179.34'), Decimal('2699700.00'), Decimal('4.85')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2019, Decimal('95.00'), Decimal('98.00'), Decimal('18.513673'), Decimal('181.67'), Decimal('2699700.00'), Decimal('4.80'))]

# %% [markdown]
# ## Exercise

# %% [markdown]
# In this exercise. We will use a subquery to answer the following question: What is the average GDP and population for countries with unemployment rates above 5%?

# %% [markdown]
# ### Creating the subquery
# Construct the subquery that displays the average GDP and average population of countries for 2020. The query should have the following columns: `Country_name`, `Avg_GDP`, `Avg_Population`.

# %%
# %%sql
# SELECT
#  Country_name,
#  AVG(Est_population_in_millions) AS AVG_Population,
#  AVG(Est_gdp_in_billions) AS AVG_GDP
# FROM Access_to_basic_services
# WHERE
#     Pct_unemployment > 5
# AND Time_period = '2020'
# GROUP BY country_name
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 37 rows affected.
# [('Uzbekistan', Decimal('34.2320500000'), Decimal('59.890000')),
#  ('Afghanistan', Decimal('38.9722300000'), Decimal('20.140000')),
#  ('Bhutan', Decimal('0.7725060000'), Decimal('2.330000')),
#  ('India', Decimal('1396.3871270000'), Decimal('2667.690000')),
#  ('Sri Lanka', Decimal('21.9190000000'), Decimal('85.350000')),
#  ('China', Decimal('1411.1000000000'), Decimal('14687.670000')),
#  ('Mongolia', Decimal('3.2943350000'), Decimal('13.310000')),
#  ('Brunei Darussalam', Decimal('0.4417250000'), Decimal('12.010000')),
#  ('Canada', Decimal('38.0372040000'), Decimal('1645.420000')),
#  ('Dominican Republic', Decimal('10.9996640000'), Decimal('78.840000')),
#  ('Jamaica', Decimal('2.8204360000'), Decimal('13.810000')),
#  ('Costa Rica', Decimal('5.1231050000'), Decimal('62.160000')),
#  ('El Salvador', Decimal('6.2927310000'), Decimal('24.560000')),
#  ('Honduras', Decimal('10.1217630000'), Decimal('23.830000')),
#  ('Panama', Decimal('4.2943960000'), Decimal('53.980000')),
#  ('Argentina', Decimal('45.3767630000'), Decimal('385.540000')),
#  ('Brazil', Decimal('213.1963040000'), Decimal('1448.560000')),
#  ('Chile', Decimal('19.3003150000'), Decimal('252.730000')),
#  ('Colombia', Decimal('50.9306620000'), Decimal('270.300000')),
#  ('Ecuador', Decimal('17.5885950000'), Decimal('99.290000')),
#  ('Paraguay', Decimal('6.6186950000'), Decimal('35.430000')),
#  ('Peru', Decimal('33.3047560000'), Decimal('201.710000')),
#  ('Uruguay', Decimal('3.4290860000'), Decimal('53.560000')),
#  ('Armenia', Decimal('2.8056080000'), Decimal('12.640000')),
#  ('Azerbaijan', Decimal('10.0931210000'), Decimal('42.690000')),
#  ('Cyprus', Decimal('1.2375370000'), Decimal('25.010000')),
#  ('Georgia', Decimal('3.7227160000'), Decimal('15.840000')),
#  ('Jordan', Decimal('10.9287210000'), Decimal('44.180000')),
#  ('Saudi Arabia', Decimal('35.9971070000'), Decimal('703.370000')),
#  ('Australia', Decimal('25.6552890000'), Decimal('1326.900000')),
#  ('New Caledonia', Decimal('0.2711300000'), Decimal('9.440000')),
#  ('Kiribati', Decimal('0.1264630000'), Decimal('0.180000')),
#  ('Mauritius', Decimal('1.2657400000'), Decimal('11.400000')),
#  ('Rwanda', Decimal('13.1463620000'), Decimal('10.180000')),
#  ('Zambia', Decimal('18.9277150000'), Decimal('18.110000')),
#  ('Botswana', Decimal('2.5464020000'), Decimal('14.930000')),
#  ('South Africa', Decimal('58.8019270000'), Decimal('337.620000'))]

# %% [markdown]
# ### Creating the main query
# Construct a query that filters out countries with unemployment rates above 5%. The query should include the following columns: `Country_name`, `Est_gdp_in_billions`,  `Est_population_in_millions`.

# %%
# %%sql
# SELECT
#     Country_name,
#     Est_population_in_millions,
#     Est_gdp_in_billions
# FROM Access_to_basic_services
# WHERE pct_unemployment >5
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 230 rows affected.
# [('Tajikistan', Decimal('8.725318'), Decimal('6.99')),
#  ('Uzbekistan', Decimal('31.298900'), Decimal('86.20')),
#  ('Uzbekistan', Decimal('31.847900'), Decimal('86.14')),
#  ('Uzbekistan', Decimal('32.388600'), Decimal('62.08')),
#  ('Uzbekistan', Decimal('32.956100'), Decimal('52.63')),
#  ('Uzbekistan', Decimal('33.580350'), Decimal('59.91')),
#  ('Uzbekistan', Decimal('34.232050'), Decimal('59.89')),
#  ('Afghanistan', Decimal('35.643418'), Decimal('18.90')),
#  ('Afghanistan', Decimal('38.972230'), Decimal('20.14')),
#  ('Bhutan', Decimal('0.772506'), Decimal('2.33')),
#  ('India', Decimal('1369.003306'), Decimal('2702.93')),
#  ('India', Decimal('1383.112050'), Decimal('2831.55')),
#  ('India', Decimal('1396.387127'), Decimal('2667.69')),
#  ('Maldives', Decimal('0.454252'), Decimal('4.38')),
#  ('Nepal', Decimal('28.183426'), Decimal('28.97')),
#  ('Sri Lanka', Decimal('21.919000'), Decimal('85.35')),
#  ('China', Decimal('1407.745000'), Decimal('14279.94')),
#  ('China', Decimal('1411.100000'), Decimal('14687.67')),
#  ('Mongolia', Decimal('3.029555'), Decimal('11.18')),
#  ('Mongolia', Decimal('3.096030'), Decimal('11.48')),
#  ('Mongolia', Decimal('3.163991'), Decimal('13.18')),
#  ('Mongolia', Decimal('3.232430'), Decimal('14.21')),
#  ('Mongolia', Decimal('3.294335'), Decimal('13.31')),
#  ('Brunei Darussalam', Decimal('0.430276'), Decimal('12.13')),
#  ('Brunei Darussalam', Decimal('0.434274'), Decimal('13.57')),
#  ('Brunei Darussalam', Decimal('0.438048'), Decimal('13.47')),
#  ('Brunei Darussalam', Decimal('0.441725'), Decimal('12.01')),
#  ('Canada', Decimal('35.702908'), Decimal('1556.51')),
#  ('Canada', Decimal('36.109487'), Decimal('1527.99')),
#  ('Canada', Decimal('36.545236'), Decimal('1649.27')),
#  ('Canada', Decimal('37.065084'), Decimal('1725.33')),
#  ('Canada', Decimal('37.601230'), Decimal('1742.02')),
#  ('Canada', Decimal('38.037204'), Decimal('1645.42')),
#  ('Greenland', Decimal('0.056114'), Decimal('2.50')),
#  ('Barbados', Decimal('0.278083'), Decimal('4.72')),
#  ('Barbados', Decimal('0.278649'), Decimal('4.83')),
#  ('Barbados', Decimal('0.279187'), Decimal('4.98')),
#  ('Barbados', Decimal('0.279688'), Decimal('5.10')),
#  ('Barbados', Decimal('0.280180'), Decimal('5.32')),
#  ('Dominican Republic', Decimal('10.405832'), Decimal('71.16')),
#  ('Dominican Republic', Decimal('10.527592'), Decimal('75.70')),
#  ('Dominican Republic', Decimal('10.647244'), Decimal('80.00')),
#  ('Dominican Republic', Decimal('10.765531'), Decimal('85.56')),
#  ('Dominican Republic', Decimal('10.881882'), Decimal('88.94')),
#  ('Dominican Republic', Decimal('10.999664'), Decimal('78.84')),
#  ('Grenada', Decimal('0.118980'), Decimal('1.00')),
#  ('Jamaica', Decimal('2.794445'), Decimal('14.19')),
#  ('Jamaica', Decimal('2.802695'), Decimal('14.08')),
#  ('Jamaica', Decimal('2.808376'), Decimal('14.81')),
#  ('Jamaica', Decimal('2.811835'), Decimal('15.73')),
#  ('Jamaica', Decimal('2.820436'), Decimal('13.81')),
#  ('Puerto Rico', Decimal('3.473232'), Decimal('103.38')),
#  ('Puerto Rico', Decimal('3.406672'), Decimal('104.34')),
#  ('Puerto Rico', Decimal('3.325286'), Decimal('103.45')),
#  ('Puerto Rico', Decimal('3.193354'), Decimal('100.96')),
#  ('Puerto Rico', Decimal('3.193694'), Decimal('105.13')),
#  ('Belize', Decimal('0.359871'), Decimal('2.21')),
#  ('Belize', Decimal('0.367313'), Decimal('2.26')),
#  ('Belize', Decimal('0.374693'), Decimal('2.29')),
#  ('Belize', Decimal('0.389095'), Decimal('2.42')),
#  ('Costa Rica', Decimal('4.895242'), Decimal('56.44')),
#  ('Costa Rica', Decimal('4.945205'), Decimal('58.85')),
#  ('Costa Rica', Decimal('4.993842'), Decimal('60.52')),
#  ('Costa Rica', Decimal('5.040734'), Decimal('62.42')),
#  ('Costa Rica', Decimal('5.084532'), Decimal('64.42')),
#  ('Costa Rica', Decimal('5.123105'), Decimal('62.16')),
#  ('El Salvador', Decimal('6.292731'), Decimal('24.56')),
#  ('Honduras', Decimal('9.294505'), Decimal('20.98')),
#  ('Honduras', Decimal('9.460798'), Decimal('21.72')),
#  ('Honduras', Decimal('9.626842'), Decimal('23.14')),
#  ('Honduras', Decimal('9.792850'), Decimal('24.07')),
#  ('Honduras', Decimal('9.958829'), Decimal('25.09')),
#  ('Honduras', Decimal('10.121763'), Decimal('23.83')),
#  ('Nicaragua', Decimal('6.572233'), Decimal('13.03')),
#  ('Panama', Decimal('4.096063'), Decimal('62.20')),
#  ('Panama', Decimal('4.165255'), Decimal('64.93')),
#  ('Panama', Decimal('4.232532'), Decimal('66.98')),
#  ('Panama', Decimal('4.294396'), Decimal('53.98')),
#  ('Argentina', Decimal('44.044811'), Decimal('643.63')),
#  ('Argentina', Decimal('44.494502'), Decimal('524.82')),
#  ('Argentina', Decimal('44.938712'), Decimal('447.75')),
#  ('Argentina', Decimal('45.376763'), Decimal('385.54')),
#  ('Brazil', Decimal('205.188205'), Decimal('1802.21')),
#  ('Brazil', Decimal('206.859578'), Decimal('1795.70')),
#  ('Brazil', Decimal('208.504960'), Decimal('2063.51')),
#  ('Brazil', Decimal('210.166592'), Decimal('1916.95')),
#  ('Brazil', Decimal('211.782878'), Decimal('1873.27')),
#  ('Brazil', Decimal('213.196304'), Decimal('1448.56')),
#  ('Chile', Decimal('17.870124'), Decimal('242.50')),
#  ('Chile', Decimal('18.083879'), Decimal('249.30')),
#  ('Chile', Decimal('18.368577'), Decimal('276.36')),
#  ('Chile', Decimal('18.701450'), Decimal('295.40')),
#  ('Chile', Decimal('19.039485'), Decimal('278.58')),
#  ('Chile', Decimal('19.300315'), Decimal('252.73')),
#  ('Colombia', Decimal('47.119728'), Decimal('293.48')),
#  ('Colombia', Decimal('47.625955'), Decimal('282.83')),
#  ('Colombia', Decimal('48.351671'), Decimal('311.88')),
#  ('Colombia', Decimal('49.276961'), Decimal('334.20')),
#  ('Colombia', Decimal('50.187406'), Decimal('323.11')),
#  ('Colombia', Decimal('50.930662'), Decimal('270.30')),
#  ('Ecuador', Decimal('17.588595'), Decimal('99.29')),
#  ('Guyana', Decimal('0.785514'), Decimal('4.79')),
#  ('Guyana', Decimal('0.798753'), Decimal('5.17')),
#  ('Paraguay', Decimal('6.266615'), Decimal('36.09')),
#  ('Paraguay', Decimal('6.443328'), Decimal('40.23')),
#  ('Paraguay', Decimal('6.530026'), Decimal('37.93')),
#  ('Paraguay', Decimal('6.618695'), Decimal('35.43')),
#  ('Peru', Decimal('33.304756'), Decimal('201.71')),
#  ('Suriname', Decimal('0.575475'), Decimal('5.13')),
#  ('Suriname', Decimal('0.581453'), Decimal('3.32')),
#  ('Uruguay', Decimal('3.402818'), Decimal('53.27')),
#  ('Uruguay', Decimal('3.413766'), Decimal('57.24')),
#  ('Uruguay', Decimal('3.422200'), Decimal('64.23')),
#  ('Uruguay', Decimal('3.427042'), Decimal('64.52')),
#  ('Uruguay', Decimal('3.428409'), Decimal('61.23')),
#  ('Uruguay', Decimal('3.429086'), Decimal('53.56')),
#  ('Algeria', Decimal('39.543154'), Decimal('165.98')),
#  ('Algeria', Decimal('40.339329'), Decimal('160.03')),
#  ('Algeria', Decimal('41.136546'), Decimal('170.10')),
#  ('Morocco', Decimal('34.680458'), Decimal('110.41')),
#  ('Morocco', Decimal('35.107264'), Decimal('111.57')),
#  ('Tunisia', Decimal('11.557779'), Decimal('45.78')),
#  ('Tunisia', Decimal('11.685667'), Decimal('44.36')),
#  ('Tunisia', Decimal('11.811443'), Decimal('42.16')),
#  ('Tunisia', Decimal('11.933041'), Decimal('42.69')),
#  ('Tunisia', Decimal('12.049314'), Decimal('41.91')),
#  ('Armenia', Decimal('2.878595'), Decimal('10.55')),
#  ('Armenia', Decimal('2.865835'), Decimal('10.55')),
#  ('Armenia', Decimal('2.851923'), Decimal('11.53')),
#  ('Armenia', Decimal('2.836557'), Decimal('12.46')),
#  ('Armenia', Decimal('2.820602'), Decimal('13.62')),
#  ('Armenia', Decimal('2.805608'), Decimal('12.64')),
#  ('Azerbaijan', Decimal('10.093121'), Decimal('42.69')),
#  ('Cyprus', Decimal('1.187280'), Decimal('19.91')),
#  ('Cyprus', Decimal('1.197881'), Decimal('21.05')),
#  ('Cyprus', Decimal('1.208523'), Decimal('22.95')),
#  ('Cyprus', Decimal('1.218831'), Decimal('25.60')),
#  ('Cyprus', Decimal('1.228836'), Decimal('25.94')),
#  ('Cyprus', Decimal('1.237537'), Decimal('25.01')),
#  ('Georgia', Decimal('3.725276'), Decimal('14.95')),
#  ('Georgia', Decimal('3.727505'), Decimal('15.14')),
#  ('Georgia', Decimal('3.728004'), Decimal('16.24')),
#  ('Georgia', Decimal('3.726549'), Decimal('17.60')),
#  ('Georgia', Decimal('3.720161'), Decimal('17.47')),
#  ('Georgia', Decimal('3.722716'), Decimal('15.84')),
#  ('Iraq', Decimal('38.697943'), Decimal('166.60')),
#  ('Iraq', Decimal('39.621162'), Decimal('187.22')),
#  ('Israel', Decimal('8.380100'), Decimal('303.41')),
#  ('Jordan', Decimal('9.494246'), Decimal('38.59')),
#  ('Jordan', Decimal('9.964656'), Decimal('39.89')),
#  ('Jordan', Decimal('10.215381'), Decimal('41.61')),
#  ('Jordan', Decimal('10.459865'), Decimal('43.37')),
#  ('Jordan', Decimal('10.698683'), Decimal('44.99')),
#  ('Jordan', Decimal('10.928721'), Decimal('44.18')),
#  ('Lebanon', Decimal('5.781907'), Decimal('51.95')),
#  ('Saudi Arabia', Decimal('32.749848'), Decimal('654.27')),
#  ('Saudi Arabia', Decimal('33.416270'), Decimal('644.94')),
#  ('Saudi Arabia', Decimal('34.193122'), Decimal('688.59')),
#  ('Saudi Arabia', Decimal('35.018133'), Decimal('816.58')),
#  ('Saudi Arabia', Decimal('35.827362'), Decimal('803.62')),
#  ('Saudi Arabia', Decimal('35.997107'), Decimal('703.37')),
#  ('Australia', Decimal('23.815995'), Decimal('1350.62')),
#  ('Australia', Decimal('24.190907'), Decimal('1206.54')),
#  ('Australia', Decimal('24.594202'), Decimal('1326.52')),
#  ('Australia', Decimal('24.966643'), Decimal('1428.29')),
#  ('Australia', Decimal('25.340217'), Decimal('1392.23')),
#  ('Australia', Decimal('25.655289'), Decimal('1326.90')),
#  ('New Zealand', Decimal('4.609400'), Decimal('178.06')),
#  ('New Zealand', Decimal('4.714100'), Decimal('188.84')),
#  ('New Caledonia', Decimal('0.270810'), Decimal('9.17')),
#  ('New Caledonia', Decimal('0.271170'), Decimal('9.85')),
#  ('New Caledonia', Decimal('0.271230'), Decimal('9.44')),
#  ('New Caledonia', Decimal('0.271130'), Decimal('9.44')),
#  ('Vanuatu', Decimal('0.304404'), Decimal('0.94')),
#  ('Guam', Decimal('0.167978'), Decimal('5.80')),
#  ('Guam', Decimal('0.168346'), Decimal('5.90')),
#  ('Kiribati', Decimal('0.116707'), Decimal('0.17')),
#  ('Kiribati', Decimal('0.124241'), Decimal('0.18')),
#  ('Kiribati', Decimal('0.126463'), Decimal('0.18')),
#  ('Marshall Islands', Decimal('0.044728'), Decimal('0.23')),
#  ('Samoa', Decimal('0.207630'), Decimal('0.88')),
#  ('Tuvalu', Decimal('0.010852'), Decimal('0.04')),
#  ('Tuvalu', Decimal('0.010828'), Decimal('0.05')),
#  ('Djibouti', Decimal('1.040233'), Decimal('2.76')),
#  ('Kenya', Decimal('50.951450'), Decimal('100.38')),
#  ('Mauritius', Decimal('1.262605'), Decimal('12.01')),
#  ('Mauritius', Decimal('1.263473'), Decimal('12.59')),
#  ('Mauritius', Decimal('1.264613'), Decimal('13.71')),
#  ('Mauritius', Decimal('1.265303'), Decimal('14.74')),
#  ('Mauritius', Decimal('1.265711'), Decimal('14.44')),
#  ('Mauritius', Decimal('1.265740'), Decimal('11.40')),
#  ('Rwanda', Decimal('12.230339'), Decimal('9.25')),
#  ('Rwanda', Decimal('12.531808'), Decimal('9.64')),
#  ('Rwanda', Decimal('12.835028'), Decimal('10.36')),
#  ('Rwanda', Decimal('13.146362'), Decimal('10.18')),
#  ('Somalia', Decimal('15.981300'), Decimal('6.49')),
#  ('Zambia', Decimal('17.298054'), Decimal('25.87')),
#  ('Zambia', Decimal('17.835893'), Decimal('26.31')),
#  ('Zambia', Decimal('18.380477'), Decimal('23.31')),
#  ('Zambia', Decimal('18.927715'), Decimal('18.11')),
#  ('Zimbabwe', Decimal('15.354608'), Decimal('21.83')),
#  ('Angola', Decimal('32.353588'), Decimal('69.31')),
#  ('Botswana', Decimal('2.499702'), Decimal('16.70')),
#  ('Botswana', Decimal('2.546402'), Decimal('14.93')),
#  ('Eswatini', Decimal('1.142524'), Decimal('3.82')),
#  ('Lesotho', Decimal('2.225702'), Decimal('2.45')),
#  ('Namibia', Decimal('2.323352'), Decimal('10.72')),
#  ('Namibia', Decimal('2.405680'), Decimal('13.68')),
#  ('South Africa', Decimal('55.876504'), Decimal('346.71')),
#  ('South Africa', Decimal('56.422274'), Decimal('323.59')),
#  ('South Africa', Decimal('56.641209'), Decimal('381.45')),
#  ('South Africa', Decimal('57.339635'), Decimal('404.16')),
#  ('South Africa', Decimal('58.087055'), Decimal('388.53')),
#  ('South Africa', Decimal('58.801927'), Decimal('337.62')),
#  ('Cabo Verde', Decimal('0.552166'), Decimal('1.60')),
#  ('Cabo Verde', Decimal('0.564954'), Decimal('1.77')),
#  ('Cabo Verde', Decimal('0.571202'), Decimal('1.97')),
#  ('Cabo Verde', Decimal('0.577030'), Decimal('1.98')),
#  ('Ghana', Decimal('28.870939'), Decimal('49.41')),
#  ('Guinea', Decimal('12.877539'), Decimal('13.44')),
#  ('Liberia', Decimal('4.796631'), Decimal('3.39')),
#  ('Mali', Decimal('18.112907'), Decimal('13.10')),
#  ('Mali', Decimal('19.311355'), Decimal('15.37')),
#  ('Mauritania', Decimal('4.160015'), Decimal('6.80')),
#  ('Mauritania', Decimal('4.383849'), Decimal('8.07')),
#  ('Niger', Decimal('21.737922'), Decimal('11.19')),
#  ('Nigeria', Decimal('188.666931'), Decimal('404.65')),
#  ('Nigeria', Decimal('193.495907'), Decimal('375.75')),
#  ('Nigeria', Decimal('203.304492'), Decimal('448.12')),
#  ('Senegal', Decimal('14.356181'), Decimal('17.77'))]

# %% [markdown]
# ### Combining the queries
#
# Using the query and the subquery, determine the average GDP and population for countries with unemployment rates above 5%. Group the results by `Country_name`.

# %%
# %%sql
# SELECT
#     Country_name,
#     Est_population_in_millions,
#     Est_gdp_in_billions
# FROM (SELECT
#  Country_name,
#  AVG(Est_population_in_millions) AS AVG_Population,
#  AVG(Est_gdp_in_billions) AS AVG_GDP
# FROM Access_to_basic_services
# WHERE
#     Pct_unemployment > 5
# AND Time_period = '2020'
# GROUP BY country_name)
# WHERE pct_unemployment >5
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# (pymysql.err.OperationalError) (1248, 'Every derived table must have its own alias')
# [SQL: SELECT
#     Country_name,
#     Est_population_in_millions,
#     Est_gdp_in_billions
# FROM (SELECT
#  Country_name,
#  AVG(Est_population_in_millions) AS AVG_Population,
#  AVG(Est_gdp_in_billions) AS AVG_GDP
# FROM Access_to_basic_services
# WHERE
#     Pct_unemployment > 5
# AND Time_period = '2020'
# GROUP BY country_name)
# WHERE pct_unemployment >5]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### Creating the subquery

# %%
# %%sql
#
# SELECT
#     Country_name,
#     Est_gdp_in_billions,
#     Est_population_in_millions
# FROM
#     Economic_Indicators
# WHERE
#     Pct_unemployment > 5
#     AND Time_period = 2020;

# %% [markdown]
# This table simply filters the `Economic_Indicators` table to only display countries with unemployment > 5. This is the input table the main query will use.

# %% [markdown]
# ### Creating the main query

# %%
# %%sql
#
# SELECT
#     Country_name,
#     AVG(Est_gdp_in_billions) AS Avg_GDP,
#     AVG(Est_population_in_millions) AS Avg_Population
# FROM
#     Economic_Indicators
# GROUP BY
#     Country_name;

# %% [markdown]
# Note that this query calculates the averages for **all** years, and for **all** countries.

# %% [markdown]
# ### Combining the queries

# %%
# %%sql
#
# SELECT
#     Country_name,
#     AVG(Est_gdp_in_billions) AS Avg_GDP,
#     AVG(Est_population_in_millions) AS Avg_Population
# FROM
#     (SELECT
#         Country_name,
#         Est_gdp_in_billions,
#         Est_population_in_millions
#     FROM
#         Economic_Indicators
#     WHERE
#         Pct_unemployment > 5
#         AND Time_period = 2020) AS FilteredCountries
# GROUP BY
#     Country_name;

# %% [markdown]
# Using the subquery filters the data first into a derived table, which the main query uses to aggregate with.

# %% [markdown]
# ## Summary

# %% [markdown]
# In this lesson, we used a subquery to determine the average GDP and populations of countries where the unemployment rate is above 5%. We made use of the `FROM` clause. In essence, the subquery in the `FROM` clause can be thought of as creating an intermediate or derived table for the main query to operate upon, even if this table exists only for the duration of the query execution.

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/refs/heads/master/ALX_banners/ALX_Navy.png"  style="width:100px"  ;/>
# </div>
