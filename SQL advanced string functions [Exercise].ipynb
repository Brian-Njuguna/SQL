# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img
#  src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/alx-courses/aice/assets/Content_page_banner_blue_dots.png"
#  alt="ALX Content Header"
#  class="full-width-image"
# />
# </div>

# %% [markdown]
# # SQL advanced string functions

# %% [markdown]
# In this exercise, we will use the skills we have learned so far to solve complex problems that involve string manipulation and handling. Ensure that you have downloaded the database file, Northwind.db.

# %% [markdown]
# ## Learning objectives
#
# In this train, we will:
# - Understand how to apply  SQL functions for data type conversion, null value handling, and string manipulation to solve complex problems.

# %% [markdown]
# First, let's load our database:

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook.
# %load_ext sql

# %%
# Load the Northwind database stored in your local machine. 
# Make sure the file is saved in the same folder as this notebook.
# %sql sqlite:///Northwind.db

# %% [markdown]
# Here is a view of all of our tables in the database:
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/Northwind_ERD.png"  style="width:70%";/>
# <br>
# <br>
#     <em>Figure 1: Northwind database ERD</em>
# </div>

# %% [markdown]
# ## Exercise

# %% [markdown]
# ### 1. Convert data type
#
# Given the `Employees` table, write a SQL query to convert the salary of all employees from integer to string data type.

# %%
# %%sql
# SELECT
# CAST(Salary AS VARCHAR) AS salary_str
# FROM Employees
# Out:
#  * sqlite:///Northwind.db
# Done.
# [('2954.55',),
#  ('2254.49',),
#  ('3119.15',),
#  ('1861.08',),
#  ('1744.21',),
#  ('2004.07',),
#  ('1991.55',),
#  ('2100.5',),
#  ('2333.33',)]

# %% [markdown]
# ### 2. Trim strings
#
# In the `Orders` table, some of the `ShipName` entries have leading and trailing white spaces. Write a SQL query to trim these white spaces.

# %%
# %%sql
# SELECT
# ShipName,
# LENGTH(ShipName)AS length,
# TRIM(LENGTH(ShipName))AS New_Length
# FROM Orders
# Out:
#  * sqlite:///Northwind.db
# Done.
# [('Vins et alcools Chevalier', 25, '25'),
#  ('Toms Spezialitten', 17, '17'),
#  ('Hanari Carnes', 13, '13'),
#  ('Victuailles en stock', 20, '20'),
#  ('Suprmes dlices', 14, '14'),
#  ('Hanari Carnes', 13, '13'),
#  ('Chop-suey Chinese', 17, '17'),
#  ('Richter Supermarkt', 18, '18'),
#  ('Wellington Importadora', 22, '22'),
#  ('HILARION-Abastos', 16, '16'),
#  ('Ernst Handel', 12, '12'),
#  ('Centro comercial Moctezuma', 26, '26'),
#  ('Ottilies Kseladen', 17, '17'),
#  ('Que Delcia', 10, '10'),
#  ('Rattlesnake Canyon Grocery', 26, '26'),
#  ('Ernst Handel', 12, '12'),
#  ('Folk och f HB', 13, '13'),
#  ('Blondel pre et fils', 19, '19'),
#  ('Wartian Herkku', 14, '14'),
#  ('Frankenversand', 14, '14'),
#  ('GROSELLA-Restaurante', 20, '20'),
#  ('White Clover Markets', 20, '20'),
#  ('Wartian Herkku', 14, '14'),
#  ('Split Rail Beer & Ale', 21, '21'),
#  ('Rattlesnake Canyon Grocery', 26, '26'),
#  ('QUICK-Stop', 10, '10'),
#  ('Vins et alcools Chevalier', 25, '25'),
#  ('Magazzini Alimentari Riuniti', 28, '28'),
#  ('Tortuga Restaurante', 19, '19'),
#  ('Morgenstern Gesundkost', 22, '22'),
#  ('Berglunds snabbkp', 17, '17'),
#  ('Lehmanns Marktstand', 19, '19'),
#  ('Berglunds snabbkp', 17, '17'),
#  ('Romero y tomillo', 16, '16'),
#  ('Romero y tomillo', 16, '16'),
#  ('LILA-Supermercado', 17, '17'),
#  ('Lehmanns Marktstand', 19, '19'),
#  ('QUICK-Stop', 10, '10'),
#  ('QUICK-Stop', 10, '10'),
#  ('Ricardo Adocicados', 18, '18'),
#  ('Reggiani Caseifici', 18, '18'),
#  ('B-s Beverages', 13, '13'),
#  ('Comrcio Mineiro', 15, '15'),
#  ('Que Delcia', 10, '10'),
#  ('Tradiao Hipermercados', 21, '21'),
#  ('Tortuga Restaurante', 19, '19'),
#  ('Rattlesnake Canyon Grocery', 26, '26'),
#  ('Vins et alcools Chevalier', 25, '25'),
#  ('LILA-Supermercado', 17, '17'),
#  ('Blondel pre et fils', 19, '19'),
#  ('Hungry Owl All-Night Grocers', 28, '28'),
#  ('Ricardo Adocicados', 18, '18'),
#  ('Magazzini Alimentari Riuniti', 28, '28'),
#  ('Die Wandernde Kuh', 17, '17'),
#  ('Suprmes dlices', 14, '14'),
#  ('Godos Cocina Tpica', 18, '18'),
#  ('Tortuga Restaurante', 19, '19'),
#  ('Old World Delicatessen', 22, '22'),
#  ('Romero y tomillo', 16, '16'),
#  ('Lonesome Pine Restaurant', 24, '24'),
#  ('Ana Trujillo Emparedados y helados', 34, '34'),
#  ('Hungry Owl All-Night Grocers', 28, '28'),
#  ('The Big Cheese', 14, '14'),
#  ('Du monde entier', 15, '15'),
#  ('Die Wandernde Kuh', 17, '17'),
#  ('QUICK-Stop', 10, '10'),
#  ('Rattlesnake Canyon Grocery', 26, '26'),
#  ('Island Trading', 14, '14'),
#  ('Rattlesnake Canyon Grocery', 26, '26'),
#  ('Lonesome Pine Restaurant', 24, '24'),
#  ('Island Trading', 14, '14'),
#  ('Tortuga Restaurante', 19, '19'),
#  ('Wartian Herkku', 14, '14'),
#  ('Island Trading', 14, '14'),
#  ('Pericles Comidas clsicas', 24, '24'),
#  ('Kniglich Essen', 14, '14'),
#  ('Save-a-lot Markets', 18, '18'),
#  ('Kniglich Essen', 14, '14'),
#  ('Blido Comidas preparadas', 24, '24'),
#  ('Folk och f HB', 13, '13'),
#  ('Furia Bacalhau e Frutos do Mar', 30, '30'),
#  ('Split Rail Beer & Ale', 21, '21'),
#  ('LILA-Supermercado', 17, '17'),
#  ('Bon app-', 8, '8'),
#  ('Mre Paillarde', 13, '13'),
#  ('Wartian Herkku', 14, '14'),
#  ('Victuailles en stock', 20, '20'),
#  ('Hungry Owl All-Night Grocers', 28, '28'),
#  ('Princesa Isabel Vinhos', 22, '22'),
#  ('Frankenversand', 14, '14'),
#  ('Old World Delicatessen', 22, '22'),
#  ('Mre Paillarde', 13, '13'),
#  ('Bon app-', 8, '8'),
#  ('Simons bistro', 13, '13'),
#  ('Frankenversand', 14, '14'),
#  ('Lehmanns Marktstand', 19, '19'),
#  ('White Clover Markets', 20, '20'),
#  ('QUICK-Stop', 10, '10'),
#  ('Rattlesnake Canyon Grocery', 26, '26'),
#  ('Familia Arquibaldo', 18, '18'),
#  ('Die Wandernde Kuh', 17, '17'),
#  ('Split Rail Beer & Ale', 21, '21'),
#  ('La maison d-Asie', 16, '16'),
#  ('Ernst Handel', 12, '12'),
#  ('Furia Bacalhau e Frutos do Mar', 30, '30'),
#  ('Piccolo und mehr', 16, '16'),
#  ('Pericles Comidas clsicas', 24, '24'),
#  ('Around the Horn', 15, '15'),
#  ('Die Wandernde Kuh', 17, '17'),
#  ('LILA-Supermercado', 17, '17'),
#  ('La maison d-Asie', 16, '16'),
#  ('Seven Seas Imports', 18, '18'),
#  ('Blondel pre et fils', 19, '19'),
#  ('QUICK-Stop', 10, '10'),
#  ('Bon app-', 8, '8'),
#  ('Drachenblut Delikatessen', 24, '24'),
#  ('Eastern Connection', 18, '18'),
#  ('Antonio Moreno Taquera', 22, '22'),
#  ('Galera del gastronmo', 20, '20'),
#  ('Vaffeljernet', 12, '12'),
#  ('Ernst Handel', 12, '12'),
#  ('Split Rail Beer & Ale', 21, '21'),
#  ('Chop-suey Chinese', 17, '17'),
#  ('La maison d-Asie', 16, '16'),
#  ('Queen Cozinha', 13, '13'),
#  ('Hungry Owl All-Night Grocers', 28, '28'),
#  ('Wolski Zajazd', 13, '13'),
#  ('Hungry Coyote Import Store', 26, '26'),
#  ('Mre Paillarde', 13, '13'),
#  ('Seven Seas Imports', 18, '18'),
#  ('Folk och f HB', 13, '13'),
#  ('Que Delcia', 10, '10'),
#  ('Hungry Owl All-Night Grocers', 28, '28'),
#  ('LILA-Supermercado', 17, '17'),
#  ('Ernst Handel', 12, '12'),
#  ('Around the Horn', 15, '15'),
#  ('Berglunds snabbkp', 17, '17'),
#  ('Split Rail Beer & Ale', 21, '21'),
#  ('Familia Arquibaldo', 18, '18'),
#  ('Sant Gourmet', 12, '12'),
#  ('Seven Seas Imports', 18, '18'),
#  ('Bottom-Dollar Markets', 21, '21'),
#  ('Ernst Handel', 12, '12'),
#  ('Drachenblut Delikatessen', 24, '24'),
#  ('Piccolo und mehr', 16, '16'),
#  ('Save-a-lot Markets', 18, '18'),
#  ('Hungry Coyote Import Store', 26, '26'),
#  ('HILARION-Abastos', 16, '16'),
#  ('Frankenversand', 14, '14'),
#  ('Princesa Isabel Vinhos', 22, '22'),
#  ('Save-a-lot Markets', 18, '18'),
#  ('Vaffeljernet', 12, '12'),
#  ('Eastern Connection', 18, '18'),
#  ('Rattlesnake Canyon Grocery', 26, '26'),
#  ('Ernst Handel', 12, '12'),
#  ('Ernst Handel', 12, '12'),
#  ('Magazzini Alimentari Riuniti', 28, '28'),
#  ('LINO-Delicateses', 16, '16'),
#  ('Queen Cozinha', 13, '13'),
#  ('Ottilies Kseladen', 17, '17'),
#  ('Folies gourmandes', 17, '17'),
#  ('Ocano Atlntico Ltda.', 20, '20'),
#  ('Bottom-Dollar Markets', 21, '21'),
#  ('Bottom-Dollar Markets', 21, '21'),
#  ('Wartian Herkku', 14, '14'),
#  ('La maison d-Asie', 16, '16'),
#  ('Familia Arquibaldo', 18, '18'),
#  ('Hungry Coyote Import Store', 26, '26'),
#  ('Wartian Herkku', 14, '14'),
#  ('Simons bistro', 13, '13'),
#  ('QUICK-Stop', 10, '10'),
#  ('Richter Supermarkt', 18, '18'),
#  ('Wellington Importadora', 22, '22'),
#  ('Que Delcia', 10, '10'),
#  ('Franchi S.p.A.', 14, '14'),
#  ('Gourmet Lanchonetes', 19, '19'),
#  ('Mre Paillarde', 13, '13'),
#  ('La maison d-Asie', 16, '16'),
#  ('Galera del gastronmo', 20, '20'),
#  ('Piccolo und mehr', 16, '16'),
#  ('Reggiani Caseifici', 18, '18'),
#  ('Hungry Owl All-Night Grocers', 28, '28'),
#  ('Ernst Handel', 12, '12'),
#  ('Bottom-Dollar Markets', 21, '21'),
#  ('Split Rail Beer & Ale', 21, '21'),
#  ('Princesa Isabel Vinhos', 22, '22'),
#  ('Folk och f HB', 13, '13'),
#  ('Consolidated Holdings', 21, '21'),
#  ('Blondel pre et fils', 19, '19'),
#  ('Wartian Herkku', 14, '14'),
#  ('Toms Spezialitten', 17, '17'),
#  ('Mre Paillarde', 13, '13'),
#  ('Save-a-lot Markets', 18, '18'),
#  ('Old World Delicatessen', 22, '22'),
#  ('Ernst Handel', 12, '12'),
#  ('Reggiani Caseifici', 18, '18'),
#  ('Berglunds snabbkp', 17, '17'),
#  ('Berglunds snabbkp', 17, '17'),
#  ('Toms Spezialitten', 17, '17'),
#  ('Ricardo Adocicados', 18, '18'),
#  ('Rancho grande', 13, '13'),
#  ('Blondel pre et fils', 19, '19'),
#  ('Victuailles en stock', 20, '20'),
#  ('QUICK-Stop', 10, '10'),
#  ('Save-a-lot Markets', 18, '18'),
#  ('Around the Horn', 15, '15'),
#  ('La maison d-Asie', 16, '16'),
#  ('Wartian Herkku', 14, '14'),
#  ('Kniglich Essen', 14, '14'),
#  ('Kniglich Essen', 14, '14'),
#  ('Suprmes dlices', 14, '14'),
#  ('Victuailles en stock', 20, '20'),
#  ('Folk och f HB', 13, '13'),
#  ('LILA-Supermercado', 17, '17'),
#  ('Consolidated Holdings', 21, '21'),
#  ('Suprmes dlices', 14, '14'),
#  ('Furia Bacalhau e Frutos do Mar', 30, '30'),
#  ('Vaffeljernet', 12, '12'),
#  ('Comrcio Mineiro', 15, '15'),
#  ('Magazzini Alimentari Riuniti', 28, '28'),
#  ('Kniglich Essen', 14, '14'),
#  ('White Clover Markets', 20, '20'),
#  ('Bon app-', 8, '8'),
#  ('B-s Beverages', 13, '13'),
#  ('Seven Seas Imports', 18, '18'),
#  ('Island Trading', 14, '14'),
#  ('Pericles Comidas clsicas', 24, '24'),
#  ('Suprmes dlices', 14, '14'),
#  ('HILARION-Abastos', 16, '16'),
#  ('Princesa Isabel Vinhos', 22, '22'),
#  ('Victuailles en stock', 20, '20'),
#  ('Rattlesnake Canyon Grocery', 26, '26'),
#  ('Folies gourmandes', 17, '17'),
#  ('Ricardo Adocicados', 18, '18'),
#  ('Lazy K Kountry Store', 20, '20'),
#  ('White Clover Markets', 20, '20'),
#  ('B-s Beverages', 13, '13'),
#  ('LINO-Delicateses', 16, '16'),
#  ('HILARION-Abastos', 16, '16'),
#  ('Queen Cozinha', 13, '13'),
#  ('Frankenversand', 14, '14'),
#  ('Piccolo und mehr', 16, '16'),
#  ('HILARION-Abastos', 16, '16'),
#  ('Furia Bacalhau e Frutos do Mar', 30, '30'),
#  ('Bottom-Dollar Markets', 21, '21'),
#  ('La maison d-Asie', 16, '16'),
#  ('Comrcio Mineiro', 15, '15'),
#  ('Laughing Bacchus Wine Cellars', 29, '29'),
#  ('Tradiao Hipermercados', 21, '21'),
#  ('Lehmanns Marktstand', 19, '19'),
#  ('HILARION-Abastos', 16, '16'),
#  ('LILA-Supermercado', 17, '17'),
#  ('La maison d-Asie', 16, '16'),
#  ('Blauer See Delikatessen', 23, '23'),
#  ('Pericles Comidas clsicas', 24, '24'),
#  ('Hungry Owl All-Night Grocers', 28, '28'),
#  ('White Clover Markets', 20, '20'),
#  ('Mre Paillarde', 13, '13'),
#  ('Kniglich Essen', 14, '14'),
#  ('Antonio Moreno Taquera', 22, '22'),
#  ('Ottilies Kseladen', 17, '17'),
#  ('Blauer See Delikatessen', 23, '23'),
#  ('Save-a-lot Markets', 18, '18'),
#  ('Bon app-', 8, '8'),
#  ('Familia Arquibaldo', 18, '18'),
#  ('Die Wandernde Kuh', 17, '17'),
#  ('Ernst Handel', 12, '12'),
#  ('QUICK-Stop', 10, '10'),
#  ('Hungry Owl All-Night Grocers', 28, '28'),
#  ('North/South', 11, '11'),
#  ('Tortuga Restaurante', 19, '19'),
#  ('Chop-suey Chinese', 17, '17'),
#  ('Sant Gourmet', 12, '12'),
#  ('Cactus Comidas para llevar', 26, '26'),
#  ('Lehmanns Marktstand', 19, '19'),
#  ('Seven Seas Imports', 18, '18'),
#  ('Berglunds snabbkp', 17, '17'),
#  ('Bon app-', 8, '8'),
#  ('Wartian Herkku', 14, '14'),
#  ('QUICK-Stop', 10, '10'),
#  ('Great Lakes Food Market', 23, '23'),
#  ('Maison Dewey', 12, '12'),
#  ('Piccolo und mehr', 16, '16'),
#  ('Ocano Atlntico Ltda.', 20, '20'),
#  ('Eastern Connection', 18, '18'),
#  ('Folk och f HB', 13, '13'),
#  ('Lehmanns Marktstand', 19, '19'),
#  ('Antonio Moreno Taquera', 22, '22'),
#  ('Lehmanns Marktstand', 19, '19'),
#  ('Richter Supermarkt', 18, '18'),
#  ('B-s Beverages', 13, '13'),
#  ('B-s Beverages', 13, '13'),
#  ('QUICK-Stop', 10, '10'),
#  ('Hanari Carnes', 13, '13'),
#  ('Kniglich Essen', 14, '14'),
#  ('LILA-Supermercado', 17, '17'),
#  ('Lonesome Pine Restaurant', 24, '24'),
#  ('Lazy K Kountry Store', 20, '20'),
#  ('Victuailles en stock', 20, '20'),
#  ('Seven Seas Imports', 18, '18'),
#  ('Toms Spezialitten', 17, '17'),
#  ('QUICK-Stop', 10, '10'),
#  ('Godos Cocina Tpica', 18, '18'),
#  ('Furia Bacalhau e Frutos do Mar', 30, '30'),
#  ('HILARION-Abastos', 16, '16'),
#  ('Wartian Herkku', 14, '14'),
#  ('Ottilies Kseladen', 17, '17'),
#  ('Save-a-lot Markets', 18, '18'),
#  ('Simons bistro', 13, '13'),
#  ('Lehmanns Marktstand', 19, '19'),
#  ('Around the Horn', 15, '15'),
#  ('Blondel pre et fils', 19, '19'),
#  ('Frankenversand', 14, '14'),
#  ('Folk och f HB', 13, '13'),
#  ('Reggiani Caseifici', 18, '18'),
#  ('Ricardo Adocicados', 18, '18'),
#  ('Rattlesnake Canyon Grocery', 26, '26'),
#  ('Mre Paillarde', 13, '13'),
#  ('Blondel pre et fils', 19, '19'),
#  ('Hungry Owl All-Night Grocers', 28, '28'),
#  ('Galera del gastronmo', 20, '20'),
#  ('Rattlesnake Canyon Grocery', 26, '26'),
#  ('Mre Paillarde', 13, '13'),
#  ('Ernst Handel', 12, '12'),
#  ('Berglunds snabbkp', 17, '17'),
#  ('Antonio Moreno Taquera', 22, '22'),
#  ('Trail-s Head Gourmet Provisioners', 33, '33'),
#  ('Morgenstern Gesundkost', 22, '22'),
#  ('Tortuga Restaurante', 19, '19'),
#  ('Trail-s Head Gourmet Provisioners', 33, '33'),
#  ('B-s Beverages', 13, '13'),
#  ('Let-s Stop N Shop', 17, '17'),
#  ('Ottilies Kseladen', 17, '17'),
#  ('Familia Arquibaldo', 18, '18'),
#  ('Blauer See Delikatessen', 23, '23'),
#  ('Wartian Herkku', 14, '14'),
#  ('Blondel pre et fils', 19, '19'),
#  ('Wellington Importadora', 22, '22'),
#  ('Reggiani Caseifici', 18, '18'),
#  ('Que Delcia', 10, '10'),
#  ('QUICK-Stop', 10, '10'),
#  ('Great Lakes Food Market', 23, '23'),
#  ('Mre Paillarde', 13, '13'),
#  ('Vaffeljernet', 12, '12'),
#  ('Lehmanns Marktstand', 19, '19'),
#  ('Lehmanns Marktstand', 19, '19'),
#  ('Old World Delicatessen', 22, '22'),
#  ('Ernst Handel', 12, '12'),
#  ('White Clover Markets', 20, '20'),
#  ('Piccolo und mehr', 16, '16'),
#  ('Rattlesnake Canyon Grocery', 26, '26'),
#  ('B-s Beverages', 13, '13'),
#  ('Hungry Coyote Import Store', 26, '26'),
#  ('HILARION-Abastos', 16, '16'),
#  ('Vaffeljernet', 12, '12'),
#  ('Save-a-lot Markets', 18, '18'),
#  ('Furia Bacalhau e Frutos do Mar', 30, '30'),
#  ('Mre Paillarde', 13, '13'),
#  ('Tradiao Hipermercados', 21, '21'),
#  ('Save-a-lot Markets', 18, '18'),
#  ('Toms Spezialitten', 17, '17'),
#  ('Du monde entier', 15, '15'),
#  ('La maison d-Asie', 16, '16'),
#  ('Wolski Zajazd', 13, '13'),
#  ('Save-a-lot Markets', 18, '18'),
#  ('HILARION-Abastos', 16, '16'),
#  ('Blauer See Delikatessen', 23, '23'),
#  ('Wilman Kala', 11, '11'),
#  ('Great Lakes Food Market', 23, '23'),
#  ('Great Lakes Food Market', 23, '23'),
#  ('Mre Paillarde', 13, '13'),
#  ('Mre Paillarde', 13, '13'),
#  ('Laughing Bacchus Wine Cellars', 29, '29'),
#  ('Island Trading', 14, '14'),
#  ('Ricardo Adocicados', 18, '18'),
#  ('Frankenversand', 14, '14'),
#  ('The Cracker Box', 15, '15'),
#  ('Ana Trujillo Emparedados y helados', 34, '34'),
#  ('Berglunds snabbkp', 17, '17'),
#  ('Save-a-lot Markets', 18, '18'),
#  ('Blondel pre et fils', 19, '19'),
#  ('Godos Cocina Tpica', 18, '18'),
#  ('Kniglich Essen', 14, '14'),
#  ('La maison d-Asie', 16, '16'),
#  ('Die Wandernde Kuh', 17, '17'),
#  ('Ernst Handel', 12, '12'),
#  ('Folies gourmandes', 17, '17'),
#  ('Magazzini Alimentari Riuniti', 28, '28'),
#  ('Wartian Herkku', 14, '14'),
#  ('Queen Cozinha', 13, '13'),
#  ('LINO-Delicateses', 16, '16'),
#  ('Sant Gourmet', 12, '12'),
#  ('Die Wandernde Kuh', 17, '17'),
#  ('HILARION-Abastos', 16, '16'),
#  ('Simons bistro', 13, '13'),
#  ('Alfreds Futterkiste', 19, '19'),
#  ('Wellington Importadora', 22, '22'),
#  ('Hanari Carnes', 13, '13'),
#  ('Hungry Owl All-Night Grocers', 28, '28'),
#  ('Que Delcia', 10, '10'),
#  ('Ricardo Adocicados', 18, '18'),
#  ('Maison Dewey', 12, '12'),
#  ('Familia Arquibaldo', 18, '18'),
#  ('Die Wandernde Kuh', 17, '17'),
#  ('Gourmet Lanchonetes', 19, '19'),
#  ('Frankenversand', 14, '14'),
#  ('Berglunds snabbkp', 17, '17'),
#  ('Reggiani Caseifici', 18, '18'),
#  ('Great Lakes Food Market', 23, '23'),
#  ('Save-a-lot Markets', 18, '18'),
#  ('QUICK-Stop', 10, '10'),
#  ('Queen Cozinha', 13, '13'),
#  ('Hungry Coyote Import Store', 26, '26'),
#  ('Hungry Owl All-Night Grocers', 28, '28'),
#  ('Lonesome Pine Restaurant', 24, '24'),
#  ('Bon app-', 8, '8'),
#  ('Furia Bacalhau e Frutos do Mar', 30, '30'),
#  ('Lonesome Pine Restaurant', 24, '24'),
#  ('Richter Supermarkt', 18, '18'),
#  ('Ernst Handel', 12, '12'),
#  ('Die Wandernde Kuh', 17, '17'),
#  ('Simons bistro', 13, '13'),
#  ('Frankenversand', 14, '14'),
#  ('France restauration', 19, '19'),
#  ('Berglunds snabbkp', 17, '17'),
#  ('Wilman Kala', 11, '11'),
#  ('Island Trading', 14, '14'),
#  ('Frankenversand', 14, '14'),
#  ('Tortuga Restaurante', 19, '19'),
#  ('Antonio Moreno Taquera', 22, '22'),
#  ('Save-a-lot Markets', 18, '18'),
#  ('Blondel pre et fils', 19, '19'),
#  ('Old World Delicatessen', 22, '22'),
#  ('Great Lakes Food Market', 23, '23'),
#  ('Antonio Moreno Taquera', 22, '22'),
#  ('Du monde entier', 15, '15'),
#  ('Ottilies Kseladen', 17, '17'),
#  ('Gourmet Lanchonetes', 19, '19'),
#  ('Piccolo und mehr', 16, '16'),
#  ('Hungry Owl All-Night Grocers', 28, '28'),
#  ('Vaffeljernet', 12, '12'),
#  ('Berglunds snabbkp', 17, '17'),
#  ('Hanari Carnes', 13, '13'),
#  ('QUICK-Stop', 10, '10'),
#  ('Alfred-s Futterkiste', 20, '20'),
#  ('White Clover Markets', 20, '20'),
#  ('QUICK-Stop', 10, '10'),
#  ('Wilman Kala', 11, '11'),
#  ('White Clover Markets', 20, '20'),
#  ('LINO-Delicateses', 16, '16'),
#  ('Ernst Handel', 12, '12'),
#  ('Morgenstern Gesundkost', 22, '22'),
#  ('Save-a-lot Markets', 18, '18'),
#  ('Hungry Owl All-Night Grocers', 28, '28'),
#  ('Alfred-s Futterkiste', 20, '20'),
#  ('Folk och f HB', 13, '13'),
#  ('Queen Cozinha', 13, '13'),
#  ('HILARION-Abastos', 16, '16'),
#  ('Old World Delicatessen', 22, '22'),
#  ('Around the Horn', 15, '15'),
#  ('The Big Cheese', 14, '14'),
#  ('Gourmet Lanchonetes', 19, '19'),
#  ('Franchi S.p.A.', 14, '14'),
#  ('Save-a-lot Markets', 18, '18'),
#  ('Hungry Owl All-Night Grocers', 28, '28'),
#  ('Save-a-lot Markets', 18, '18'),
#  ('Save-a-lot Markets', 18, '18'),
#  ('Bon app-', 8, '8'),
#  ('Rancho grande', 13, '13'),
#  ('Frankenversand', 14, '14'),
#  ('Kniglich Essen', 14, '14'),
#  ('Let-s Stop N Shop', 17, '17'),
#  ('Que Delcia', 10, '10'),
#  ('QUICK-Stop', 10, '10'),
#  ('Save-a-lot Markets', 18, '18'),
#  ('White Clover Markets', 20, '20'),
#  ('Mre Paillarde', 13, '13'),
#  ('Familia Arquibaldo', 18, '18'),
#  ('Eastern Connection', 18, '18'),
#  ('Reggiani Caseifici', 18, '18'),
#  ('Queen Cozinha', 13, '13'),
#  ('LINO-Delicateses', 16, '16'),
#  ('Bon app-', 8, '8'),
#  ('Chop-suey Chinese', 17, '17'),
#  ('Bon app-', 8, '8'),
#  ('Berglunds snabbkp', 17, '17'),
#  ('Gourmet Lanchonetes', 19, '19'),
#  ('Let-s Stop N Shop', 17, '17'),
#  ('Hungry Owl All-Night Grocers', 28, '28'),
#  ('Vins et alcools Chevalier', 25, '25'),
#  ('Spcialits du monde', 18, '18'),
#  ('Vins et alcools Chevalier', 25, '25'),
#  ('White Clover Markets', 20, '20'),
#  ('Around the Horn', 15, '15'),
#  ('Bottom-Dollar Markets', 21, '21'),
#  ('Around the Horn', 15, '15'),
#  ('Vaffeljernet', 12, '12'),
#  ('QUICK-Stop', 10, '10'),
#  ('Chop-suey Chinese', 17, '17'),
#  ('Piccolo und mehr', 16, '16'),
#  ('Save-a-lot Markets', 18, '18'),
#  ('Island Trading', 14, '14'),
#  ('Wartian Herkku', 14, '14'),
#  ('Richter Supermarkt', 18, '18'),
#  ('North/South', 11, '11'),
#  ('Franchi S.p.A.', 14, '14'),
#  ('Magazzini Alimentari Riuniti', 28, '28'),
#  ('Bon app-', 8, '8'),
#  ('Split Rail Beer & Ale', 21, '21'),
#  ('Save-a-lot Markets', 18, '18'),
#  ('Richter Supermarkt', 18, '18'),
#  ('Ana Trujillo Emparedados y helados', 34, '34'),
#  ('Maison Dewey', 12, '12'),
#  ('Rattlesnake Canyon Grocery', 26, '26'),
#  ('Folk och f HB', 13, '13'),
#  ('Folies gourmandes', 17, '17'),
#  ('Ernst Handel', 12, '12'),
#  ('QUICK-Stop', 10, '10'),
#  ('Ottilies Kseladen', 17, '17'),
#  ('Suprmes dlices', 14, '14'),
#  ('Around the Horn', 15, '15'),
#  ('Vaffeljernet', 12, '12'),
#  ('Hanari Carnes', 13, '13'),
#  ('Ernst Handel', 12, '12'),
#  ('Lehmanns Marktstand', 19, '19'),
#  ('Ernst Handel', 12, '12'),
#  ('Folk och f HB', 13, '13'),
#  ('The Cracker Box', 15, '15'),
#  ('Ernst Handel', 12, '12'),
#  ('Gourmet Lanchonetes', 19, '19'),
#  ('Berglunds snabbkp', 17, '17'),
#  ('Morgenstern Gesundkost', 22, '22'),
#  ('LILA-Supermercado', 17, '17'),
#  ('Wartian Herkku', 14, '14'),
#  ('Cactus Comidas para llevar', 26, '26'),
#  ('Hanari Carnes', 13, '13'),
#  ('Magazzini Alimentari Riuniti', 28, '28'),
#  ('GROSELLA-Restaurante', 20, '20'),
#  ('Queen Cozinha', 13, '13'),
#  ('La maison d-Asie', 16, '16'),
#  ('QUICK-Stop', 10, '10'),
#  ('Folies gourmandes', 17, '17'),
#  ('Gourmet Lanchonetes', 19, '19'),
#  ('Frankenversand', 14, '14'),
#  ('Wolski Zajazd', 13, '13'),
#  ('Around the Horn', 15, '15'),
#  ('Que Delcia', 10, '10'),
#  ('Ernst Handel', 12, '12'),
#  ('HILARION-Abastos', 16, '16'),
#  ('Drachenblut Delikatessen', 24, '24'),
#  ('Island Trading', 14, '14'),
#  ('Kniglich Essen', 14, '14'),
#  ('Seven Seas Imports', 18, '18'),
#  ('Blido Comidas preparadas', 24, '24'),
#  ('Simons bistro', 13, '13'),
#  ('Wellington Importadora', 22, '22'),
#  ('Seven Seas Imports', 18, '18'),
#  ('The Big Cheese', 14, '14'),
#  ('Victuailles en stock', 20, '20'),
#  ('Franchi S.p.A.', 14, '14'),
#  ('Old World Delicatessen', 22, '22'),
#  ('Wellington Importadora', 22, '22'),
#  ('Laughing Bacchus Wine Cellars', 29, '29'),
#  ('LINO-Delicateses', 16, '16'),
#  ('Reggiani Caseifici', 18, '18'),
#  ('Ricardo Adocicados', 18, '18'),
#  ('Victuailles en stock', 20, '20'),
#  ('Save-a-lot Markets', 18, '18'),
#  ('Great Lakes Food Market', 23, '23'),
#  ('Kniglich Essen', 14, '14'),
#  ('Magazzini Alimentari Riuniti', 28, '28'),
#  ('Cactus Comidas para llevar', 26, '26'),
#  ('Rattlesnake Canyon Grocery', 26, '26'),
#  ('Split Rail Beer & Ale', 21, '21'),
#  ('Trail-s Head Gourmet Provisioners', 33, '33'),
#  ('LILA-Supermercado', 17, '17'),
#  ('Folk och f HB', 13, '13'),
#  ('Drachenblut Delikatessen', 24, '24'),
#  ('Blondel pre et fils', 19, '19'),
#  ('Bon app-', 8, '8'),
#  ('Rancho grande', 13, '13'),
#  ('Island Trading', 14, '14'),
#  ('Tradiao Hipermercados', 21, '21'),
#  ('Sant Gourmet', 12, '12'),
#  ('La maison d-Asie', 16, '16'),
#  ('Ottilies Kseladen', 17, '17'),
#  ('Tradiao Hipermercados', 21, '21'),
#  ('Alfred-s Futterkiste', 20, '20'),
#  ('Ernst Handel', 12, '12'),
#  ('Berglunds snabbkp', 17, '17'),
#  ('LINO-Delicateses', 16, '16'),
#  ('Tradiao Hipermercados', 21, '21'),
#  ('LINO-Delicateses', 16, '16'),
#  ('Suprmes dlices', 14, '14'),
#  ('Tortuga Restaurante', 19, '19'),
#  ('Victuailles en stock', 20, '20'),
#  ('Piccolo und mehr', 16, '16'),
#  ('QUICK-Stop', 10, '10'),
#  ('Suprmes dlices', 14, '14'),
#  ('Save-a-lot Markets', 18, '18'),
#  ('Consolidated Holdings', 21, '21'),
#  ('Kniglich Essen', 14, '14'),
#  ('Victuailles en stock', 20, '20'),
#  ('Ricardo Adocicados', 18, '18'),
#  ('Rattlesnake Canyon Grocery', 26, '26'),
#  ('Blauer See Delikatessen', 23, '23'),
#  ('Ernst Handel', 12, '12'),
#  ('Old World Delicatessen', 22, '22'),
#  ('Antonio Moreno Taquera', 22, '22'),
#  ('Berglunds snabbkp', 17, '17'),
#  ('La corne d-abondance', 20, '20'),
#  ('Frankenversand', 14, '14'),
#  ('France restauration', 19, '19'),
#  ('White Clover Markets', 20, '20'),
#  ('Lehmanns Marktstand', 19, '19'),
#  ('HILARION-Abastos', 16, '16'),
#  ('Around the Horn', 15, '15'),
#  ('QUICK-Stop', 10, '10'),
#  ('Berglunds snabbkp', 17, '17'),
#  ('Lonesome Pine Restaurant', 24, '24'),
#  ('Queen Cozinha', 13, '13'),
#  ('Seven Seas Imports', 18, '18'),
#  ('Wolski Zajazd', 13, '13'),
#  ('Bon app-', 8, '8'),
#  ('Godos Cocina Tpica', 18, '18'),
#  ('Wilman Kala', 11, '11'),
#  ('Godos Cocina Tpica', 18, '18'),
#  ('Berglunds snabbkp', 17, '17'),
#  ('Bon app-', 8, '8'),
#  ('Ricardo Adocicados', 18, '18'),
#  ('QUICK-Stop', 10, '10'),
#  ('Wilman Kala', 11, '11'),
#  ('Folk och f HB', 13, '13'),
#  ('Cactus Comidas para llevar', 26, '26'),
#  ('Save-a-lot Markets', 18, '18'),
#  ('Lonesome Pine Restaurant', 24, '24'),
#  ('Let-s Stop N Shop', 17, '17'),
#  ('Suprmes dlices', 14, '14'),
#  ('Hanari Carnes', 13, '13'),
#  ('Galera del gastronmo', 20, '20'),
#  ('Godos Cocina Tpica', 18, '18'),
#  ('Rattlesnake Canyon Grocery', 26, '26'),
#  ('Du monde entier', 15, '15'),
#  ('Lehmanns Marktstand', 19, '19'),
#  ('Maison Dewey', 12, '12'),
#  ('Kniglich Essen', 14, '14'),
#  ('Save-a-lot Markets', 18, '18'),
#  ('Ernst Handel', 12, '12'),
#  ('Maison Dewey', 12, '12'),
#  ('Hungry Owl All-Night Grocers', 28, '28'),
#  ('Ocano Atlntico Ltda.', 20, '20'),
#  ('LILA-Supermercado', 17, '17'),
#  ('Wellington Importadora', 22, '22'),
#  ('HILARION-Abastos', 16, '16'),
#  ('Folk och f HB', 13, '13'),
#  ('Hanari Carnes', 13, '13'),
#  ('White Clover Markets', 20, '20'),
#  ('Wellington Importadora', 22, '22'),
#  ('Wolski Zajazd', 13, '13'),
#  ('Spcialits du monde', 18, '18'),
#  ('Reggiani Caseifici', 18, '18'),
#  ('Sant Gourmet', 12, '12'),
#  ('Wilman Kala', 11, '11'),
#  ('Godos Cocina Tpica', 18, '18'),
#  ('Hungry Owl All-Night Grocers', 28, '28'),
#  ('Queen Cozinha', 13, '13'),
#  ('Queen Cozinha', 13, '13'),
#  ('Tortuga Restaurante', 19, '19'),
#  ('Rancho grande', 13, '13'),
#  ('Romero y tomillo', 16, '16'),
#  ('Bottom-Dollar Markets', 21, '21'),
#  ('LINO-Delicateses', 16, '16'),
#  ('Around the Horn', 15, '15'),
#  ('Vaffeljernet', 12, '12'),
#  ('Hanari Carnes', 13, '13'),
#  ('La maison d-Asie', 16, '16'),
#  ('Berglunds snabbkp', 17, '17'),
#  ('Hanari Carnes', 13, '13'),
#  ('Ana Trujillo Emparedados y helados', 34, '34'),
#  ('La corne d-abondance', 20, '20'),
#  ('Galera del gastronmo', 20, '20'),
#  ('Frankenversand', 14, '14'),
#  ('Suprmes dlices', 14, '14'),
#  ('Richter Supermarkt', 18, '18'),
#  ('Bon app-', 8, '8'),
#  ('Island Trading', 14, '14'),
#  ('Lehmanns Marktstand', 19, '19'),
#  ('Wellington Importadora', 22, '22'),
#  ('Great Lakes Food Market', 23, '23'),
#  ('Cactus Comidas para llevar', 26, '26'),
#  ('QUICK-Stop', 10, '10'),
#  ('Magazzini Alimentari Riuniti', 28, '28'),
#  ('Bon app-', 8, '8'),
#  ('Save-a-lot Markets', 18, '18'),
#  ('Reggiani Caseifici', 18, '18'),
#  ('B-s Beverages', 13, '13'),
#  ('Bottom-Dollar Markets', 21, '21'),
#  ('Morgenstern Gesundkost', 22, '22'),
#  ('Vaffeljernet', 12, '12'),
#  ('B-s Beverages', 13, '13'),
#  ('Godos Cocina Tpica', 18, '18'),
#  ('Bottom-Dollar Markets', 21, '21'),
#  ('Magazzini Alimentari Riuniti', 28, '28'),
#  ('Richter Supermarkt', 18, '18'),
#  ('Alfred-s Futterkiste', 20, '20'),
#  ('Around the Horn', 15, '15'),
#  ('LINO-Delicateses', 16, '16'),
#  ('Folk och f HB', 13, '13'),
#  ('Blauer See Delikatessen', 23, '23'),
#  ('HILARION-Abastos', 16, '16'),
#  ('Ocano Atlntico Ltda.', 20, '20'),
#  ('Gourmet Lanchonetes', 19, '19'),
#  ('HILARION-Abastos', 16, '16'),
#  ('Queen Cozinha', 13, '13'),
#  ('QUICK-Stop', 10, '10'),
#  ('Furia Bacalhau e Frutos do Mar', 30, '30'),
#  ('Spcialits du monde', 18, '18'),
#  ('Old World Delicatessen', 22, '22'),
#  ('Chop-suey Chinese', 17, '17'),
#  ('Toms Spezialitten', 17, '17'),
#  ('Ernst Handel', 12, '12'),
#  ('Comrcio Mineiro', 15, '15'),
#  ('Blido Comidas preparadas', 24, '24'),
#  ('France restauration', 19, '19'),
#  ('La corne d-abondance', 20, '20'),
#  ('La corne d-abondance', 20, '20'),
#  ('Split Rail Beer & Ale', 21, '21'),
#  ('Bottom-Dollar Markets', 21, '21'),
#  ('HILARION-Abastos', 16, '16'),
#  ('Folk och f HB', 13, '13'),
#  ('Maison Dewey', 12, '12'),
#  ('Ernst Handel', 12, '12'),
#  ('Folk och f HB', 13, '13'),
#  ('Hanari Carnes', 13, '13'),
#  ('Bottom-Dollar Markets', 21, '21'),
#  ('Save-a-lot Markets', 18, '18'),
#  ('Save-a-lot Markets', 18, '18'),
#  ('Hungry Owl All-Night Grocers', 28, '28'),
#  ('Ocano Atlntico Ltda.', 20, '20'),
#  ('Eastern Connection', 18, '18'),
#  ('Rattlesnake Canyon Grocery', 26, '26'),
#  ('Que Delcia', 10, '10'),
#  ('Ernst Handel', 12, '12'),
#  ('QUICK-Stop', 10, '10'),
#  ('The Big Cheese', 14, '14'),
#  ('Folk och f HB', 13, '13'),
#  ('Vaffeljernet', 12, '12'),
#  ('Pericles Comidas clsicas', 24, '24'),
#  ('QUICK-Stop', 10, '10'),
#  ('LILA-Supermercado', 17, '17'),
#  ('Wolski Zajazd', 13, '13'),
#  ('Ottilies Kseladen', 17, '17'),
#  ('Rattlesnake Canyon Grocery', 26, '26'),
#  ('Folk och f HB', 13, '13'),
#  ('Save-a-lot Markets', 18, '18'),
#  ('The Cracker Box', 15, '15'),
#  ('Maison Dewey', 12, '12'),
#  ('Wilman Kala', 11, '11'),
#  ('Great Lakes Food Market', 23, '23'),
#  ('Princesa Isabel Vinhos', 22, '22'),
#  ('Ernst Handel', 12, '12'),
#  ('Godos Cocina Tpica', 18, '18'),
#  ('Reggiani Caseifici', 18, '18'),
#  ('Alfred-s Futterkiste', 20, '20'),
#  ('Frankenversand', 14, '14'),
#  ('Romero y tomillo', 16, '16'),
#  ('LINO-Delicateses', 16, '16'),
#  ('Sant Gourmet', 12, '12'),
#  ('Around the Horn', 15, '15'),
#  ('Ernst Handel', 12, '12'),
#  ('Lonesome Pine Restaurant', 24, '24'),
#  ('Rancho grande', 13, '13'),
#  ('Ottilies Kseladen', 17, '17'),
#  ('QUICK-Stop', 10, '10'),
#  ('Hanari Carnes', 13, '13'),
#  ('B-s Beverages', 13, '13'),
#  ('Eastern Connection', 18, '18'),
#  ('Wartian Herkku', 14, '14'),
#  ('Franchi S.p.A.', 14, '14'),
#  ('Bottom-Dollar Markets', 21, '21'),
#  ('Kniglich Essen', 14, '14'),
#  ('Chop-suey Chinese', 17, '17'),
#  ('Save-a-lot Markets', 18, '18'),
#  ('Save-a-lot Markets', 18, '18'),
#  ('White Clover Markets', 20, '20'),
#  ('Richter Supermarkt', 18, '18'),
#  ('Old World Delicatessen', 22, '22'),
#  ('Suprmes dlices', 14, '14'),
#  ('Drachenblut Delikatessen', 24, '24'),
#  ('Godos Cocina Tpica', 18, '18'),
#  ('Suprmes dlices', 14, '14'),
#  ('LINO-Delicateses', 16, '16'),
#  ('Great Lakes Food Market', 23, '23'),
#  ('Chop-suey Chinese', 17, '17'),
#  ('Comrcio Mineiro', 15, '15'),
#  ('Spcialits du monde', 18, '18'),
#  ('Wolski Zajazd', 13, '13'),
#  ('Bottom-Dollar Markets', 21, '21'),
#  ('Die Wandernde Kuh', 17, '17'),
#  ('Eastern Connection', 18, '18'),
#  ('Bottom-Dollar Markets', 21, '21'),
#  ('Gourmet Lanchonetes', 19, '19'),
#  ('Folk och f HB', 13, '13'),
#  ('La maison d-Asie', 16, '16'),
#  ('Hanari Carnes', 13, '13'),
#  ('Piccolo und mehr', 16, '16'),
#  ('Cactus Comidas para llevar', 26, '26'),
#  ('HILARION-Abastos', 16, '16'),
#  ('Eastern Connection', 18, '18'),
#  ('North/South', 11, '11'),
#  ('Blauer See Delikatessen', 23, '23'),
#  ('Ricardo Adocicados', 18, '18'),
#  ('Franchi S.p.A.', 14, '14'),
#  ('Great Lakes Food Market', 23, '23'),
#  ('Reggiani Caseifici', 18, '18'),
#  ('Hungry Owl All-Night Grocers', 28, '28'),
#  ('Save-a-lot Markets', 18, '18'),
#  ('LILA-Supermercado', 17, '17'),
#  ('White Clover Markets', 20, '20'),
#  ('Drachenblut Delikatessen', 24, '24'),
#  ('Queen Cozinha', 13, '13'),
#  ('Tortuga Restaurante', 19, '19'),
#  ('Lehmanns Marktstand', 19, '19'),
#  ('LILA-Supermercado', 17, '17'),
#  ('Ernst Handel', 12, '12'),
#  ('Pericles Comidas clsicas', 24, '24'),
#  ('Simons bistro', 13, '13'),
#  ('Richter Supermarkt', 18, '18'),
#  ('Bon app-', 8, '8'),
#  ('Rattlesnake Canyon Grocery', 26, '26')]

# %% [markdown]
# ### 3. Replace string
#
# The `Customers` table contains null values in the `ContactTitle` column. Write a SQL command to replace these null values with the string 'N/A'.

# %%
# %%sql
# UPDATE
# Customers
# SET
# ContactTitle = IFNULL(ContactTitle,'N/A');
# Out:
#  * sqlite:///Northwind.db
# 93 rows affected.
# []

# %% [markdown]
# ### 4. Extract characters
#
# Write a SQL command to extract the first three characters from the `City` column in the `Customers` table.

# %%
# %%sql
# SELECT
#     City,
#     SUBSTR(City,1,3) as city_code
# FROM Customers;
# Out:
#  * sqlite:///Northwind.db
# Done.
# [('Berlin', 'Ber'),
#  ('Mxico D.F.', 'Mxi'),
#  ('Mxico D.F.', 'Mxi'),
#  ('London', 'Lon'),
#  ('Lule', 'Lul'),
#  ('Mannheim', 'Man'),
#  ('Strasbourg', 'Str'),
#  ('Madrid', 'Mad'),
#  ('Marseille', 'Mar'),
#  ('Tsawassen', 'Tsa'),
#  ('London', 'Lon'),
#  ('Buenos Aires', 'Bue'),
#  ('Mxico D.F.', 'Mxi'),
#  ('Bern', 'Ber'),
#  ('Sao Paulo', 'Sao'),
#  ('London', 'Lon'),
#  ('Aachen', 'Aac'),
#  ('Nantes', 'Nan'),
#  ('London', 'Lon'),
#  ('Graz', 'Gra'),
#  ('Sao Paulo', 'Sao'),
#  ('Madrid', 'Mad'),
#  ('Lille', 'Lil'),
#  ('Brcke', 'Brc'),
#  ('Mnchen', 'Mnc'),
#  ('Nantes', 'Nan'),
#  ('Torino', 'Tor'),
#  ('Lisboa', 'Lis'),
#  ('Barcelona', 'Bar'),
#  ('Sevilla', 'Sev'),
#  ('Campinas', 'Cam'),
#  ('Eugene', 'Eug'),
#  ('Caracas', 'Car'),
#  ('Rio de Janeiro', 'Rio'),
#  ('San Cristbal', 'San'),
#  ('Elgin', 'Elg'),
#  ('Cork', 'Cor'),
#  ('Cowes', 'Cow'),
#  ('Brandenburg', 'Bra'),
#  ('Versailles', 'Ver'),
#  ('Toulouse', 'Tou'),
#  ('Vancouver', 'Van'),
#  ('Walla Walla', 'Wal'),
#  ('Frankfurt a.M.', 'Fra'),
#  ('San Francisco', 'San'),
#  ('Barquisimeto', 'Bar'),
#  ('I. de Margarita', 'I. '),
#  ('Portland', 'Por'),
#  ('Bergamo', 'Ber'),
#  ('Bruxelles', 'Bru'),
#  ('Montral', 'Mon'),
#  ('Leipzig', 'Lei'),
#  ('London', 'Lon'),
#  ('Buenos Aires', 'Bue'),
#  ('Anchorage', 'Anc'),
#  ('Kln', 'Kln'),
#  ('Paris', 'Par'),
#  ('Mxico D.F.', 'Mxi'),
#  ('Salzburg', 'Sal'),
#  ('Lisboa', 'Lis'),
#  ('Rio de Janeiro', 'Rio'),
#  ('Sao Paulo', 'Sao'),
#  ('Cunewalde', 'Cun'),
#  ('Buenos Aires', 'Bue'),
#  ('Albuquerque', 'Alb'),
#  ('Reggio Emilia', 'Reg'),
#  ('Rio de Janeiro', 'Rio'),
#  ('Genve', 'Gen'),
#  ('Madrid', 'Mad'),
#  ('Stavern', 'Sta'),
#  ('Boise', 'Boi'),
#  ('London', 'Lon'),
#  ('Kobenhavn', 'Kob'),
#  ('Paris', 'Par'),
#  ('Lander', 'Lan'),
#  ('Charleroi', 'Cha'),
#  ('Portland', 'Por'),
#  ('Butte', 'But'),
#  ('Mnster', 'Mns'),
#  ('Mxico D.F.', 'Mxi'),
#  ('Sao Paulo', 'Sao'),
#  ('Kirkland', 'Kir'),
#  ('rhus', 'rhu'),
#  (None, None),
#  (None, None),
#  ('Lyon', 'Lyo'),
#  ('Reims', 'Rei'),
#  ('Stuttgart', 'Stu'),
#  ('Oulu', 'Oul'),
#  ('Resende', 'Res'),
#  ('Seattle', 'Sea'),
#  ('Helsinki', 'Hel'),
#  ('Warszawa', 'War')]

# %% [markdown]
# ### 5. String concatenation
#
# Write a SQL query to concatenate the `FirstName` and `LastName` of employees in the `Employees` table into a new column `FullName`.

# %%
# %%sql
# SELECT
#     FirstName,
#     LastName,
# CONCAT(
#     FirstName," ",
#     LastName) AS FullName
# From Employees
# Out:
#  * sqlite:///Northwind.db
# Done.
# [('Nancy', 'Davolio', 'Nancy Davolio'),
#  ('Andrew', 'Fuller', 'Andrew Fuller'),
#  ('Janet', 'Leverling', 'Janet Leverling'),
#  ('Margaret', 'Peacock', 'Margaret Peacock'),
#  ('Steven', 'Buchanan', 'Steven Buchanan'),
#  ('Michael', 'Suyama', 'Michael Suyama'),
#  ('Robert', 'King', 'Robert King'),
#  ('Laura', 'Callahan', 'Laura Callahan'),
#  ('Anne', 'Dodsworth', 'Anne Dodsworth')]

# %% [markdown]
# ### Challenge question
#
# You are working in the marketing department of your company and you have been given the task of conducting an email marketing campaign targeting all customers based in France.

# %% [markdown]
# You have a `Customers` table which includes an `Email` column. However, the data isn't perfect. Some email addresses might be duplicated, others might be `NULL`, and some might have unnecessary white spaces at the start or end of the address.
#
# Your task is to clean up the data and compile a list of unique email addresses to use for the marketing campaign. Here are the requirements:

# %% [markdown]
# 1. Exclude any `NULL` email addresses from your list. We can't send emails to addresses we don't have.
# 2. Make sure there are no duplicates in your list. We don't want to annoy our customers by sending them the same email multiple times.
# 3. Remove any unnecessary white spaces from the start or end of the email addresses. This will help avoid any errors when sending the emails.

# %% [markdown]
# Remember, the success of our campaign depends on the quality of this list!
#
# Your output should look something like this, though the exact email addresses will depend on the data in your `Customers` table:

# %% [raw]
# customer1@example.com
# customer2@example.com
# customer3@example.com

# %%
# %%sql
# SELECT *
# FROM Customers
# Out:
#  * sqlite:///Northwind.db
# Done.
# [('ALFKI', 'Alfreds Futterkiste', 'Maria Anders', 'Sales Representative', 'Obere Str. 57', 'Berlin', None, '12209', 'Germany', '030-0074321', '030-0076545'),
#  ('ANATR', 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Owner', 'Avda. de la Constitucin 2222', 'Mxico D.F.', None, '05021', 'Mexico', '(5) 555-4729', '(5) 555-3745'),
#  ('ANTON', 'Antonio Moreno Taquera', 'Antonio Moreno', 'Owner', 'Mataderos  2312', 'Mxico D.F.', None, '05023', 'Mexico', '(5) 555-3932', None),
#  ('AROUT', 'Around the Horn', 'Thomas Hardy', 'Sales Representative', '120 Hanover Sq.', 'London', None, 'WA1 1DP', 'UK', '(171) 555-7788', '(171) 555-6750'),
#  ('BERGS', 'Berglunds snabbkp', 'Christina Berglund', 'Order Administrator', 'Berguvsvgen  8', 'Lule', None, 'S-958 22', 'Sweden', '0921-12 34 65', '0921-12 34 67'),
#  ('BLAUS', 'Blauer See Delikatessen', 'Hanna Moos', 'Sales Representative', 'Forsterstr. 57', 'Mannheim', None, '68306', 'Germany', '0621-08460', '0621-08924'),
#  ('BLONP', 'Blondesddsl pre et fils', 'Frdrique Citeaux', 'Marketing Manager', '24, place Klber', 'Strasbourg', None, '67000', 'France', '88.60.15.31', '88.60.15.32'),
#  ('BOLID', 'Blido Comidas preparadas', 'Martn Sommer', 'Owner', 'C/ Araquil, 67', 'Madrid', None, '28023', 'Spain', '(91) 555 22 82', '(91) 555 91 99'),
#  ('BONAP', "Bon app'", 'Laurence Lebihan', 'Owner', '12, rue des Bouchers', 'Marseille', None, '13008', 'France', '91.24.45.40', '91.24.45.41'),
#  ('BOTTM', 'Bottom-Dollar Markets', 'Elizabeth Lincoln', 'Accounting Manager', '23 Tsawassen Blvd.', 'Tsawassen', 'BC', 'T2F 8M4', 'Canada', '(604) 555-4729', '(604) 555-3745'),
#  ('BSBEV', "B's Beverages", 'Victoria Ashworth', 'Sales Representative', 'Fauntleroy Circus', 'London', None, 'EC2 5NT', 'UK', '(171) 555-1212', None),
#  ('CACTU', 'Cactus Comidas para llevar', 'Patricio Simpson', 'Sales Agent', 'Cerrito 333', 'Buenos Aires', None, '1010', 'Argentina', '(1) 135-5555', '(1) 135-4892'),
#  ('CENTC', 'Centro comercial Moctezuma', 'Francisco Chang', 'Marketing Manager', 'Sierras de Granada 9993', 'Mxico D.F.', None, '05022', 'Mexico', '(5) 555-3392', '(5) 555-7293'),
#  ('CHOPS', 'Chop-suey Chinese', 'Yang Wang', 'Owner', 'Hauptstr. 29', 'Bern', None, '3012', 'Switzerland', '0452-076545', None),
#  ('COMMI', 'Comrcio Mineiro', 'Pedro Afonso', 'Sales Associate', 'Av. dos Lusadas, 23', 'Sao Paulo', 'SP', '05432-043', 'Brazil', '(11) 555-7647', None),
#  ('CONSH', 'Consolidated Holdings', 'Elizabeth Brown', 'Sales Representative', 'Berkeley Gardens 12  Brewery', 'London', None, 'WX1 6LT', 'UK', '(171) 555-2282', '(171) 555-9199'),
#  ('DRACD', 'Drachenblut Delikatessen', 'Sven Ottlieb', 'Order Administrator', 'Walserweg 21', 'Aachen', None, '52066', 'Germany', '0241-039123', '0241-059428'),
#  ('DUMON', 'Du monde entier', 'Janine Labrune', 'Owner', '67, rue des Cinquante Otages', 'Nantes', None, '44000', 'France', '40.67.88.88', '40.67.89.89'),
#  ('EASTC', 'Eastern Connection', 'Ann Devon', 'Sales Agent', '35 King George', 'London', None, 'WX3 6FW', 'UK', '(171) 555-0297', '(171) 555-3373'),
#  ('ERNSH', 'Ernst Handel', 'Roland Mendel', 'Sales Manager', 'Kirchgasse 6', 'Graz', None, '8010', 'Austria', '7675-3425', '7675-3426'),
#  ('FAMIA', 'Familia Arquibaldo', 'Aria Cruz', 'Marketing Assistant', 'Rua Ors, 92', 'Sao Paulo', 'SP', '05442-030', 'Brazil', '(11) 555-9857', None),
#  ('FISSA', 'FISSA Fabrica Inter. Salchichas S.A.', 'Diego Roel', 'Accounting Manager', 'C/ Moralzarzal, 86', 'Madrid', None, '28034', 'Spain', '(91) 555 94 44', '(91) 555 55 93'),
#  ('FOLIG', 'Folies gourmandes', 'Martine Ranc', 'Assistant Sales Agent', '184, chausse de Tournai', 'Lille', None, '59000', 'France', '20.16.10.16', '20.16.10.17'),
#  ('FOLKO', 'Folk och f HB', 'Maria Larsson', 'Owner', 'kergatan 24', 'Brcke', None, 'S-844 67', 'Sweden', '0695-34 67 21', None),
#  ('FRANK', 'Frankenversand', 'Peter Franken', 'Marketing Manager', 'Berliner Platz 43', 'Mnchen', None, '80805', 'Germany', '089-0877310', '089-0877451'),
#  ('FRANR', 'France restauration', 'Carine Schmitt', 'Marketing Manager', '54, rue Royale', 'Nantes', None, '44000', 'France', '40.32.21.21', '40.32.21.20'),
#  ('FRANS', 'Franchi S.p.A.', 'Paolo Accorti', 'Sales Representative', 'Via Monte Bianco 34', 'Torino', None, '10100', 'Italy', '011-4988260', '011-4988261'),
#  ('FURIB', 'Furia Bacalhau e Frutos do Mar', 'Lino Rodriguez', 'Sales Manager', 'Jardim das rosas n. 32', 'Lisboa', None, '1675', 'Portugal', '(1) 354-2534', '(1) 354-2535'),
#  ('GALED', 'Galera del gastrnomo', 'Eduardo Saavedra', 'Marketing Manager', 'Rambla de Catalua, 23', 'Barcelona', None, '08022', 'Spain', '(93) 203 4560', '(93) 203 4561'),
#  ('GODOS', 'Godos Cocina Tpica', 'Jos Pedro Freyre', 'Sales Manager', 'C/ Romero, 33', 'Sevilla', None, '41101', 'Spain', '(95) 555 82 82', None),
#  ('GOURL', 'Gourmet Lanchonetes', 'Andr Fonseca', 'Sales Associate', 'Av. Brasil, 442', 'Campinas', 'SP', '04876-786', 'Brazil', '(11) 555-9482', None),
#  ('GREAL', 'Great Lakes Food Market', 'Howard Snyder', 'Marketing Manager', '2732 Baker Blvd.', 'Eugene', 'OR', '97403', 'USA', '(503) 555-7555', None),
#  ('GROSR', 'GROSELLA-Restaurante', 'Manuel Pereira', 'Owner', '5 Ave. Los Palos Grandes', 'Caracas', 'DF', '1081', 'Venezuela', '(2) 283-2951', '(2) 283-3397'),
#  ('HANAR', 'Hanari Carnes', 'Mario Pontes', 'Accounting Manager', 'Rua do Pao, 67', 'Rio de Janeiro', 'RJ', '05454-876', 'Brazil', '(21) 555-0091', '(21) 555-8765'),
#  ('HILAA', 'HILARION-Abastos', 'Carlos Hernndez', 'Sales Representative', 'Carrera 22 con Ave. Carlos Soublette #8-35', 'San Cristbal', 'Tchira', '5022', 'Venezuela', '(5) 555-1340', '(5) 555-1948'),
#  ('HUNGC', 'Hungry Coyote Import Store', 'Yoshi Latimer', 'Sales Representative', 'City Center Plaza 516 Main St.', 'Elgin', 'OR', '97827', 'USA', '(503) 555-6874', '(503) 555-2376'),
#  ('HUNGO', 'Hungry Owl All-Night Grocers', 'Patricia McKenna', 'Sales Associate', '8 Johnstown Road', 'Cork', 'Co. Cork', None, 'Ireland', '2967 542', '2967 3333'),
#  ('ISLAT', 'Island Trading', 'Helen Bennett', 'Marketing Manager', 'Garden House Crowther Way', 'Cowes', 'Isle of Wight', 'PO31 7PJ', 'UK', '(198) 555-8888', None),
#  ('KOENE', 'Kniglich Essen', 'Philip Cramer', 'Sales Associate', 'Maubelstr. 90', 'Brandenburg', None, '14776', 'Germany', '0555-09876', None),
#  ('LACOR', "La corne d'abondance", 'Daniel Tonini', 'Sales Representative', "67, avenue de l'Europe", 'Versailles', None, '78000', 'France', '30.59.84.10', '30.59.85.11'),
#  ('LAMAI', "La maison d'Asie", 'Annette Roulet', 'Sales Manager', '1 rue Alsace-Lorraine', 'Toulouse', None, '31000', 'France', '61.77.61.10', '61.77.61.11'),
#  ('LAUGB', 'Laughing Bacchus Wine Cellars', 'Yoshi Tannamuri', 'Marketing Assistant', '1900 Oak St.', 'Vancouver', 'BC', 'V3F 2K1', 'Canada', '(604) 555-3392', '(604) 555-7293'),
#  ('LAZYK', 'Lazy K Kountry Store', 'John Steel', 'Marketing Manager', '12 Orchestra Terrace', 'Walla Walla', 'WA', '99362', 'USA', '(509) 555-7969', '(509) 555-6221'),
#  ('LEHMS', 'Lehmanns Marktstand', 'Renate Messner', 'Sales Representative', 'Magazinweg 7', 'Frankfurt a.M.', None, '60528', 'Germany', '069-0245984', '069-0245874'),
#  ('LETSS', "Let's Stop N Shop", 'Jaime Yorres', 'Owner', '87 Polk St. Suite 5', 'San Francisco', 'CA', '94117', 'USA', '(415) 555-5938', None),
#  ('LILAS', 'LILA-Supermercado', 'Carlos Gonzlez', 'Accounting Manager', 'Carrera 52 con Ave. Bolvar #65-98 Llano Largo', 'Barquisimeto', 'Lara', '3508', 'Venezuela', '(9) 331-6954', '(9) 331-7256'),
#  ('LINOD', 'LINO-Delicateses', 'Felipe Izquierdo', 'Owner', 'Ave. 5 de Mayo Porlamar', 'I. de Margarita', 'Nueva Esparta', '4980', 'Venezuela', '(8) 34-56-12', '(8) 34-93-93'),
#  ('LONEP', 'Lonesome Pine Restaurant', 'Fran Wilson', 'Sales Manager', '89 Chiaroscuro Rd.', 'Portland', 'OR', '97219', 'USA', '(503) 555-9573', '(503) 555-9646'),
#  ('MAGAA', 'Magazzini Alimentari Riuniti', 'Giovanni Rovelli', 'Marketing Manager', 'Via Ludovico il Moro 22', 'Bergamo', None, '24100', 'Italy', '035-640230', '035-640231'),
#  ('MAISD', 'Maison Dewey', 'Catherine Dewey', 'Sales Agent', 'Rue Joseph-Bens 532', 'Bruxelles', None, 'B-1180', 'Belgium', '(02) 201 24 67', '(02) 201 24 68'),
#  ('MEREP', 'Mre Paillarde', 'Jean Fresnire', 'Marketing Assistant', '43 rue St. Laurent', 'Montral', 'Qubec', 'H1J 1C3', 'Canada', '(514) 555-8054', '(514) 555-8055'),
#  ('MORGK', 'Morgenstern Gesundkost', 'Alexander Feuer', 'Marketing Assistant', 'Heerstr. 22', 'Leipzig', None, '04179', 'Germany', '0342-023176', None),
#  ('NORTS', 'North/South', 'Simon Crowther', 'Sales Associate', 'South House 300 Queensbridge', 'London', None, 'SW7 1RZ', 'UK', '(171) 555-7733', '(171) 555-2530'),
#  ('OCEAN', 'Ocano Atlntico Ltda.', 'Yvonne Moncada', 'Sales Agent', 'Ing. Gustavo Moncada 8585 Piso 20-A', 'Buenos Aires', None, '1010', 'Argentina', '(1) 135-5333', '(1) 135-5535'),
#  ('OLDWO', 'Old World Delicatessen', 'Rene Phillips', 'Sales Representative', '2743 Bering St.', 'Anchorage', 'AK', '99508', 'USA', '(907) 555-7584', '(907) 555-2880'),
#  ('OTTIK', 'Ottilies Kseladen', 'Henriette Pfalzheim', 'Owner', 'Mehrheimerstr. 369', 'Kln', None, '50739', 'Germany', '0221-0644327', '0221-0765721'),
#  ('PARIS', 'Paris spcialits', 'Marie Bertrand', 'Owner', '265, boulevard Charonne', 'Paris', None, '75012', 'France', '(1) 42.34.22.66', '(1) 42.34.22.77'),
#  ('PERIC', 'Pericles Comidas clsicas', 'Guillermo Fernndez', 'Sales Representative', 'Calle Dr. Jorge Cash 321', 'Mxico D.F.', None, '05033', 'Mexico', '(5) 552-3745', '(5) 545-3745'),
#  ('PICCO', 'Piccolo und mehr', 'Georg Pipps', 'Sales Manager', 'Geislweg 14', 'Salzburg', None, '5020', 'Austria', '6562-9722', '6562-9723'),
#  ('PRINI', 'Princesa Isabel Vinhos', 'Isabel de Castro', 'Sales Representative', 'Estrada da sade n. 58', 'Lisboa', None, '1756', 'Portugal', '(1) 356-5634', None),
#  ('QUEDE', 'Que Delcia', 'Bernardo Batista', 'Accounting Manager', 'Rua da Panificadora, 12', 'Rio de Janeiro', 'RJ', '02389-673', 'Brazil', '(21) 555-4252', '(21) 555-4545'),
#  ('QUEEN', 'Queen Cozinha', 'Lcia Carvalho', 'Marketing Assistant', 'Alameda dos Canrios, 891', 'Sao Paulo', 'SP', '05487-020', 'Brazil', '(11) 555-1189', None),
#  ('QUICK', 'QUICK-Stop', 'Horst Kloss', 'Accounting Manager', 'Taucherstrae 10', 'Cunewalde', None, '01307', 'Germany', '0372-035188', None),
#  ('RANCH', 'Rancho grande', 'Sergio Gutirrez', 'Sales Representative', 'Av. del Libertador 900', 'Buenos Aires', None, '1010', 'Argentina', '(1) 123-5555', '(1) 123-5556'),
#  ('RATTC', 'Rattlesnake Canyon Grocery', 'Paula Wilson', 'Assistant Sales Representative', '2817 Milton Dr.', 'Albuquerque', 'NM', '87110', 'USA', '(505) 555-5939', '(505) 555-3620'),
#  ('REGGC', 'Reggiani Caseifici', 'Maurizio Moroni', 'Sales Associate', 'Strada Provinciale 124', 'Reggio Emilia', None, '42100', 'Italy', '0522-556721', '0522-556722'),
#  ('RICAR', 'Ricardo Adocicados', 'Janete Limeira', 'Assistant Sales Agent', 'Av. Copacabana, 267', 'Rio de Janeiro', 'RJ', '02389-890', 'Brazil', '(21) 555-3412', None),
#  ('RICSU', 'Richter Supermarkt', 'Michael Holz', 'Sales Manager', 'Grenzacherweg 237', 'Genve', None, '1203', 'Switzerland', '0897-034214', None),
#  ('ROMEY', 'Romero y tomillo', 'Alejandra Camino', 'Accounting Manager', 'Gran Va, 1', 'Madrid', None, '28001', 'Spain', '(91) 745 6200', '(91) 745 6210'),
#  ('SANTG', 'Sant Gourmet', 'Jonas Bergulfsen', 'Owner', 'Erling Skakkes gate 78', 'Stavern', None, '4110', 'Norway', '07-98 92 35', '07-98 92 47'),
#  ('SAVEA', 'Save-a-lot Markets', 'Jose Pavarotti', 'Sales Representative', '187 Suffolk Ln.', 'Boise', 'ID', '83720', 'USA', '(208) 555-8097', None),
#  ('SEVES', 'Seven Seas Imports', 'Hari Kumar', 'Sales Manager', '90 Wadhurst Rd.', 'London', None, 'OX15 4NB', 'UK', '(171) 555-1717', '(171) 555-5646'),
#  ('SIMOB', 'Simons bistro', 'Jytte Petersen', 'Owner', 'Vinbltet 34', 'Kobenhavn', None, '1734', 'Denmark', '31 12 34 56', '31 13 35 57'),
#  ('SPECD', 'Spcialits du monde', 'Dominique Perrier', 'Marketing Manager', '25, rue Lauriston', 'Paris', None, '75016', 'France', '(1) 47.55.60.10', '(1) 47.55.60.20'),
#  ('SPLIR', 'Split Rail Beer & Ale', 'Art Braunschweiger', 'Sales Manager', 'P.O. Box 555', 'Lander', 'WY', '82520', 'USA', '(307) 555-4680', '(307) 555-6525'),
#  ('SUPRD', 'Suprmes dlices', 'Pascale Cartrain', 'Accounting Manager', 'Boulevard Tirou, 255', 'Charleroi', None, 'B-6000', 'Belgium', '(071) 23 67 22 20', '(071) 23 67 22 21'),
#  ('THEBI', 'The Big Cheese', 'Liz Nixon', 'Marketing Manager', '89 Jefferson Way Suite 2', 'Portland', 'OR', '97201', 'USA', '(503) 555-3612', None),
#  ('THECR', 'The Cracker Box', 'Liu Wong', 'Marketing Assistant', '55 Grizzly Peak Rd.', 'Butte', 'MT', '59801', 'USA', '(406) 555-5834', '(406) 555-8083'),
#  ('TOMSP', 'Toms Spezialitten', 'Karin Josephs', 'Marketing Manager', 'Luisenstr. 48', 'Mnster', None, '44087', 'Germany', '0251-031259', '0251-035695'),
#  ('TORTU', 'Tortuga Restaurante', 'Miguel Angel Paolino', 'Owner', 'Avda. Azteca 123', 'Mxico D.F.', None, '05033', 'Mexico', '(5) 555-2933', None),
#  ('TRADH', 'Tradio Hipermercados', 'Anabela Domingues', 'Sales Representative', 'Av. Ins de Castro, 414', 'Sao Paulo', 'SP', '05634-030', 'Brazil', '(11) 555-2167', '(11) 555-2168'),
#  ('TRAIH', "Trail's Head Gourmet Provisioners", 'Helvetius Nagy', 'Sales Associate', '722 DaVinci Blvd.', 'Kirkland', 'WA', '98034', 'USA', '(206) 555-8257', '(206) 555-2174'),
#  ('VAFFE', 'Vaffeljernet', 'Palle Ibsen', 'Sales Manager', 'Smagsloget 45', 'rhus', None, '8200', 'Denmark', '86 21 32 43', '86 22 33 44'),
#  ('Val2 ', 'IT', 'Val2', 'IT', None, None, None, None, None, None, None),
#  ('VALON', 'IT', 'Valon Hoti', 'IT', None, None, None, None, None, None, None),
#  ('VICTE', 'Victuailles en stock', 'Mary Saveley', 'Sales Agent', '2, rue du Commerce', 'Lyon', None, '69004', 'France', '78.32.54.86', '78.32.54.87'),
#  ('VINET', 'Vins et alcools Chevalier', 'Paul Henriot', 'Accounting Manager', "59 rue de l'Abbaye", 'Reims', None, '51100', 'France', '26.47.15.10', '26.47.15.11'),
#  ('WANDK', 'Die Wandernde Kuh', 'Rita Mller', 'Sales Representative', 'Adenauerallee 900', 'Stuttgart', None, '70563', 'Germany', '0711-020361', '0711-035428'),
#  ('WARTH', 'Wartian Herkku', 'Pirkko Koskitalo', 'Accounting Manager', 'Torikatu 38', 'Oulu', None, '90110', 'Finland', '981-443655', '981-443655'),
#  ('WELLI', 'Wellington Importadora', 'Paula Parente', 'Sales Manager', 'Rua do Mercado, 12', 'Resende', 'SP', '08737-363', 'Brazil', '(14) 555-8122', None),
#  ('WHITC', 'White Clover Markets', 'Karl Jablonski', 'Owner', '305 - 14th Ave. S. Suite 3B', 'Seattle', 'WA', '98128', 'USA', '(206) 555-4112', '(206) 555-4115'),
#  ('WILMK', 'Wilman Kala', 'Matti Karttunen', 'Owner/Marketing Assistant', 'Keskuskatu 45', 'Helsinki', None, '21240', 'Finland', '90-224 8858', '90-224 8858'),
#  ('WOLZA', 'Wolski  Zajazd', 'Zbyszek Piestrzeniewicz', 'Owner', 'ul. Filtrowa 68', 'Warszawa', None, '01-012', 'Poland', '(26) 642-7012', '(26) 642-7012')]

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### 1. Convert data type
#
# The `CAST` function is used to convert one data type to another. In this query, it is used to convert the `Salary` column from an integer to a string.

# %%
# %%sql
#
# SELECT
#     CAST(Salary AS CHAR) AS SalaryString
# FROM
#     Employees;

# %% [markdown]
# ### 2. Trim strings
#
# The `TRIM` function is used to remove leading and trailing spaces from a string. This query uses `TRIM` to remove spaces from the `ShipName` entries.

# %%
# %%sql
#
# SELECT
#     LENGTH(TRIM(ShipName)) AS TrimmedShipName
# FROM
#     Orders;
# Out:
#  * sqlite:///Northwind.db
# Done.
# [(25,),
#  (17,),
#  (13,),
#  (20,),
#  (14,),
#  (13,),
#  (17,),
#  (18,),
#  (22,),
#  (16,),
#  (12,),
#  (26,),
#  (17,),
#  (10,),
#  (26,),
#  (12,),
#  (13,),
#  (19,),
#  (14,),
#  (14,),
#  (20,),
#  (20,),
#  (14,),
#  (21,),
#  (26,),
#  (10,),
#  (25,),
#  (28,),
#  (19,),
#  (22,),
#  (17,),
#  (19,),
#  (17,),
#  (16,),
#  (16,),
#  (17,),
#  (19,),
#  (10,),
#  (10,),
#  (18,),
#  (18,),
#  (13,),
#  (15,),
#  (10,),
#  (21,),
#  (19,),
#  (26,),
#  (25,),
#  (17,),
#  (19,),
#  (21,),
#  (21,),
#  (16,),
#  (13,),
#  (12,),
#  (12,),
#  (13,),
#  (13,),
#  (21,),
#  (18,),
#  (18,),
#  (28,),
#  (20,),
#  (18,),
#  (26,),
#  (10,),
#  (12,),
#  (10,),
#  (14,),
#  (13,),
#  (12,),
#  (24,),
#  (10,),
#  (17,),
#  (13,),
#  (17,),
#  (26,),
#  (13,),
#  (18,),
#  (15,),
#  (12,),
#  (11,),
#  (23,),
#  (22,),
#  (12,),
#  (18,),
#  (18,),
#  (20,),
#  (14,),
#  (16,),
#  (16,),
#  (12,),
#  (15,),
#  (12,),
#  (24,),
#  (13,),
#  (17,),
#  (10,),
#  (13,),
#  (13,),
#  (18,),
#  (14,),
#  (14,),
#  (21,),
#  (14,),
#  (17,),
#  (18,),
#  (18,),
#  (20,),
#  (18,),
#  (22,),
#  (14,),
#  (24,),
#  (18,),
#  (14,),
#  (16,),
#  (23,),
#  (17,),
#  (15,),
#  (18,),
#  (13,),
#  (21,),
#  (17,),
#  (18,),
#  (21,),
#  (19,),
#  (13,),
#  (16,),
#  (13,),
#  (16,),
#  (26,),
#  (16,),
#  (18,),
#  (11,),
#  (23,),
#  (18,),
#  (14,),
#  (23,),
#  (18,),
#  (28,),
#  (18,),
#  (17,),
#  (20,),
#  (24,),
#  (13,),
#  (19,),
#  (19,),
#  (17,),
#  (12,),
#  (24,),
#  (13,),
#  (18,),
#  (8,),
#  (26,)]

# %% [markdown]
# ### 3. Replace string
#
# The `COALESCE` function returns the first non-null value in a list. In this case, it's used to replace `NULL` values in the `ContactTitle` column with `'N/A'`.

# %%
# %%sql
#
# UPDATE
#     Customers
# SET
#     ContactTitle = COALESCE(ContactTitle, 'N/A');
# Out:
#  * sqlite:///Northwind.db
# 93 rows affected.
# []

# %% [markdown]
# ### 4. Extract characters
#
# The `LEFT` function is used to extract a specified number of characters from a string, starting from the left. This query extracts the first three characters from the `City` column.

# %%
# %%sql
#
# SELECT
#     LEFT(City, 3) AS CitySubstring
# FROM
#     Customers;
# Out:
#  * sqlite:///Northwind.db
# (sqlite3.OperationalError) no such function: LEFT
# [SQL: SELECT
#     LEFT(City, 3) AS CitySubstring
# FROM
#     Customers;]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %% [markdown]
# ### 5. String concatenation
#
# The `CONCAT` function is used to combine two or more strings into one. This query concatenates the `FirstName` and `LastName` columns with a space in between.

# %%
# %%sql
#
# SELECT
#     CONCAT(FirstName, ' ', LastName) AS FullName
# FROM
#     Employees;

# %% [markdown]
# ### Challenge question
#
# The SQL statement is reading data from the Customers table (`FROM` Customers).
#
# The `WHERE` clause filters out the customers who are based in France `(Country = 'France')` and whose email address is not `NULL (AND Email IS NOT NULL)`.
#
# The `SELECT DISTINCT TRIM(Email)` part of the statement is where the magic happens. `TRIM(Email)` removes any white spaces from the start and end of the email addresses. And `DISTINCT` ensures that each email address in your results is unique.
#
# Thus, this query will return a list of unique, cleaned-up email addresses for all customers in France, ready for you to use in your marketing campaign.

# %%
# %%sql
#
# SELECT
#     DISTINCT TRIM(Email)
# FROM
#     Customers
# WHERE
#     Country = 'France'
#     AND Email IS NOT NULL;

# %% [markdown]
# #
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/refs/heads/master/ALX_banners/ALX_Navy.png"  style="width:100px"  ;/>
# </div>
