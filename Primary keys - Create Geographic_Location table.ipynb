# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img
#  src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/alx-courses/aice/assets/Content_page_banner_blue_dots.png"
#  alt="ALX Content Header"
#  class="full-width-image"
# />
# </div>

# %% [markdown]
# # Primary keys: Create Geographic_Location table

# %% [markdown]
# In this notebook, we demonstrate how to divide a larger dataset into smaller tables and link them using relationships.

# %% [markdown]
# > ⚠️ This notebook will not run on Google Colab because it cannot connect to a local database. Please make sure that this notebook is running on the same local machine as your MySQL Workbench installation and MySQL `united_nations` database.

# %% [markdown]
# ## Learning objectives
#
# By the end of this train, you should:
# - Understand how to extract specific related columns from a table to create a new table that will be linked with the rest of the tables using a relation.
# - Understand how to create a primary key and the uniqueness constraint.

# %% [markdown]
# ## Connecting to our MySQL database
#
# Using our Access_to_Basic_Services table created in MySQL Workbench, we are interested in creating a table that contains only the geographic location data for each country. We can apply the same queries in MySQL Workbench and in this notebook if we connect to our MySQL server. Since we have a MySQL database, we can connect to it using mysql and pymysql.

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook. 
# If you get an error here, make sure that mysql and pymysql are installed correctly. 

# %load_ext sql

# %%
# Establish a connection to the local database using the '%sql' magic command.
# Replace 'password' with our connection password and `db_name` with our database name. 
# If you get an error here, please make sure the database name or password is correct.

# %sql mysql+pymysql://root:HardThings25@localhost:3306/united_nations

# %% [markdown]
# To make a query, we add the `%%sql` command to the start of a cell, create one open line, and then the query like below, and run the cell.

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     Access_to_Basic_Services
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 5 rows affected.
# [('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2015, Decimal('94.67'), Decimal('98.00'), Decimal('17.542806'), Decimal('184.39'), Decimal('2699700.00'), Decimal('4.93')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2016, Decimal('94.67'), Decimal('98.00'), Decimal('17.794055'), Decimal('137.28'), Decimal('2699700.00'), Decimal('4.96')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2017, Decimal('95.00'), Decimal('98.00'), Decimal('18.037776'), Decimal('166.81'), Decimal('2699700.00'), Decimal('4.90')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2018, Decimal('95.00'), Decimal('98.00'), Decimal('18.276452'), Decimal('179.34'), Decimal('2699700.00'), Decimal('4.85')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2019, Decimal('95.00'), Decimal('98.00'), Decimal('18.513673'), Decimal('181.67'), Decimal('2699700.00'), Decimal('4.80'))]

# %% [markdown]
# ## Exercise
#
# We want to do the following:
# 1. Create a table named `Geographic_Location`.
# 2. Extract the relevant columns from the `Access_to_Basic_Services` table into the `Geographic_Location` table.

# %% [markdown]
# ### 1. Create a table named Geographic_Location.
#
# Create a table named `Geographic_Location` with the columns `Country_name`, `Sub_region`, `Region`, and `Land_area`, with `Country_name` being the primary key.

# %%
# %%sql
# DROP TABLE  IF EXISTS Geographic_location;
# CREATE TABLE united_nations.Geographic_location(Country_Name VARCHAR(100) PRIMARY KEY,
#                                                 Sub_region VARCHAR(100),
#                                                 Region VARCHAR(100),
#                                                 Land_area INT)
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 0 rows affected.
# 0 rows affected.
# []

# %% [markdown]
# ### 2. Extract the relevant columns from the Access_to_Basic_Services table.
#
# Extract the columns `Country_name`, `Sub_region`, `Region`, and `Land_area` from the `Access_to_Basic_Services` table into the newly created `Geographic_Location` table.

# %%
# %%sql
# INSERT INTO Geographic_location(Country_name, Sub_region,Region, Land_area)
# SELECT
#     Country_name,
#     Sub_region,
#     Region,
#    AVG(Land_area) AS country_area
# FROM united_nations.Access_to_Basic_services
# GROUP BY country_name,Region, Sub_region
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 182 rows affected.
# []

# %%
# %%sql
# SELECT * FROM united_nations.geographic_location
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 182 rows affected.
# [('Afghanistan', 'Southern Asia', 'Central and Southern Asia', 652230),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', 2381741),
#  ('American Samoa', 'Polynesia', 'Oceania', 200),
#  ('Angola', 'Middle Africa', 'Sub-Saharan Africa', 1246700),
#  ('Anguilla', 'Caribbean', 'Latin America and the Caribbean', None),
#  ('Antigua and Barbuda', 'Caribbean', 'Latin America and the Caribbean', 440),
#  ('Argentina', 'South America', 'Latin America and the Caribbean', 2736690),
#  ('Armenia', 'Western Asia', 'Northern Africa and Western Asia', 28470),
#  ('Aruba', 'Caribbean', 'Latin America and the Caribbean', 180),
#  ('Australia', 'Australia and New Zealand', 'Oceania', 7690400),
#  ('Azerbaijan', 'Western Asia', 'Northern Africa and Western Asia', 82658),
#  ('Bahamas', 'Caribbean', 'Latin America and the Caribbean', None),
#  ('Bahrain', 'Western Asia', 'Northern Africa and Western Asia', 781),
#  ('Bangladesh', 'Southern Asia', 'Central and Southern Asia', 130170),
#  ('Barbados', 'Caribbean', 'Latin America and the Caribbean', 430),
#  ('Belize', 'Central America', 'Latin America and the Caribbean', 22810),
#  ('Benin', 'Western Africa', 'Sub-Saharan Africa', 112760),
#  ('Bermuda', 'Northern America', 'Europe and Northern America', 54),
#  ('Bhutan', 'Southern Asia', 'Central and Southern Asia', 38138),
#  ('Bolivia (Plurinational State of)', 'South America', 'Latin America and the Caribbean', None),
#  ('Botswana', 'Southern Africa', 'Sub-Saharan Africa', 566730),
#  ('Brazil', 'South America', 'Latin America and the Caribbean', 8358140),
#  ('British Virgin Islands', 'Caribbean', 'Latin America and the Caribbean', 150),
#  ('Brunei Darussalam', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', 5270),
#  ('Burkina Faso', 'Western Africa', 'Sub-Saharan Africa', 273600),
#  ('Burundi', 'Eastern Africa', 'Sub-Saharan Africa', 25680),
#  ('Cabo Verde', 'Western Africa', 'Sub-Saharan Africa', 4030),
#  ('Cambodia', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', 176520),
#  ('Cameroon', 'Middle Africa', 'Sub-Saharan Africa', 472710),
#  ('Canada', 'Northern America', 'Europe and Northern America', 8965590),
#  ('Cayman Islands', 'Caribbean', 'Latin America and the Caribbean', 240),
#  ('Central African Republic', 'Middle Africa', 'Sub-Saharan Africa', 622980),
#  ('Chad', 'Middle Africa', 'Sub-Saharan Africa', 1259200),
#  ('Chile', 'South America', 'Latin America and the Caribbean', 743532),
#  ('China', 'Eastern Asia', 'Eastern and South-Eastern Asia', 9424702),
#  ('Colombia', 'South America', 'Latin America and the Caribbean', 1109500),
#  ('Comoros', 'Eastern Africa', 'Sub-Saharan Africa', 1861),
#  ('Congo', 'Middle Africa', 'Sub-Saharan Africa', None),
#  ('Cook Islands', 'Polynesia', 'Oceania', None),
#  ('Costa Rica', 'Central America', 'Latin America and the Caribbean', 51060),
#  ("Côte d'Ivoire", 'Western Africa', 'Sub-Saharan Africa', None),
#  ('Cuba', 'Caribbean', 'Latin America and the Caribbean', 103890),
#  ('Curaçao', 'Caribbean', 'Latin America and the Caribbean', None),
#  ('Cyprus', 'Western Asia', 'Northern Africa and Western Asia', 9240),
#  ("Democratic People's Republic of Korea", 'Eastern Asia', 'Eastern and South-Eastern Asia', None),
#  ('Democratic Republic of the Congo', 'Middle Africa', 'Sub-Saharan Africa', None),
#  ('Djibouti', 'Eastern Africa', 'Sub-Saharan Africa', 23180),
#  ('Dominica', 'Caribbean', 'Latin America and the Caribbean', 750),
#  ('Dominican Republic', 'Caribbean', 'Latin America and the Caribbean', 48310),
#  ('Ecuador', 'South America', 'Latin America and the Caribbean', 248360),
#  ('Egypt', 'Northern Africa', 'Northern Africa and Western Asia', None),
#  ('El Salvador', 'Central America', 'Latin America and the Caribbean', 20720),
#  ('Equatorial Guinea', 'Middle Africa', 'Sub-Saharan Africa', 28050),
#  ('Eritrea', 'Eastern Africa', 'Sub-Saharan Africa', 121083),
#  ('Eswatini', 'Southern Africa', 'Sub-Saharan Africa', 17200),
#  ('Ethiopia', 'Eastern Africa', 'Sub-Saharan Africa', 1128559),
#  ('Falkland Islands (Malvinas)', 'South America', 'Latin America and the Caribbean', None),
#  ('Fiji', 'Melanesia', 'Oceania', 18270),
#  ('French Guiana', 'South America', 'Latin America and the Caribbean', None),
#  ('French Polynesia', 'Polynesia', 'Oceania', 3471),
#  ('Gabon', 'Middle Africa', 'Sub-Saharan Africa', 257670),
#  ('Gambia', 'Western Africa', 'Sub-Saharan Africa', None),
#  ('Georgia', 'Western Asia', 'Northern Africa and Western Asia', 69490),
#  ('Ghana', 'Western Africa', 'Sub-Saharan Africa', 227539),
#  ('Greenland', 'Northern America', 'Europe and Northern America', 410450),
#  ('Grenada', 'Caribbean', 'Latin America and the Caribbean', 340),
#  ('Guadeloupe', 'Caribbean', 'Latin America and the Caribbean', None),
#  ('Guam', 'Micronesia', 'Oceania', 540),
#  ('Guatemala', 'Central America', 'Latin America and the Caribbean', 107160),
#  ('Guinea', 'Western Africa', 'Sub-Saharan Africa', 245720),
#  ('Guinea-Bissau', 'Western Africa', 'Sub-Saharan Africa', 28120),
#  ('Guyana', 'South America', 'Latin America and the Caribbean', 196850),
#  ('Haiti', 'Caribbean', 'Latin America and the Caribbean', 27560),
#  ('Honduras', 'Central America', 'Latin America and the Caribbean', 111890),
#  ('India', 'Southern Asia', 'Central and Southern Asia', 2973190),
#  ('Indonesia', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', 1877519),
#  ('Iran (Islamic Republic of)', 'Southern Asia', 'Central and Southern Asia', None),
#  ('Iraq', 'Western Asia', 'Northern Africa and Western Asia', 434128),
#  ('Israel', 'Western Asia', 'Northern Africa and Western Asia', 21640),
#  ('Jamaica', 'Caribbean', 'Latin America and the Caribbean', 10830),
#  ('Japan', 'Eastern Asia', 'Eastern and South-Eastern Asia', 364500),
#  ('Jordan', 'Western Asia', 'Northern Africa and Western Asia', 88785),
#  ('Kazakhstan', 'Central Asia', 'Central and Southern Asia', 2699700),
#  ('Kenya', 'Eastern Africa', 'Sub-Saharan Africa', 569140),
#  ('Kiribati', 'Micronesia', 'Oceania', 810),
#  ('Kuwait', 'Western Asia', 'Northern Africa and Western Asia', 17820),
#  ('Kyrgyzstan', 'Central Asia', 'Central and Southern Asia', None),
#  ("Lao People's Democratic Republic", 'South-Eastern Asia', 'Eastern and South-Eastern Asia', None),
#  ('Lebanon', 'Western Asia', 'Northern Africa and Western Asia', 10230),
#  ('Lesotho', 'Southern Africa', 'Sub-Saharan Africa', 30360),
#  ('Liberia', 'Western Africa', 'Sub-Saharan Africa', 96320),
#  ('Libya', 'Northern Africa', 'Northern Africa and Western Asia', 1759540),
#  ('Madagascar', 'Eastern Africa', 'Sub-Saharan Africa', 581800),
#  ('Malawi', 'Eastern Africa', 'Sub-Saharan Africa', 94280),
#  ('Malaysia', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', 328550),
#  ('Maldives', 'Southern Asia', 'Central and Southern Asia', 300),
#  ('Mali', 'Western Africa', 'Sub-Saharan Africa', 1220190),
#  ('Marshall Islands', 'Micronesia', 'Oceania', 180),
#  ('Martinique', 'Caribbean', 'Latin America and the Caribbean', None),
#  ('Mauritania', 'Western Africa', 'Sub-Saharan Africa', 1030700),
#  ('Mauritius', 'Eastern Africa', 'Sub-Saharan Africa', 2030),
#  ('Mayotte', 'Eastern Africa', 'Sub-Saharan Africa', None),
#  ('Mexico', 'Central America', 'Latin America and the Caribbean', 1943950),
#  ('Micronesia (Federated States of)', 'Micronesia', 'Oceania', None),
#  ('Mongolia', 'Eastern Asia', 'Eastern and South-Eastern Asia', 1557298),
#  ('Montserrat', 'Caribbean', 'Latin America and the Caribbean', None),
#  ('Morocco', 'Northern Africa', 'Northern Africa and Western Asia', 446300),
#  ('Mozambique', 'Eastern Africa', 'Sub-Saharan Africa', 786380),
#  ('Myanmar', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', 652780),
#  ('Namibia', 'Southern Africa', 'Sub-Saharan Africa', 823290),
#  ('Nauru', 'Micronesia', 'Oceania', 20),
#  ('Nepal', 'Southern Asia', 'Central and Southern Asia', 143350),
#  ('New Caledonia', 'Melanesia', 'Oceania', 18280),
#  ('New Zealand', 'Australia and New Zealand', 'Oceania', 263310),
#  ('Nicaragua', 'Central America', 'Latin America and the Caribbean', 120340),
#  ('Niger', 'Western Africa', 'Sub-Saharan Africa', 1266700),
#  ('Nigeria', 'Western Africa', 'Sub-Saharan Africa', 910770),
#  ('Niue', 'Polynesia', 'Oceania', None),
#  ('Northern Mariana Islands', 'Micronesia', 'Oceania', 460),
#  ('Oman', 'Western Asia', 'Northern Africa and Western Asia', 309500),
#  ('Pakistan', 'Southern Asia', 'Central and Southern Asia', 770880),
#  ('Palau', 'Micronesia', 'Oceania', 460),
#  ('Panama', 'Central America', 'Latin America and the Caribbean', 74150),
#  ('Papua New Guinea', 'Melanesia', 'Oceania', 452860),
#  ('Paraguay', 'South America', 'Latin America and the Caribbean', 397300),
#  ('Peru', 'South America', 'Latin America and the Caribbean', 1280000),
#  ('Philippines', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', 298170),
#  ('Puerto Rico', 'Caribbean', 'Latin America and the Caribbean', 8870),
#  ('Qatar', 'Western Asia', 'Northern Africa and Western Asia', 11490),
#  ('Republic of Korea', 'Eastern Asia', 'Eastern and South-Eastern Asia', None),
#  ('Réunion', 'Eastern Africa', 'Sub-Saharan Africa', None),
#  ('Rwanda', 'Eastern Africa', 'Sub-Saharan Africa', 24670),
#  ('Saint Barthélemy', 'Caribbean', 'Latin America and the Caribbean', None),
#  ('Saint Helena', 'Western Africa', 'Sub-Saharan Africa', None),
#  ('Saint Kitts and Nevis', 'Caribbean', 'Latin America and the Caribbean', None),
#  ('Saint Lucia', 'Caribbean', 'Latin America and the Caribbean', None),
#  ('Saint Martin (French Part)', 'Caribbean', 'Latin America and the Caribbean', None),
#  ('Saint Pierre and Miquelon', 'Northern America', 'Europe and Northern America', None),
#  ('Saint Vincent and the Grenadines', 'Caribbean', 'Latin America and the Caribbean', None),
#  ('Samoa', 'Polynesia', 'Oceania', 2797),
#  ('Sao Tome and Principe', 'Middle Africa', 'Sub-Saharan Africa', 960),
#  ('Saudi Arabia', 'Western Asia', 'Northern Africa and Western Asia', 2149690),
#  ('Senegal', 'Western Africa', 'Sub-Saharan Africa', 192530),
#  ('Seychelles', 'Eastern Africa', 'Sub-Saharan Africa', 460),
#  ('Sierra Leone', 'Western Africa', 'Sub-Saharan Africa', 72180),
#  ('Singapore', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', 713),
#  ('Sint Maarten (Dutch part)', 'Caribbean', 'Latin America and the Caribbean', 34),
#  ('Solomon Islands', 'Melanesia', 'Oceania', 27990),
#  ('Somalia', 'Eastern Africa', 'Sub-Saharan Africa', 627340),
#  ('South Africa', 'Southern Africa', 'Sub-Saharan Africa', 1213090),
#  ('South Sudan', 'Eastern Africa', 'Sub-Saharan Africa', 631930),
#  ('Sri Lanka', 'Southern Asia', 'Central and Southern Asia', 61878),
#  ('State of Palestine', 'Western Asia', 'Northern Africa and Western Asia', None),
#  ('Sudan', 'Northern Africa', 'Northern Africa and Western Asia', 1868000),
#  ('Suriname', 'South America', 'Latin America and the Caribbean', 156000),
#  ('Syrian Arab Republic', 'Western Asia', 'Northern Africa and Western Asia', 183630),
#  ('Tajikistan', 'Central Asia', 'Central and Southern Asia', 138790),
#  ('Thailand', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', 510890),
#  ('Timor-Leste', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', 14870),
#  ('Togo', 'Western Africa', 'Sub-Saharan Africa', 54390),
#  ('Tokelau', 'Polynesia', 'Oceania', None),
#  ('Tonga', 'Polynesia', 'Oceania', 720),
#  ('Trinidad and Tobago', 'Caribbean', 'Latin America and the Caribbean', 5130),
#  ('Tunisia', 'Northern Africa', 'Northern Africa and Western Asia', 155360),
#  ('Türkiye', 'Western Asia', 'Northern Africa and Western Asia', None),
#  ('Turkmenistan', 'Central Asia', 'Central and Southern Asia', 469930),
#  ('Turks and Caicos Islands', 'Caribbean', 'Latin America and the Caribbean', 950),
#  ('Tuvalu', 'Polynesia', 'Oceania', 30),
#  ('Uganda', 'Eastern Africa', 'Sub-Saharan Africa', 200520),
#  ('United Arab Emirates', 'Western Asia', 'Northern Africa and Western Asia', 71020),
#  ('United Republic of Tanzania', 'Eastern Africa', 'Sub-Saharan Africa', None),
#  ('United States of America', 'Northern America', 'Europe and Northern America', None),
#  ('United States Virgin Islands', 'Caribbean', 'Latin America and the Caribbean', None),
#  ('Uruguay', 'South America', 'Latin America and the Caribbean', 175020),
#  ('Uzbekistan', 'Central Asia', 'Central and Southern Asia', 440595),
#  ('Vanuatu', 'Melanesia', 'Oceania', 12190),
#  ('Venezuela (Bolivarian Republic of)', 'South America', 'Latin America and the Caribbean', None),
#  ('Viet Nam', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', None),
#  ('Wallis and Futuna Islands', 'Polynesia', 'Oceania', None),
#  ('Yemen', 'Western Asia', 'Northern Africa and Western Asia', None),
#  ('Zambia', 'Eastern Africa', 'Sub-Saharan Africa', 743390),
#  ('Zimbabwe', 'Eastern Africa', 'Sub-Saharan Africa', 386850)]

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### 1. Create a table named Geographic_Location.

# %%
# %%sql
#
# CREATE TABLE united_nations.Geographic_Location (
#   Country_name VARCHAR(37) PRIMARY KEY,
#   Sub_region VARCHAR(25),
#   Region VARCHAR(32),
#   Land_area NUMERIC(10,2)
# );

# %% [markdown]
# Remember to create the primary constraint for the `Country_name` column since it will be the identifier for each unique country.

# %% [markdown]
# ### 2. Extract the relevant columns from the Access_to_Basic_Services table.

# %%
# %%sql
#
# INSERT INTO united_nations.Geographic_Location (Country_name, Sub_region, Region, Land_area)
# SELECT Country_name,
#     Sub_region,
#     Region,
#     AVG(Land_area) as Country_area
# FROM united_nations.Access_to_Basic_Services
# GROUP BY Country_name,
#     Sub_region,
#     Region;

# %% [markdown]
# Remember that we specified that the `Country_name` column serves as the primary key for the `Geographic_location` table.
# `Country_name`, however, is not a unique identifier and contains duplicate countries in the `Access_to_Basic_Services` table since the same country names have been recorded many times for various years. The same applies for `Sub_region` and `Region`.
#
# These duplicates will also be copied when the data of this column are transferred to the new `Geographic_Location` table. In order to obtain the unique entries, we must group the data by `Country_name`, `Sub_region`, and `Region`.
#
# By doing this, any "Duplicate entry for primary key" errors will be avoided.

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/refs/heads/master/ALX_banners/ALX_Navy.png"  style="width:100px"  ;/>
# </div>
