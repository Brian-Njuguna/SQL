# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img
#  src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/alx-courses/aice/assets/Content_page_banner_blue_dots.png"
#  alt="ALX Content Header"
#  class="full-width-image"
# />
# </div>

# %% [markdown]
# # Joins and set operations

# %% [markdown]
# In this exercise, we will use the skills we have learned so far to solve complex problems that involve string manipulation and handling.

# %% [markdown]
# ## Learning objectives
#
# In this exercise, we will:
# - Understand and use different types of SQL Joins to combine data from different tables.
# - Use `UNION`, `INTERSECT`, and `MINUS/EXCEPT` operators to combine rows from different tables.
# - Understand the difference between Joins and Unions/Intersections/Minus in terms of column-wise and row-wise concatenation.

# %% [markdown]
# First, let's load our sample database:

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook.
# %load_ext sql

# %%
# Load the Northwind database stored in your local machine. 
# Make sure the file is saved in the same folder as this notebook.
# %sql sqlite:///Northwind.db

# %% [markdown]
# Here is a view of all of our tables in the database:
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/Northwind_ERD.png"  style="width:70%";/>
# <br>
# <br>
#     <em>Figure 1: Northwind database ERD</em>
# </div>

# %% [markdown]
# ## Overview
# Run the necessary queries that will provide us with the following information. Compare your queries with the solutions at the end of this notebook.

# %% [markdown]
# ### Exercise 1
#
# Using the Northwind database, determine the list of products and their respective suppliers.

# %%
# %%sql
# SELECT
#     Suppliers.SupplierID,
#     Suppliers.CompanyName,
#     products.productName
# FROM Suppliers
# LEFT JOIN
#     Products
# ON suppliers.SupplierID = Products.SupplierID
# Out:
#  * sqlite:///Northwind.db
# Done.
# [(1, 'Exotic Liquids', 'Aniseed Syrup'),
#  (1, 'Exotic Liquids', 'Chai'),
#  (1, 'Exotic Liquids', 'Chang'),
#  (2, 'New Orleans Cajun Delights', "Chef Anton's Cajun Seasoning"),
#  (2, 'New Orleans Cajun Delights', "Chef Anton's Gumbo Mix"),
#  (2, 'New Orleans Cajun Delights', 'Louisiana Fiery Hot Pepper Sauce'),
#  (2, 'New Orleans Cajun Delights', 'Louisiana Hot Spiced Okra'),
#  (3, "Grandma Kelly's Homestead", "Grandma's Boysenberry Spread"),
#  (3, "Grandma Kelly's Homestead", 'Northwoods Cranberry Sauce'),
#  (3, "Grandma Kelly's Homestead", "Uncle Bob's Organic Dried Pears"),
#  (4, 'Tokyo Traders', 'Ikura'),
#  (4, 'Tokyo Traders', 'Longlife Tofu'),
#  (4, 'Tokyo Traders', 'Mishi Kobe Niku'),
#  (5, "Cooperativa de Quesos 'Las Cabras'", 'Queso Cabrales'),
#  (5, "Cooperativa de Quesos 'Las Cabras'", 'Queso Manchego La Pastora'),
#  (6, "Mayumi's", 'Genen Shouyu'),
#  (6, "Mayumi's", 'Konbu'),
#  (6, "Mayumi's", 'Tofu'),
#  (7, 'Pavlova, Ltd.', 'Alice Mutton'),
#  (7, 'Pavlova, Ltd.', 'Carnarvon Tigers'),
#  (7, 'Pavlova, Ltd.', 'Outback Lager'),
#  (7, 'Pavlova, Ltd.', 'Pavlova'),
#  (7, 'Pavlova, Ltd.', 'Vegie-spread'),
#  (8, 'Specialty Biscuits, Ltd.', 'Scottish Longbreads'),
#  (8, 'Specialty Biscuits, Ltd.', "Sir Rodney's Marmalade"),
#  (8, 'Specialty Biscuits, Ltd.', "Sir Rodney's Scones"),
#  (8, 'Specialty Biscuits, Ltd.', 'Teatime Chocolate Biscuits'),
#  (9, 'PB Knckebrd AB', "Gustaf's Knckebrd"),
#  (9, 'PB Knckebrd AB', 'Tunnbrd'),
#  (10, 'Refrescos Americanas LTDA', 'Guaran Fantstica'),
#  (11, 'Heli Swaren GmbH & Co. KG', 'Gumbr Gummibrchen'),
#  (11, 'Heli Swaren GmbH & Co. KG', 'NuNuCa Nu-Nougat-Creme'),
#  (11, 'Heli Swaren GmbH & Co. KG', 'Schoggi Schokolade'),
#  (12, 'Plutzer Lebensmittelgromrkte AG', 'Original Frankfurter grne Soe'),
#  (12, 'Plutzer Lebensmittelgromrkte AG', 'Rhnbru Klosterbier'),
#  (12, 'Plutzer Lebensmittelgromrkte AG', 'Rssle Sauerkraut'),
#  (12, 'Plutzer Lebensmittelgromrkte AG', 'Thringer Rostbratwurst'),
#  (12, 'Plutzer Lebensmittelgromrkte AG', 'Wimmers gute Semmelkndel'),
#  (13, 'Nord-Ost-Fisch Handelsgesellschaft mbH', 'Nord-Ost Matjeshering'),
#  (14, 'Formaggi Fortini s.r.l.', 'Gorgonzola Telino'),
#  (14, 'Formaggi Fortini s.r.l.', 'Mascarpone Fabioli'),
#  (14, 'Formaggi Fortini s.r.l.', 'Mozzarella di Giovanni'),
#  (15, 'Norske Meierier', 'Flotemysost'),
#  (15, 'Norske Meierier', 'Geitost'),
#  (15, 'Norske Meierier', 'Gudbrandsdalsost'),
#  (16, 'Bigfoot Breweries', 'Laughing Lumberjack Lager'),
#  (16, 'Bigfoot Breweries', 'Sasquatch Ale'),
#  (16, 'Bigfoot Breweries', 'Steeleye Stout'),
#  (17, 'Svensk Sjfda AB', 'Gravad lax'),
#  (17, 'Svensk Sjfda AB', 'Inlagd Sill'),
#  (17, 'Svensk Sjfda AB', 'Rd Kaviar'),
#  (18, 'Aux joyeux ecclsiastiques', 'Chartreuse verte'),
#  (18, 'Aux joyeux ecclsiastiques', 'Cte de Blaye'),
#  (19, 'New England Seafood Cannery', 'Boston Crab Meat'),
#  (19, 'New England Seafood Cannery', "Jack's New England Clam Chowder"),
#  (20, 'Leka Trading', 'Gula Malacca'),
#  (20, 'Leka Trading', 'Ipoh Coffee'),
#  (20, 'Leka Trading', 'Singaporean Hokkien Fried Mee'),
#  (21, 'Lyngbysild', 'Rogede sild'),
#  (21, 'Lyngbysild', 'Spegesild'),
#  (22, 'Zaanse Snoepfabriek', 'Chocolade'),
#  (22, 'Zaanse Snoepfabriek', 'Zaanse koeken'),
#  (23, 'Karkki Oy', 'Lakkalikri'),
#  (23, 'Karkki Oy', 'Maxilaku'),
#  (23, 'Karkki Oy', 'Valkoinen suklaa'),
#  (24, "G'day, Mate", 'Filo Mix'),
#  (24, "G'day, Mate", 'Manjimup Dried Apples'),
#  (24, "G'day, Mate", 'Perth Pasties'),
#  (25, 'Ma Maison', 'Pt chinois'),
#  (25, 'Ma Maison', 'Tourtire'),
#  (26, 'Pasta Buttini s.r.l.', 'Gnocchi di nonna Alice'),
#  (26, 'Pasta Buttini s.r.l.', 'Ravioli Angelo'),
#  (27, 'Escargots Nouveaux', 'Escargots de Bourgogne'),
#  (28, 'Gai pturage', 'Camembert Pierrot'),
#  (28, 'Gai pturage', 'Raclette Courdavault'),
#  (29, "Forts d'rables", "Sirop d'rable"),
#  (29, "Forts d'rables", 'Tarte au sucre')]

# %% [markdown]
# ### Exercise 2
#
# Generate a list of all cities where customers and employees are located.

# %%
# %%sql
# SELECT
#      Employees.city AS CITY
# FROM employees
# UNION ALL
# SELECT
#     Customers.city
# FROM customers
# Out:
#  * sqlite:///Northwind.db
# Done.
# [('Seattle',),
#  ('Tacoma',),
#  ('Kirkland',),
#  ('Redmond',),
#  ('London',),
#  ('London',),
#  ('London',),
#  ('Seattle',),
#  ('London',),
#  ('Berlin',),
#  ('Mxico D.F.',),
#  ('Mxico D.F.',),
#  ('London',),
#  ('Lule',),
#  ('Mannheim',),
#  ('Strasbourg',),
#  ('Madrid',),
#  ('Marseille',),
#  ('Tsawassen',),
#  ('London',),
#  ('Buenos Aires',),
#  ('Mxico D.F.',),
#  ('Bern',),
#  ('Sao Paulo',),
#  ('London',),
#  ('Aachen',),
#  ('Nantes',),
#  ('London',),
#  ('Graz',),
#  ('Sao Paulo',),
#  ('Madrid',),
#  ('Lille',),
#  ('Brcke',),
#  ('Mnchen',),
#  ('Nantes',),
#  ('Torino',),
#  ('Lisboa',),
#  ('Barcelona',),
#  ('Sevilla',),
#  ('Campinas',),
#  ('Eugene',),
#  ('Caracas',),
#  ('Rio de Janeiro',),
#  ('San Cristbal',),
#  ('Elgin',),
#  ('Cork',),
#  ('Cowes',),
#  ('Brandenburg',),
#  ('Versailles',),
#  ('Toulouse',),
#  ('Vancouver',),
#  ('Walla Walla',),
#  ('Frankfurt a.M.',),
#  ('San Francisco',),
#  ('Barquisimeto',),
#  ('I. de Margarita',),
#  ('Portland',),
#  ('Bergamo',),
#  ('Bruxelles',),
#  ('Montral',),
#  ('Leipzig',),
#  ('London',),
#  ('Buenos Aires',),
#  ('Anchorage',),
#  ('Kln',),
#  ('Paris',),
#  ('Mxico D.F.',),
#  ('Salzburg',),
#  ('Lisboa',),
#  ('Rio de Janeiro',),
#  ('Sao Paulo',),
#  ('Cunewalde',),
#  ('Buenos Aires',),
#  ('Albuquerque',),
#  ('Reggio Emilia',),
#  ('Rio de Janeiro',),
#  ('Genve',),
#  ('Madrid',),
#  ('Stavern',),
#  ('Boise',),
#  ('London',),
#  ('Kobenhavn',),
#  ('Paris',),
#  ('Lander',),
#  ('Charleroi',),
#  ('Portland',),
#  ('Butte',),
#  ('Mnster',),
#  ('Mxico D.F.',),
#  ('Sao Paulo',),
#  ('Kirkland',),
#  ('rhus',),
#  (None,),
#  (None,),
#  ('Lyon',),
#  ('Reims',),
#  ('Stuttgart',),
#  ('Oulu',),
#  ('Resende',),
#  ('Seattle',),
#  ('Helsinki',),
#  ('Warszawa',)]

# %% [markdown]
# ###  Exercise 3
#
# Create a list of all unique cities where customers are located and employees live.

# %%
# %%sql
# SELECT
#      Employees.city AS CITY
# FROM employees
# UNION ALL
# SELECT
#     Customers.city
# FROM customers
# Out:
#  * sqlite:///Northwind.db
# Done.
# [('Seattle',),
#  ('Tacoma',),
#  ('Kirkland',),
#  ('Redmond',),
#  ('London',),
#  ('London',),
#  ('London',),
#  ('Seattle',),
#  ('London',),
#  ('Berlin',),
#  ('Mxico D.F.',),
#  ('Mxico D.F.',),
#  ('London',),
#  ('Lule',),
#  ('Mannheim',),
#  ('Strasbourg',),
#  ('Madrid',),
#  ('Marseille',),
#  ('Tsawassen',),
#  ('London',),
#  ('Buenos Aires',),
#  ('Mxico D.F.',),
#  ('Bern',),
#  ('Sao Paulo',),
#  ('London',),
#  ('Aachen',),
#  ('Nantes',),
#  ('London',),
#  ('Graz',),
#  ('Sao Paulo',),
#  ('Madrid',),
#  ('Lille',),
#  ('Brcke',),
#  ('Mnchen',),
#  ('Nantes',),
#  ('Torino',),
#  ('Lisboa',),
#  ('Barcelona',),
#  ('Sevilla',),
#  ('Campinas',),
#  ('Eugene',),
#  ('Caracas',),
#  ('Rio de Janeiro',),
#  ('San Cristbal',),
#  ('Elgin',),
#  ('Cork',),
#  ('Cowes',),
#  ('Brandenburg',),
#  ('Versailles',),
#  ('Toulouse',),
#  ('Vancouver',),
#  ('Walla Walla',),
#  ('Frankfurt a.M.',),
#  ('San Francisco',),
#  ('Barquisimeto',),
#  ('I. de Margarita',),
#  ('Portland',),
#  ('Bergamo',),
#  ('Bruxelles',),
#  ('Montral',),
#  ('Leipzig',),
#  ('London',),
#  ('Buenos Aires',),
#  ('Anchorage',),
#  ('Kln',),
#  ('Paris',),
#  ('Mxico D.F.',),
#  ('Salzburg',),
#  ('Lisboa',),
#  ('Rio de Janeiro',),
#  ('Sao Paulo',),
#  ('Cunewalde',),
#  ('Buenos Aires',),
#  ('Albuquerque',),
#  ('Reggio Emilia',),
#  ('Rio de Janeiro',),
#  ('Genve',),
#  ('Madrid',),
#  ('Stavern',),
#  ('Boise',),
#  ('London',),
#  ('Kobenhavn',),
#  ('Paris',),
#  ('Lander',),
#  ('Charleroi',),
#  ('Portland',),
#  ('Butte',),
#  ('Mnster',),
#  ('Mxico D.F.',),
#  ('Sao Paulo',),
#  ('Kirkland',),
#  ('rhus',),
#  (None,),
#  (None,),
#  ('Lyon',),
#  ('Reims',),
#  ('Stuttgart',),
#  ('Oulu',),
#  ('Resende',),
#  ('Seattle',),
#  ('Helsinki',),
#  ('Warszawa',)]

# %% [markdown]
# ### 4. Challenge question
#
# Using the Northwind database, as the new sales analyst, you've been asked to prepare a sales report for the last quarter. Your report should include:
# 1. Customer names and their countries.
# 2. The total amount spent by each customer.
# 3. The list of products each customer purchased.
# 4. The total quantity of each product purchased by each customer.
#
# Only include customers who have spent more than 5000 in the last quarter.

# %%
# %%sql
# SELECT
#     c.ContactName,
#     c.Country,
#     p.ProductName AS P_Name,
#     ROUND(SUM(od.UnitPrice * od.Quantity)) AS Total_amount,
#     SUM(od.Quantity) AS total_quantity
# FROM Customers c
# JOIN Orders o
#     ON c.CustomerID = o.CustomerID
# JOIN OrderDetails od
#     ON o.OrderID = od.OrderID
# JOIN Products p
#     ON od.ProductID = p.ProductID
# WHERE
#     o.OrderDate BETWEEN '1996-08-01' AND '1998-01-30'
# GROUP BY
#     c.ContactName,
#     c.Country,
#     p.ProductName
# HAVING
#     SUM(od.Quantity*od.UnitPrice) > 5000;
# Out:
#  * sqlite:///Northwind.db
# Done.
# [('Georg Pipps', 'Austria', 'Cte de Blaye', 10540.0, 50),
#  ('Horst Kloss', 'Germany', 'Camembert Pierrot', 6222.0, 194),
#  ('Horst Kloss', 'Germany', 'Cte de Blaye', 7905.0, 30),
#  ('Horst Kloss', 'Germany', 'Schoggi Schokolade', 5268.0, 120),
#  ('Howard Snyder', 'USA', 'Cte de Blaye', 11858.0, 45),
#  ('Jean Fresnire', 'Canada', 'Cte de Blaye', 10329.0, 49),
#  ('Jose Pavarotti', 'USA', 'Thringer Rostbratwurst', 6832.0, 60),
#  ('Jytte Petersen', 'Denmark', 'Cte de Blaye', 10540.0, 50),
#  ('Lcia Carvalho', 'Brazil', 'Cte de Blaye', 8432.0, 40),
#  ('Patricia McKenna', 'Ireland', 'Raclette Courdavault', 5830.0, 112),
#  ('Paula Wilson', 'USA', 'Cte de Blaye', 6324.0, 30),
#  ('Paula Wilson', 'USA', 'Tarte au sucre', 6208.0, 145),
#  ('Philip Cramer', 'Germany', 'Cte de Blaye', 7905.0, 30),
#  ('Roland Mendel', 'Austria', 'Manjimup Dried Apples', 6360.0, 120)]

# %% [markdown]
# ### Exercise 1
#
# This query combines rows from `Products` and `Suppliers` tables based on the condition where `Products.SupplierID` equals `Suppliers.SupplierID`.
#
# Expected outcome: The result should be a table that includes columns for `ProductName` and `SupplierName` which shows the products and their respective suppliers.

# %%
# %%sql
#
# SELECT
#     product.ProductName,
#     supplier.CompanyName
# FROM
#     Products AS product
# INNER JOIN
#     Suppliers AS supplier
#     ON product.SupplierID = supplier.SupplierID;
# Out:
#  * sqlite:///Northwind.db
# Done.
# [('Chai', 'Exotic Liquids'),
#  ('Chang', 'Exotic Liquids'),
#  ('Aniseed Syrup', 'Exotic Liquids'),
#  ("Chef Anton's Cajun Seasoning", 'New Orleans Cajun Delights'),
#  ("Chef Anton's Gumbo Mix", 'New Orleans Cajun Delights'),
#  ("Grandma's Boysenberry Spread", "Grandma Kelly's Homestead"),
#  ("Uncle Bob's Organic Dried Pears", "Grandma Kelly's Homestead"),
#  ('Northwoods Cranberry Sauce', "Grandma Kelly's Homestead"),
#  ('Mishi Kobe Niku', 'Tokyo Traders'),
#  ('Ikura', 'Tokyo Traders'),
#  ('Queso Cabrales', "Cooperativa de Quesos 'Las Cabras'"),
#  ('Queso Manchego La Pastora', "Cooperativa de Quesos 'Las Cabras'"),
#  ('Konbu', "Mayumi's"),
#  ('Tofu', "Mayumi's"),
#  ('Genen Shouyu', "Mayumi's"),
#  ('Pavlova', 'Pavlova, Ltd.'),
#  ('Alice Mutton', 'Pavlova, Ltd.'),
#  ('Carnarvon Tigers', 'Pavlova, Ltd.'),
#  ('Teatime Chocolate Biscuits', 'Specialty Biscuits, Ltd.'),
#  ("Sir Rodney's Marmalade", 'Specialty Biscuits, Ltd.'),
#  ("Sir Rodney's Scones", 'Specialty Biscuits, Ltd.'),
#  ("Gustaf's Knckebrd", 'PB Knckebrd AB'),
#  ('Tunnbrd', 'PB Knckebrd AB'),
#  ('Guaran Fantstica', 'Refrescos Americanas LTDA'),
#  ('NuNuCa Nu-Nougat-Creme', 'Heli Swaren GmbH & Co. KG'),
#  ('Gumbr Gummibrchen', 'Heli Swaren GmbH & Co. KG'),
#  ('Schoggi Schokolade', 'Heli Swaren GmbH & Co. KG'),
#  ('Rssle Sauerkraut', 'Plutzer Lebensmittelgromrkte AG'),
#  ('Thringer Rostbratwurst', 'Plutzer Lebensmittelgromrkte AG'),
#  ('Nord-Ost Matjeshering', 'Nord-Ost-Fisch Handelsgesellschaft mbH'),
#  ('Gorgonzola Telino', 'Formaggi Fortini s.r.l.'),
#  ('Mascarpone Fabioli', 'Formaggi Fortini s.r.l.'),
#  ('Geitost', 'Norske Meierier'),
#  ('Sasquatch Ale', 'Bigfoot Breweries'),
#  ('Steeleye Stout', 'Bigfoot Breweries'),
#  ('Inlagd Sill', 'Svensk Sjfda AB'),
#  ('Gravad lax', 'Svensk Sjfda AB'),
#  ('Cte de Blaye', 'Aux joyeux ecclsiastiques'),
#  ('Chartreuse verte', 'Aux joyeux ecclsiastiques'),
#  ('Boston Crab Meat', 'New England Seafood Cannery'),
#  ("Jack's New England Clam Chowder", 'New England Seafood Cannery'),
#  ('Singaporean Hokkien Fried Mee', 'Leka Trading'),
#  ('Ipoh Coffee', 'Leka Trading'),
#  ('Gula Malacca', 'Leka Trading'),
#  ('Rogede sild', 'Lyngbysild'),
#  ('Spegesild', 'Lyngbysild'),
#  ('Zaanse koeken', 'Zaanse Snoepfabriek'),
#  ('Chocolade', 'Zaanse Snoepfabriek'),
#  ('Maxilaku', 'Karkki Oy'),
#  ('Valkoinen suklaa', 'Karkki Oy'),
#  ('Manjimup Dried Apples', "G'day, Mate"),
#  ('Filo Mix', "G'day, Mate"),
#  ('Perth Pasties', "G'day, Mate"),
#  ('Tourtire', 'Ma Maison'),
#  ('Pt chinois', 'Ma Maison'),
#  ('Gnocchi di nonna Alice', 'Pasta Buttini s.r.l.'),
#  ('Ravioli Angelo', 'Pasta Buttini s.r.l.'),
#  ('Escargots de Bourgogne', 'Escargots Nouveaux'),
#  ('Raclette Courdavault', 'Gai pturage'),
#  ('Camembert Pierrot', 'Gai pturage'),
#  ("Sirop d'rable", "Forts d'rables"),
#  ('Tarte au sucre', "Forts d'rables"),
#  ('Vegie-spread', 'Pavlova, Ltd.'),
#  ('Wimmers gute Semmelkndel', 'Plutzer Lebensmittelgromrkte AG'),
#  ('Louisiana Fiery Hot Pepper Sauce', 'New Orleans Cajun Delights'),
#  ('Louisiana Hot Spiced Okra', 'New Orleans Cajun Delights'),
#  ('Laughing Lumberjack Lager', 'Bigfoot Breweries'),
#  ('Scottish Longbreads', 'Specialty Biscuits, Ltd.'),
#  ('Gudbrandsdalsost', 'Norske Meierier'),
#  ('Outback Lager', 'Pavlova, Ltd.'),
#  ('Flotemysost', 'Norske Meierier'),
#  ('Mozzarella di Giovanni', 'Formaggi Fortini s.r.l.'),
#  ('Rd Kaviar', 'Svensk Sjfda AB'),
#  ('Longlife Tofu', 'Tokyo Traders'),
#  ('Rhnbru Klosterbier', 'Plutzer Lebensmittelgromrkte AG'),
#  ('Lakkalikri', 'Karkki Oy'),
#  ('Original Frankfurter grne Soe', 'Plutzer Lebensmittelgromrkte AG')]

# %% [markdown]
# ### Exercise 2
#
# The `UNION` operator is used to combine the results of two `SELECT` statements. It removes duplicate rows from the results.
#
# Expected outcome: A single column table of unique cities where customers and employees are located.

# %%
# %%sql
#
# SELECT
#     City
# FROM
#     Customers
# UNION
# SELECT
#     City
# FROM
#     Employees;
# Out:
#  * sqlite:///Northwind.db
# Done.
# [(None,),
#  ('Aachen',),
#  ('Albuquerque',),
#  ('Anchorage',),
#  ('Barcelona',),
#  ('Barquisimeto',),
#  ('Bergamo',),
#  ('Berlin',),
#  ('Bern',),
#  ('Boise',),
#  ('Brandenburg',),
#  ('Brcke',),
#  ('Bruxelles',),
#  ('Buenos Aires',),
#  ('Butte',),
#  ('Campinas',),
#  ('Caracas',),
#  ('Charleroi',),
#  ('Cork',),
#  ('Cowes',),
#  ('Cunewalde',),
#  ('Elgin',),
#  ('Eugene',),
#  ('Frankfurt a.M.',),
#  ('Genve',),
#  ('Graz',),
#  ('Helsinki',),
#  ('I. de Margarita',),
#  ('Kirkland',),
#  ('Kln',),
#  ('Kobenhavn',),
#  ('Lander',),
#  ('Leipzig',),
#  ('Lille',),
#  ('Lisboa',),
#  ('London',),
#  ('Lule',),
#  ('Lyon',),
#  ('Madrid',),
#  ('Mannheim',),
#  ('Marseille',),
#  ('Mnchen',),
#  ('Mnster',),
#  ('Montral',),
#  ('Mxico D.F.',),
#  ('Nantes',),
#  ('Oulu',),
#  ('Paris',),
#  ('Portland',),
#  ('Redmond',),
#  ('Reggio Emilia',),
#  ('Reims',),
#  ('Resende',),
#  ('Rio de Janeiro',),
#  ('Salzburg',),
#  ('San Cristbal',),
#  ('San Francisco',),
#  ('Sao Paulo',),
#  ('Seattle',),
#  ('Sevilla',),
#  ('Stavern',),
#  ('Strasbourg',),
#  ('Stuttgart',),
#  ('Tacoma',),
#  ('Torino',),
#  ('Toulouse',),
#  ('Tsawassen',),
#  ('Vancouver',),
#  ('Versailles',),
#  ('Walla Walla',),
#  ('Warszawa',),
#  ('rhus',)]

# %% [markdown]
# ###  Exercise 3
#
# The `JOIN` query returns cities that are common in both `Customers` and `Employees` tables (i.e. it looks for matches). On the other hand, the `UNION` query returns a list of all unique cities in both tables, eliminating any duplicates.
#
# Expected outcome: Two sets of outputs – one for the `JOIN` query and another for the `UNION` query.

# %%
# %%sql
#
# SELECT
#     Customers.City
# FROM
#     Customers
# INNER JOIN
#     Employees
#     ON Customers.City = Employees.City;
#
#
# SELECT
#     City
# FROM
#     Customers
# UNION
# SELECT
#     City
# FROM
#     Employees;
# Out:
#  * sqlite:///Northwind.db
# Done.
# Done.
# [(None,),
#  ('Aachen',),
#  ('Albuquerque',),
#  ('Anchorage',),
#  ('Barcelona',),
#  ('Barquisimeto',),
#  ('Bergamo',),
#  ('Berlin',),
#  ('Bern',),
#  ('Boise',),
#  ('Brandenburg',),
#  ('Brcke',),
#  ('Bruxelles',),
#  ('Buenos Aires',),
#  ('Butte',),
#  ('Campinas',),
#  ('Caracas',),
#  ('Charleroi',),
#  ('Cork',),
#  ('Cowes',),
#  ('Cunewalde',),
#  ('Elgin',),
#  ('Eugene',),
#  ('Frankfurt a.M.',),
#  ('Genve',),
#  ('Graz',),
#  ('Helsinki',),
#  ('I. de Margarita',),
#  ('Kirkland',),
#  ('Kln',),
#  ('Kobenhavn',),
#  ('Lander',),
#  ('Leipzig',),
#  ('Lille',),
#  ('Lisboa',),
#  ('London',),
#  ('Lule',),
#  ('Lyon',),
#  ('Madrid',),
#  ('Mannheim',),
#  ('Marseille',),
#  ('Mnchen',),
#  ('Mnster',),
#  ('Montral',),
#  ('Mxico D.F.',),
#  ('Nantes',),
#  ('Oulu',),
#  ('Paris',),
#  ('Portland',),
#  ('Redmond',),
#  ('Reggio Emilia',),
#  ('Reims',),
#  ('Resende',),
#  ('Rio de Janeiro',),
#  ('Salzburg',),
#  ('San Cristbal',),
#  ('San Francisco',),
#  ('Sao Paulo',),
#  ('Seattle',),
#  ('Sevilla',),
#  ('Stavern',),
#  ('Strasbourg',),
#  ('Stuttgart',),
#  ('Tacoma',),
#  ('Torino',),
#  ('Toulouse',),
#  ('Tsawassen',),
#  ('Vancouver',),
#  ('Versailles',),
#  ('Walla Walla',),
#  ('Warszawa',),
#  ('rhus',)]

# %% [markdown]
# ### 4. Challenge question

# %%
# %%sql
#
# SELECT
#     customer.ContactName,
#     customer.Country,
#     SUM(orderDetails.Quantity * orderDetails.UnitPrice) AS TotalSalesAmount,
#     product.ProductName,
#     SUM(orderDetails.Quantity) AS TotalUnitsSold
# FROM
#     Customers AS customer
# JOIN
#     Orders AS orders
#     ON customer.CustomerID = orders.CustomerID
# JOIN
#     OrderDetails AS orderDetails
#     ON orders.OrderID = orderDetails.OrderID
# JOIN
#     Products AS product
#     ON orderDetails.ProductID = product.ProductID
# WHERE
#     orders.OrderDate BETWEEN '1996-08-01' AND '1998-01-30'
# GROUP BY
#     customer.ContactName,
#     customer.Country,
#     product.ProductName
# HAVING
#     SUM(orderDetails.Quantity * orderDetails.UnitPrice) > 5000;
# Out:
#  * sqlite:///Northwind.db
# Done.
# [('Georg Pipps', 'Austria', 10540.0, 'Cte de Blaye', 50),
#  ('Horst Kloss', 'Germany', 6222.0, 'Camembert Pierrot', 194),
#  ('Horst Kloss', 'Germany', 7905.0, 'Cte de Blaye', 30),
#  ('Horst Kloss', 'Germany', 5268.0, 'Schoggi Schokolade', 120),
#  ('Howard Snyder', 'USA', 11857.5, 'Cte de Blaye', 45),
#  ('Jean Fresnire', 'Canada', 10329.2, 'Cte de Blaye', 49),
#  ('Jose Pavarotti', 'USA', 6832.4400000000005, 'Thringer Rostbratwurst', 60),
#  ('Jytte Petersen', 'Denmark', 10540.0, 'Cte de Blaye', 50),
#  ('Lcia Carvalho', 'Brazil', 8432.0, 'Cte de Blaye', 40),
#  ('Patricia McKenna', 'Ireland', 5830, 'Raclette Courdavault', 112),
#  ('Paula Wilson', 'USA', 6324.0, 'Cte de Blaye', 30),
#  ('Paula Wilson', 'USA', 6208.0, 'Tarte au sucre', 145),
#  ('Philip Cramer', 'Germany', 7905.0, 'Cte de Blaye', 30),
#  ('Roland Mendel', 'Austria', 6360, 'Manjimup Dried Apples', 120)]

# %% [markdown]
# This problem involves pulling data from multiple tables (`Customers`, `Orders`, `OrderDetails`, and `Products`) to create a detailed report. It's testing your ability to use `JOINS`, aggregate functions, grouping, and the `HAVING` clause.
#
# Here's how to break down the problem:
#
# 1. **Identify the tables you need to pull data from**: For this problem, you'll need data from the `Customers`, `Orders`, `OrderDetails`, and `Products` tables.
# 2. **Join these tables**: Use SQL joins to connect these tables. The `Orders` table is connected to `Customers` via `CustomerID`. The `OrderDetails` table is connected to `Orders` via `OrderID` and to `Products` via `ProductID`.
# 3. **Filter the data**: Use the `WHERE` clause to filter orders to only include those from the last quarter ('2023-04-01' to '2023-06-30').
# 4. **Aggregate the data**: Aggregate functions are needed to calculate the total amount spent by each customer (SUM of `Quantity` * `UnitPrice`) and the total quantity of each product purchased by each customer (`SUM` of `Quantity`). This is done in the `SELECT` clause.
# 5. **Group the data**: Use the `GROUP BY` clause to segment the data by `CustomerName`, `Country`, and `ProductName`.
# 6. **Apply a condition on an aggregate:** Lastly, use the `HAVING` clause to include only customers who have spent more than 5000 in the last quarter. Remember, when you want to use a condition on an aggregate, you should use the `HAVING` clause, not the `WHERE` clause. The `WHERE` clause is used to filter rows, while the `HAVING` clause is used to filter groups.
#
# The result is a detailed report with customer names, their countries, the total amount spent by each customer, the list of products each customer purchased, and the total quantity of each product purchased by each customer for the last quarter. Only customers who spent more than 5000 are included.

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/refs/heads/master/ALX_banners/ALX_Navy.png"  style="width:100px"  ;/>
# </div>
