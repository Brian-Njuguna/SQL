# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img
#  src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/alx-courses/aice/assets/Content_page_banner_blue_dots.png"
#  alt="ALX Content Header"
#  class="full-width-image"
# />
# </div>

# %% [markdown]
# # Control flow functions

# %% [markdown]
# In this exercise, we'll use control flow functions to break down a complex problem into its fundamental components.

# %% [markdown]
# ## Learning objectives
#
# In this train, we will learn to:
# - Use the `IIF` control function to check for a certain condition and return a value for each scenario.
# - Use the `CASE` statement to categorise data in an existing column.

# %% [markdown]
# First, let's load our sample database:

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook.
# %load_ext sql

# %%
# Load the Northwind database stored in your local machine. 
# Make sure the file is saved in the same folder as this notebook.
# %sql sqlite:///Northwind.db

# %% [markdown]
# Here is a view of all of our tables in the database:
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/Northwind_ERD.png"  style="width:70%";/>
# <br>
# <br>
#     <em>Figure 1: Northwind database ERD</em>
# </div>

# %% [markdown]
# ## Exercise

# %% [markdown]
# ### 1. Categorise employees based on salaries
#
# Using the `Employees` table in the Northwind database, write a SQL query that returns a list of all employees along with a column `HighSalary` that shows 'Yes' if the employee's salary is above \$50,000 and 'No' otherwise.

# %%
# %%sql
# SELECT
# CONCAT(
#     FirstName,' ',
#     lastName) AS Employees_name,
# IF(SALARY > 50000,'Yes','No') HighSalary
#
# FROM Employees;
# Out:
#  * sqlite:///Northwind.db
# Done.
# [('Nancy Davolio', 'No'),
#  ('Andrew Fuller', 'No'),
#  ('Janet Leverling', 'No'),
#  ('Margaret Peacock', 'No'),
#  ('Steven Buchanan', 'No'),
#  ('Michael Suyama', 'No'),
#  ('Robert King', 'No'),
#  ('Laura Callahan', 'No'),
#  ('Anne Dodsworth', 'No')]

# %% [markdown]
# ### 2. Categorise orders based on quantity
#
# Based on the `OrderDetails` table, write a SQL query that categorises orders into 'Small', 'Medium', or 'Large' based on the order quantity: Small (less than 20), Medium (between 20 and 100), and Large (more than 100).

# %%
# %%sql
# SELECT
#     OrderId,
#     Quantity,
# CASE WHEN Quantity < 20
#     THEN 'Small'
#     WHEN Quantity BETWEEN 20  AND 100
#     THEN 'Medium'
#     ELSE 'Large'
# END AS Size_of_Order
# FROM OrderdETAILS;
# Out:
#  * sqlite:///Northwind.db
# Done.
# [(10248, 12, 'Small'),
#  (10248, 10, 'Small'),
#  (10248, 5, 'Small'),
#  (10249, 9, 'Small'),
#  (10249, 40, 'Medium'),
#  (10250, 10, 'Small'),
#  (10250, 35, 'Medium'),
#  (10250, 15, 'Small'),
#  (10251, 6, 'Small'),
#  (10251, 15, 'Small'),
#  (10251, 20, 'Medium'),
#  (10252, 40, 'Medium'),
#  (10252, 25, 'Medium'),
#  (10252, 40, 'Medium'),
#  (10253, 20, 'Medium'),
#  (10253, 42, 'Medium'),
#  (10253, 40, 'Medium'),
#  (10254, 15, 'Small'),
#  (10254, 21, 'Medium'),
#  (10254, 21, 'Medium'),
#  (10255, 20, 'Medium'),
#  (10255, 35, 'Medium'),
#  (10255, 25, 'Medium'),
#  (10255, 30, 'Medium'),
#  (10256, 15, 'Small'),
#  (10256, 12, 'Small'),
#  (10257, 25, 'Medium'),
#  (10257, 6, 'Small'),
#  (10257, 15, 'Small'),
#  (10258, 50, 'Medium'),
#  (10258, 65, 'Medium'),
#  (10258, 6, 'Small'),
#  (10259, 10, 'Small'),
#  (10259, 1, 'Small'),
#  (10260, 16, 'Small'),
#  (10260, 50, 'Medium'),
#  (10260, 15, 'Small'),
#  (10260, 21, 'Medium'),
#  (10261, 20, 'Medium'),
#  (10261, 20, 'Medium'),
#  (10262, 12, 'Small'),
#  (10262, 15, 'Small'),
#  (10262, 2, 'Small'),
#  (10263, 60, 'Medium'),
#  (10263, 28, 'Medium'),
#  (10263, 60, 'Medium'),
#  (10263, 36, 'Medium'),
#  (10264, 35, 'Medium'),
#  (10264, 25, 'Medium'),
#  (10265, 30, 'Medium'),
#  (10265, 20, 'Medium'),
#  (10266, 12, 'Small'),
#  (10267, 50, 'Medium'),
#  (10267, 70, 'Medium'),
#  (10267, 15, 'Small'),
#  (10268, 10, 'Small'),
#  (10268, 4, 'Small'),
#  (10269, 60, 'Medium'),
#  (10269, 20, 'Medium'),
#  (10270, 30, 'Medium'),
#  (10270, 25, 'Medium'),
#  (10271, 24, 'Medium'),
#  (10272, 6, 'Small'),
#  (10272, 40, 'Medium'),
#  (10272, 24, 'Medium'),
#  (10273, 24, 'Medium'),
#  (10273, 15, 'Small'),
#  (10273, 20, 'Medium'),
#  (10273, 60, 'Medium'),
#  (10273, 33, 'Medium'),
#  (10274, 20, 'Medium'),
#  (10274, 7, 'Small'),
#  (10275, 12, 'Small'),
#  (10275, 6, 'Small'),
#  (10276, 15, 'Small'),
#  (10276, 10, 'Small'),
#  (10277, 20, 'Medium'),
#  (10277, 12, 'Small'),
#  (10278, 16, 'Small'),
#  (10278, 15, 'Small'),
#  (10278, 8, 'Small'),
#  (10278, 25, 'Medium'),
#  (10279, 15, 'Small'),
#  (10280, 12, 'Small'),
#  (10280, 20, 'Medium'),
#  (10280, 30, 'Medium'),
#  (10281, 1, 'Small'),
#  (10281, 6, 'Small'),
#  (10281, 4, 'Small'),
#  (10282, 6, 'Small'),
#  (10282, 2, 'Small'),
#  (10283, 20, 'Medium'),
#  (10283, 18, 'Small'),
#  (10283, 35, 'Medium'),
#  (10283, 3, 'Small'),
#  (10284, 15, 'Small'),
#  (10284, 21, 'Medium'),
#  (10284, 20, 'Medium'),
#  (10284, 5, 'Small'),
#  (10285, 45, 'Medium'),
#  (10285, 40, 'Medium'),
#  (10285, 36, 'Medium'),
#  (10286, 100, 'Medium'),
#  (10286, 40, 'Medium'),
#  (10287, 40, 'Medium'),
#  (10287, 20, 'Medium'),
#  (10287, 15, 'Small'),
#  (10288, 10, 'Small'),
#  (10288, 3, 'Small'),
#  (10289, 30, 'Medium'),
#  (10289, 9, 'Small'),
#  (10290, 20, 'Medium'),
#  (10290, 15, 'Small'),
#  (10290, 15, 'Small'),
#  (10290, 10, 'Small'),
#  (10291, 20, 'Medium'),
#  (10291, 24, 'Medium'),
#  (10291, 2, 'Small'),
#  (10292, 20, 'Medium'),
#  (10293, 12, 'Small'),
#  (10293, 10, 'Small'),
#  (10293, 5, 'Small'),
#  (10293, 6, 'Small'),
#  (10294, 18, 'Small'),
#  (10294, 15, 'Small'),
#  (10294, 15, 'Small'),
#  (10294, 21, 'Medium'),
#  (10294, 6, 'Small'),
#  (10295, 4, 'Small'),
#  (10296, 12, 'Small'),
#  (10296, 30, 'Medium'),
#  (10296, 15, 'Small'),
#  (10297, 60, 'Medium'),
#  (10297, 20, 'Medium'),
#  (10298, 40, 'Medium'),
#  (10298, 40, 'Medium'),
#  (10298, 30, 'Medium'),
#  (10298, 15, 'Small'),
#  (10299, 15, 'Small'),
#  (10299, 20, 'Medium'),
#  (10300, 30, 'Medium'),
#  (10300, 20, 'Medium'),
#  (10301, 10, 'Small'),
#  (10301, 20, 'Medium'),
#  (10302, 40, 'Medium'),
#  (10302, 28, 'Medium'),
#  (10302, 12, 'Small'),
#  (10303, 40, 'Medium'),
#  (10303, 30, 'Medium'),
#  (10303, 15, 'Small'),
#  (10304, 30, 'Medium'),
#  (10304, 10, 'Small'),
#  (10304, 2, 'Small'),
#  (10305, 25, 'Medium'),
#  (10305, 25, 'Medium'),
#  (10305, 30, 'Medium'),
#  (10306, 10, 'Small'),
#  (10306, 10, 'Small'),
#  (10306, 5, 'Small'),
#  (10307, 10, 'Small'),
#  (10307, 3, 'Small'),
#  (10308, 1, 'Small'),
#  (10308, 5, 'Small'),
#  (10309, 20, 'Medium'),
#  (10309, 30, 'Medium'),
#  (10309, 2, 'Small'),
#  (10309, 20, 'Medium'),
#  (10309, 3, 'Small'),
#  (10310, 10, 'Small'),
#  (10310, 5, 'Small'),
#  (10311, 6, 'Small'),
#  (10311, 7, 'Small'),
#  (10312, 4, 'Small'),
#  (10312, 24, 'Medium'),
#  (10312, 20, 'Medium'),
#  (10312, 10, 'Small'),
#  (10313, 12, 'Small'),
#  (10314, 40, 'Medium'),
#  (10314, 30, 'Medium'),
#  (10314, 25, 'Medium'),
#  (10315, 14, 'Small'),
#  (10315, 30, 'Medium'),
#  (10316, 10, 'Small'),
#  (10316, 70, 'Medium'),
#  (10317, 20, 'Medium'),
#  (10318, 20, 'Medium'),
#  (10318, 6, 'Small'),
#  (10319, 8, 'Small'),
#  (10319, 14, 'Small'),
#  (10319, 30, 'Medium'),
#  (10320, 30, 'Medium'),
#  (10321, 10, 'Small'),
#  (10322, 20, 'Medium'),
#  (10323, 5, 'Small'),
#  (10323, 4, 'Small'),
#  (10323, 4, 'Small'),
#  (10324, 21, 'Medium'),
#  (10324, 70, 'Medium'),
#  (10324, 30, 'Medium'),
#  (10324, 40, 'Medium'),
#  (10324, 80, 'Medium'),
#  (10325, 6, 'Small'),
#  (10325, 12, 'Small'),
#  (10325, 9, 'Small'),
#  (10325, 4, 'Small'),
#  (10325, 40, 'Medium'),
#  (10326, 24, 'Medium'),
#  (10326, 16, 'Small'),
#  (10326, 50, 'Medium'),
#  (10327, 25, 'Medium'),
#  (10327, 50, 'Medium'),
#  (10327, 35, 'Medium'),
#  (10327, 30, 'Medium'),
#  (10328, 9, 'Small'),
#  (10328, 40, 'Medium'),
#  (10328, 10, 'Small'),
#  (10329, 10, 'Small'),
#  (10329, 8, 'Small'),
#  (10329, 20, 'Medium'),
#  (10329, 12, 'Small'),
#  (10330, 50, 'Medium'),
#  (10330, 25, 'Medium'),
#  (10331, 15, 'Small'),
#  (10332, 40, 'Medium'),
#  (10332, 10, 'Small'),
#  (10332, 16, 'Small'),
#  (10333, 10, 'Small'),
#  (10333, 10, 'Small'),
#  (10333, 40, 'Medium'),
#  (10334, 8, 'Small'),
#  (10334, 10, 'Small'),
#  (10335, 7, 'Small'),
#  (10335, 25, 'Medium'),
#  (10335, 6, 'Small'),
#  (10335, 48, 'Medium'),
#  (10336, 18, 'Small'),
#  (10337, 40, 'Medium'),
#  (10337, 24, 'Medium'),
#  (10337, 20, 'Medium'),
#  (10337, 28, 'Medium'),
#  (10337, 25, 'Medium'),
#  (10338, 20, 'Medium'),
#  (10338, 15, 'Small'),
#  (10339, 10, 'Small'),
#  (10339, 70, 'Medium'),
#  (10339, 28, 'Medium'),
#  (10340, 20, 'Medium'),
#  (10340, 12, 'Small'),
#  (10340, 40, 'Medium'),
#  (10341, 8, 'Small'),
#  (10341, 9, 'Small'),
#  (10342, 24, 'Medium'),
#  (10342, 56, 'Medium'),
#  (10342, 40, 'Medium'),
#  (10342, 40, 'Medium'),
#  (10343, 50, 'Medium'),
#  (10343, 4, 'Small'),
#  (10343, 15, 'Small'),
#  (10344, 35, 'Medium'),
#  (10344, 70, 'Medium'),
#  (10345, 70, 'Medium'),
#  (10345, 80, 'Medium'),
#  (10345, 9, 'Small'),
#  (10346, 36, 'Medium'),
#  (10346, 20, 'Medium'),
#  (10347, 10, 'Small'),
#  (10347, 50, 'Medium'),
#  (10347, 4, 'Small'),
#  (10347, 6, 'Small'),
#  (10348, 15, 'Small'),
#  (10348, 25, 'Medium'),
#  (10349, 24, 'Medium'),
#  (10350, 15, 'Small'),
#  (10350, 18, 'Small'),
#  (10351, 20, 'Medium'),
#  (10351, 13, 'Small'),
#  (10351, 77, 'Medium'),
#  (10351, 10, 'Small'),
#  (10352, 10, 'Small'),
#  (10352, 20, 'Medium'),
#  (10353, 12, 'Small'),
#  (10353, 50, 'Medium'),
#  (10354, 12, 'Small'),
#  (10354, 4, 'Small'),
#  (10355, 25, 'Medium'),
#  (10355, 25, 'Medium'),
#  (10356, 30, 'Medium'),
#  (10356, 12, 'Small'),
#  (10356, 20, 'Medium'),
#  (10357, 30, 'Medium'),
#  (10357, 16, 'Small'),
#  (10357, 8, 'Small'),
#  (10358, 10, 'Small'),
#  (10358, 10, 'Small'),
#  (10358, 20, 'Medium'),
#  (10359, 56, 'Medium'),
#  (10359, 70, 'Medium'),
#  (10359, 80, 'Medium'),
#  (10360, 30, 'Medium'),
#  (10360, 35, 'Medium'),
#  (10360, 10, 'Small'),
#  (10360, 35, 'Medium'),
#  (10360, 28, 'Medium'),
#  (10361, 54, 'Medium'),
#  (10361, 55, 'Medium'),
#  (10362, 50, 'Medium'),
#  (10362, 20, 'Medium'),
#  (10362, 24, 'Medium'),
#  (10363, 20, 'Medium'),
#  (10363, 12, 'Small'),
#  (10363, 12, 'Small'),
#  (10364, 30, 'Medium'),
#  (10364, 5, 'Small'),
#  (10365, 24, 'Medium'),
#  (10366, 5, 'Small'),
#  (10366, 5, 'Small'),
#  (10367, 36, 'Medium'),
#  (10367, 18, 'Small'),
#  (10367, 15, 'Small'),
#  (10367, 7, 'Small'),
#  (10368, 5, 'Small'),
#  (10368, 13, 'Small'),
#  (10368, 25, 'Medium'),
#  (10368, 35, 'Medium'),
#  (10369, 20, 'Medium'),
#  (10369, 18, 'Small'),
#  (10370, 15, 'Small'),
#  (10370, 30, 'Medium'),
#  (10370, 20, 'Medium'),
#  (10371, 6, 'Small'),
#  (10372, 12, 'Small'),
#  (10372, 40, 'Medium'),
#  (10372, 70, 'Medium'),
#  (10372, 42, 'Medium'),
#  (10373, 80, 'Medium'),
#  (10373, 50, 'Medium'),
#  (10374, 30, 'Medium'),
#  (10374, 15, 'Small'),
#  (10375, 15, 'Small'),
#  (10375, 10, 'Small'),
#  (10376, 42, 'Medium'),
#  (10377, 20, 'Medium'),
#  (10377, 20, 'Medium'),
#  (10378, 6, 'Small'),
#  (10379, 8, 'Small'),
#  (10379, 16, 'Small'),
#  (10379, 20, 'Medium'),
#  (10380, 18, 'Small'),
#  (10380, 20, 'Medium'),
#  (10380, 6, 'Small'),
#  (10380, 30, 'Medium'),
#  (10381, 14, 'Small'),
#  (10382, 32, 'Medium'),
#  (10382, 9, 'Small'),
#  (10382, 14, 'Small'),
#  (10382, 60, 'Medium'),
#  (10382, 50, 'Medium'),
#  (10383, 20, 'Medium'),
#  (10383, 15, 'Small'),
#  (10383, 20, 'Medium'),
#  (10384, 28, 'Medium'),
#  (10384, 15, 'Small'),
#  (10385, 10, 'Small'),
#  (10385, 20, 'Medium'),
#  (10385, 8, 'Small'),
#  (10386, 15, 'Small'),
#  (10386, 10, 'Small'),
#  (10387, 15, 'Small'),
#  (10387, 6, 'Small'),
#  (10387, 12, 'Small'),
#  (10387, 15, 'Small'),
#  (10388, 15, 'Small'),
#  (10388, 20, 'Medium'),
#  (10388, 40, 'Medium'),
#  (10389, 16, 'Small'),
#  (10389, 15, 'Small'),
#  (10389, 20, 'Medium'),
#  (10389, 30, 'Medium'),
#  (10390, 60, 'Medium'),
#  (10390, 40, 'Medium'),
#  (10390, 45, 'Medium'),
#  (10390, 24, 'Medium'),
#  (10391, 18, 'Small'),
#  (10392, 50, 'Medium'),
#  (10393, 25, 'Medium'),
#  (10393, 42, 'Medium'),
#  (10393, 7, 'Small'),
#  (10393, 70, 'Medium'),
#  (10393, 32, 'Medium'),
#  (10394, 10, 'Small'),
#  (10394, 10, 'Small'),
#  (10395, 28, 'Medium'),
#  (10395, 70, 'Medium'),
#  (10395, 8, 'Small'),
#  (10396, 40, 'Medium'),
#  (10396, 60, 'Medium'),
#  (10396, 21, 'Medium'),
#  (10397, 10, 'Small'),
#  (10397, 18, 'Small'),
#  (10398, 30, 'Medium'),
#  (10398, 120, 'Large'),
#  (10399, 60, 'Medium'),
#  (10399, 30, 'Medium'),
#  (10399, 35, 'Medium'),
#  (10399, 14, 'Small'),
#  (10400, 21, 'Medium'),
#  (10400, 35, 'Medium'),
#  (10400, 30, 'Medium'),
#  (10401, 18, 'Small'),
#  (10401, 70, 'Medium'),
#  (10401, 20, 'Medium'),
#  (10401, 60, 'Medium'),
#  (10402, 60, 'Medium'),
#  (10402, 65, 'Medium'),
#  (10403, 21, 'Medium'),
#  (10403, 70, 'Medium'),
#  (10404, 30, 'Medium'),
#  (10404, 40, 'Medium'),
#  (10404, 30, 'Medium'),
#  (10405, 50, 'Medium'),
#  (10406, 10, 'Small'),
#  (10406, 30, 'Medium'),
#  (10406, 42, 'Medium'),
#  (10406, 5, 'Small'),
#  (10406, 2, 'Small'),
#  (10407, 30, 'Medium'),
#  (10407, 15, 'Small'),
#  (10407, 15, 'Small'),
#  (10408, 10, 'Small'),
#  (10408, 6, 'Small'),
#  (10408, 35, 'Medium'),
#  (10409, 12, 'Small'),
#  (10409, 12, 'Small'),
#  (10410, 49, 'Medium'),
#  (10410, 16, 'Small'),
#  (10411, 25, 'Medium'),
#  (10411, 40, 'Medium'),
#  (10411, 9, 'Small'),
#  (10412, 20, 'Medium'),
#  (10413, 24, 'Medium'),
#  (10413, 40, 'Medium'),
#  (10413, 14, 'Small'),
#  (10414, 18, 'Small'),
#  (10414, 50, 'Medium'),
#  (10415, 2, 'Small'),
#  (10415, 20, 'Medium'),
#  (10416, 20, 'Medium'),
#  (10416, 10, 'Small'),
#  (10416, 20, 'Medium'),
#  (10417, 50, 'Medium'),
#  (10417, 2, 'Small'),
#  (10417, 36, 'Medium'),
#  (10417, 35, 'Medium'),
#  (10418, 60, 'Medium'),
#  (10418, 55, 'Medium'),
#  (10418, 16, 'Small'),
#  (10418, 15, 'Small'),
#  (10419, 60, 'Medium'),
#  (10419, 20, 'Medium'),
#  (10420, 20, 'Medium'),
#  (10420, 2, 'Small'),
#  (10420, 8, 'Small'),
#  (10420, 20, 'Medium'),
#  (10421, 4, 'Small'),
#  (10421, 30, 'Medium'),
#  (10421, 15, 'Small'),
#  (10421, 10, 'Small'),
#  (10422, 2, 'Small'),
#  (10423, 14, 'Small'),
#  (10423, 20, 'Medium'),
#  (10424, 60, 'Medium'),
#  (10424, 49, 'Medium'),
#  (10424, 30, 'Medium'),
#  (10425, 10, 'Small'),
#  (10425, 20, 'Medium'),
#  (10426, 5, 'Small'),
#  (10426, 7, 'Small'),
#  (10427, 35, 'Medium'),
#  (10428, 20, 'Medium'),
#  (10429, 40, 'Medium'),
#  (10429, 35, 'Medium'),
#  (10430, 45, 'Medium'),
#  (10430, 50, 'Medium'),
#  (10430, 30, 'Medium'),
#  (10430, 70, 'Medium'),
#  (10431, 50, 'Medium'),
#  (10431, 50, 'Medium'),
#  (10431, 30, 'Medium'),
#  (10432, 10, 'Small'),
#  (10432, 40, 'Medium'),
#  (10433, 28, 'Medium'),
#  (10434, 6, 'Small'),
#  (10434, 18, 'Small'),
#  (10435, 10, 'Small'),
#  (10435, 12, 'Small'),
#  (10435, 10, 'Small'),
#  (10436, 5, 'Small'),
#  (10436, 40, 'Medium'),
#  (10436, 30, 'Medium'),
#  (10436, 24, 'Medium'),
#  (10437, 15, 'Small'),
#  (10438, 15, 'Small'),
#  (10438, 20, 'Medium'),
#  (10438, 15, 'Small'),
#  (10439, 15, 'Small'),
#  (10439, 16, 'Small'),
#  (10439, 6, 'Small'),
#  (10439, 30, 'Medium'),
#  (10440, 45, 'Medium'),
#  (10440, 49, 'Medium'),
#  (10440, 24, 'Medium'),
#  (10440, 90, 'Medium'),
#  (10441, 50, 'Medium'),
#  (10442, 30, 'Medium'),
#  (10442, 80, 'Medium'),
#  (10442, 60, 'Medium'),
#  (10443, 6, 'Small'),
#  (10443, 12, 'Small'),
#  (10444, 10, 'Small'),
#  (10444, 15, 'Small'),
#  (10444, 8, 'Small'),
#  (10444, 30, 'Medium'),
#  (10445, 6, 'Small'),
#  (10445, 15, 'Small'),
#  (10446, 12, 'Small'),
#  (10446, 20, 'Medium'),
#  (10446, 3, 'Small'),
#  (10446, 15, 'Small'),
#  (10447, 40, 'Medium'),
#  (10447, 35, 'Medium'),
#  (10447, 2, 'Small'),
#  (10448, 6, 'Small'),
#  (10448, 20, 'Medium'),
#  (10449, 14, 'Small'),
#  (10449, 20, 'Medium'),
#  (10449, 35, 'Medium'),
#  (10450, 20, 'Medium'),
#  (10450, 6, 'Small'),
#  (10451, 120, 'Large'),
#  (10451, 35, 'Medium'),
#  (10451, 28, 'Medium'),
#  (10451, 55, 'Medium'),
#  (10452, 15, 'Small'),
#  (10452, 100, 'Medium'),
#  (10453, 15, 'Small'),
#  (10453, 25, 'Medium'),
#  (10454, 20, 'Medium'),
#  (10454, 20, 'Medium'),
#  (10454, 10, 'Small'),
#  (10455, 20, 'Medium'),
#  (10455, 50, 'Medium'),
#  (10455, 25, 'Medium'),
#  (10455, 30, 'Medium'),
#  (10456, 40, 'Medium'),
#  (10456, 21, 'Medium'),
#  (10457, 36, 'Medium'),
#  (10458, 30, 'Medium'),
#  (10458, 30, 'Medium'),
#  (10458, 20, 'Medium'),
#  (10458, 15, 'Small'),
#  (10458, 50, 'Medium'),
#  (10459, 16, 'Small'),
#  (10459, 20, 'Medium'),
#  (10459, 40, 'Medium'),
#  (10460, 21, 'Medium'),
#  (10460, 4, 'Small'),
#  (10461, 40, 'Medium'),
#  (10461, 28, 'Medium'),
#  (10461, 60, 'Medium'),
#  (10462, 1, 'Small'),
#  (10462, 21, 'Medium'),
#  (10463, 21, 'Medium'),
#  (10463, 50, 'Medium'),
#  (10464, 16, 'Small'),
#  (10464, 3, 'Small'),
#  (10464, 30, 'Medium'),
#  (10464, 20, 'Medium'),
#  (10465, 25, 'Medium'),
#  (10465, 18, 'Small'),
#  (10465, 20, 'Medium'),
#  (10465, 30, 'Medium'),
#  (10465, 25, 'Medium'),
#  (10466, 10, 'Small'),
#  (10466, 5, 'Small'),
#  (10467, 28, 'Medium'),
#  (10467, 12, 'Small'),
#  (10468, 8, 'Small'),
#  (10468, 15, 'Small'),
#  (10469, 40, 'Medium'),
#  (10469, 35, 'Medium'),
#  (10469, 2, 'Small'),
#  (10470, 30, 'Medium'),
#  (10470, 15, 'Small'),
#  (10470, 8, 'Small'),
#  (10471, 30, 'Medium'),
#  (10471, 20, 'Medium'),
#  (10472, 80, 'Medium'),
#  (10472, 18, 'Small'),
#  (10473, 12, 'Small'),
#  (10473, 12, 'Small'),
#  (10474, 12, 'Small'),
#  (10474, 18, 'Small'),
#  (10474, 21, 'Medium'),
#  (10474, 10, 'Small'),
#  (10475, 35, 'Medium'),
#  (10475, 60, 'Medium'),
#  (10475, 42, 'Medium'),
#  (10476, 2, 'Small'),
#  (10476, 12, 'Small'),
#  (10477, 15, 'Small'),
#  (10477, 21, 'Medium'),
#  (10477, 20, 'Medium'),
#  (10478, 20, 'Medium'),
#  (10479, 30, 'Medium'),
#  (10479, 28, 'Medium'),
#  (10479, 60, 'Medium'),
#  (10479, 30, 'Medium'),
#  (10480, 30, 'Medium'),
#  (10480, 12, 'Small'),
#  (10481, 24, 'Medium'),
#  (10481, 40, 'Medium'),
#  (10482, 10, 'Small'),
#  (10483, 35, 'Medium'),
#  (10483, 30, 'Medium'),
#  (10484, 14, 'Small'),
#  (10484, 10, 'Small'),
#  (10484, 3, 'Small'),
#  (10485, 20, 'Medium'),
#  (10485, 20, 'Medium'),
#  (10485, 30, 'Medium'),
#  (10485, 60, 'Medium'),
#  (10486, 5, 'Small'),
#  (10486, 25, 'Medium'),
#  (10486, 16, 'Small'),
#  (10487, 5, 'Small'),
#  (10487, 30, 'Medium'),
#  (10487, 24, 'Medium'),
#  (10488, 30, 'Medium'),
#  (10488, 20, 'Medium'),
#  (10489, 15, 'Small'),
#  (10489, 18, 'Small'),
#  (10490, 60, 'Medium'),
#  (10490, 30, 'Medium'),
#  (10490, 36, 'Medium'),
#  (10491, 15, 'Small'),
#  (10491, 7, 'Small'),
#  (10492, 60, 'Medium'),
#  (10492, 20, 'Medium'),
#  (10493, 15, 'Small'),
#  (10493, 10, 'Small'),
#  (10493, 10, 'Small'),
#  (10494, 30, 'Medium'),
#  (10495, 10, 'Small'),
#  (10495, 20, 'Medium'),
#  (10495, 5, 'Small'),
#  (10496, 20, 'Medium'),
#  (10497, 14, 'Small'),
#  (10497, 25, 'Medium'),
#  (10497, 25, 'Medium'),
#  (10498, 14, 'Small'),
#  (10498, 5, 'Small'),
#  (10498, 30, 'Medium'),
#  (10499, 20, 'Medium'),
#  (10499, 25, 'Medium'),
#  (10500, 12, 'Small'),
#  (10500, 8, 'Small'),
#  (10501, 20, 'Medium'),
#  (10502, 21, 'Medium'),
#  (10502, 6, 'Small'),
#  (10502, 30, 'Medium'),
#  (10503, 70, 'Medium'),
#  (10503, 20, 'Medium'),
#  (10504, 12, 'Small'),
#  (10504, 12, 'Small'),
#  (10504, 10, 'Small'),
#  (10504, 25, 'Medium'),
#  (10505, 3, 'Small'),
#  (10506, 18, 'Small'),
#  (10506, 14, 'Small'),
#  (10507, 15, 'Small'),
#  (10507, 15, 'Small'),
#  (10508, 10, 'Small'),
#  (10508, 10, 'Small'),
#  (10509, 3, 'Small'),
#  (10510, 36, 'Medium'),
#  (10510, 36, 'Medium'),
#  (10511, 50, 'Medium'),
#  (10511, 50, 'Medium'),
#  (10511, 10, 'Small'),
#  (10512, 10, 'Small'),
#  (10512, 9, 'Small'),
#  (10512, 6, 'Small'),
#  (10512, 12, 'Small'),
#  (10513, 40, 'Medium'),
#  (10513, 50, 'Medium'),
#  (10513, 15, 'Small'),
#  (10514, 39, 'Medium'),
#  (10514, 35, 'Medium'),
#  (10514, 70, 'Medium'),
#  (10514, 39, 'Medium'),
#  (10514, 50, 'Medium'),
#  (10515, 16, 'Small'),
#  (10515, 50, 'Medium'),
#  (10515, 120, 'Large'),
#  (10515, 16, 'Small'),
#  (10515, 84, 'Medium'),
#  (10516, 25, 'Medium'),
#  (10516, 80, 'Medium'),
#  (10516, 20, 'Medium'),
#  (10517, 6, 'Small'),
#  (10517, 4, 'Small'),
#  (10517, 6, 'Small'),
#  (10518, 5, 'Small'),
#  (10518, 15, 'Small'),
#  (10518, 9, 'Small'),
#  (10519, 16, 'Small'),
#  (10519, 40, 'Medium'),
#  (10519, 10, 'Small'),
#  (10520, 8, 'Small'),
#  (10520, 5, 'Small'),
#  (10521, 3, 'Small'),
#  (10521, 10, 'Small'),
#  (10521, 6, 'Small'),
#  (10522, 40, 'Medium'),
#  (10522, 24, 'Medium'),
#  (10522, 20, 'Medium'),
#  (10522, 25, 'Medium'),
#  (10523, 25, 'Medium'),
#  (10523, 15, 'Small'),
#  (10523, 18, 'Small'),
#  (10523, 6, 'Small'),
#  (10524, 2, 'Small'),
#  (10524, 10, 'Small'),
#  (10524, 60, 'Medium'),
#  (10524, 15, 'Small'),
#  (10525, 30, 'Medium'),
#  (10525, 15, 'Small'),
#  (10526, 8, 'Small'),
#  (10526, 10, 'Small'),
#  (10526, 30, 'Medium'),
#  (10527, 50, 'Medium'),
#  (10527, 30, 'Medium'),
#  (10528, 3, 'Small'),
#  (10528, 8, 'Small'),
#  (10528, 9, 'Small'),
#  (10529, 14, 'Small'),
#  (10529, 20, 'Medium'),
#  (10529, 10, 'Small'),
#  (10530, 40, 'Medium'),
#  (10530, 25, 'Medium'),
#  (10530, 20, 'Medium'),
#  (10530, 50, 'Medium'),
#  (10531, 2, 'Small'),
#  (10532, 15, 'Small'),
#  (10532, 24, 'Medium'),
#  (10533, 50, 'Medium'),
#  (10533, 24, 'Medium'),
#  (10533, 24, 'Medium'),
#  (10534, 10, 'Small'),
#  (10534, 10, 'Small'),
#  (10534, 10, 'Small'),
#  (10535, 50, 'Medium'),
#  (10535, 10, 'Small'),
#  (10535, 5, 'Small'),
#  (10535, 15, 'Small'),
#  (10536, 15, 'Small'),
#  (10536, 20, 'Medium'),
#  (10536, 30, 'Medium'),
#  (10536, 35, 'Medium'),
#  (10537, 30, 'Medium'),
#  (10537, 6, 'Small'),
#  (10537, 20, 'Medium'),
#  (10537, 21, 'Medium'),
#  (10537, 9, 'Small'),
#  (10538, 7, 'Small'),
#  (10538, 1, 'Small'),
#  (10539, 8, 'Small'),
#  (10539, 15, 'Small'),
#  (10539, 15, 'Small'),
#  (10539, 6, 'Small'),
#  (10540, 60, 'Medium'),
#  (10540, 40, 'Medium'),
#  (10540, 30, 'Medium'),
#  (10540, 35, 'Medium'),
#  (10541, 35, 'Medium'),
#  (10541, 4, 'Small'),
#  (10541, 36, 'Medium'),
#  (10541, 9, 'Small'),
#  (10542, 15, 'Small'),
#  (10542, 24, 'Medium'),
#  (10543, 30, 'Medium'),
#  (10543, 70, 'Medium'),
#  (10544, 7, 'Small'),
#  (10544, 7, 'Small'),
#  (10545, 10, 'Small'),
#  (10546, 10, 'Small'),
#  (10546, 30, 'Medium'),
#  (10546, 40, 'Medium'),
#  (10547, 24, 'Medium'),
#  (10547, 60, 'Medium'),
#  (10548, 10, 'Small'),
#  (10548, 14, 'Small'),
#  (10549, 55, 'Medium'),
#  (10549, 100, 'Medium'),
#  (10549, 48, 'Medium'),
#  (10550, 8, 'Small'),
#  (10550, 10, 'Small'),
#  (10550, 6, 'Small'),
#  (10550, 10, 'Small'),
#  (10551, 40, 'Medium'),
#  (10551, 20, 'Medium'),
#  (10551, 40, 'Medium'),
#  (10552, 18, 'Small'),
#  (10552, 30, 'Medium'),
#  (10553, 15, 'Small'),
#  (10553, 14, 'Small'),
#  (10553, 24, 'Medium'),
#  (10553, 30, 'Medium'),
#  (10553, 6, 'Small'),
#  (10554, 30, 'Medium'),
#  (10554, 20, 'Medium'),
#  (10554, 20, 'Medium'),
#  (10554, 10, 'Small'),
#  (10555, 30, 'Medium'),
#  (10555, 35, 'Medium'),
#  (10555, 18, 'Small'),
#  (10555, 20, 'Medium'),
#  (10555, 40, 'Medium'),
#  (10556, 24, 'Medium'),
#  (10557, 30, 'Medium'),
#  (10557, 20, 'Medium'),
#  (10558, 25, 'Medium'),
#  (10558, 20, 'Medium'),
#  (10558, 30, 'Medium'),
#  (10558, 18, 'Small'),
#  (10558, 3, 'Small'),
#  (10559, 12, 'Small'),
#  (10559, 18, 'Small'),
#  (10560, 20, 'Medium'),
#  (10560, 15, 'Small'),
#  (10561, 10, 'Small'),
#  (10561, 50, 'Medium'),
#  (10562, 20, 'Medium'),
#  (10562, 10, 'Small'),
#  (10563, 25, 'Medium'),
#  (10563, 70, 'Medium'),
#  (10564, 16, 'Small'),
#  (10564, 6, 'Small'),
#  (10564, 25, 'Medium'),
#  (10565, 25, 'Medium'),
#  (10565, 18, 'Small'),
#  (10566, 35, 'Medium'),
#  (10566, 18, 'Small'),
#  (10566, 10, 'Small'),
#  (10567, 60, 'Medium'),
#  (10567, 3, 'Small'),
#  (10567, 40, 'Medium'),
#  (10568, 5, 'Small'),
#  (10569, 35, 'Medium'),
#  (10569, 30, 'Medium'),
#  (10570, 15, 'Small'),
#  (10570, 60, 'Medium'),
#  (10571, 11, 'Small'),
#  (10571, 28, 'Medium'),
#  (10572, 12, 'Small'),
#  (10572, 10, 'Small'),
#  (10572, 50, 'Medium'),
#  (10572, 15, 'Small'),
#  (10573, 18, 'Small'),
#  (10573, 40, 'Medium'),
#  (10573, 25, 'Medium'),
#  (10574, 14, 'Small'),
#  (10574, 2, 'Small'),
#  (10574, 10, 'Small'),
#  (10574, 6, 'Small'),
#  (10575, 12, 'Small'),
#  (10575, 6, 'Small'),
#  (10575, 30, 'Medium'),
#  (10575, 10, 'Small'),
#  (10576, 10, 'Small'),
#  (10576, 20, 'Medium'),
#  (10576, 21, 'Medium'),
#  (10577, 10, 'Small'),
#  (10577, 20, 'Medium'),
#  (10577, 18, 'Small'),
#  (10578, 20, 'Medium'),
#  (10578, 6, 'Small'),
#  (10579, 10, 'Small'),
#  (10579, 21, 'Medium'),
#  (10580, 15, 'Small'),
#  (10580, 9, 'Small'),
#  (10580, 30, 'Medium'),
#  (10581, 50, 'Medium'),
#  (10582, 4, 'Small'),
#  (10582, 14, 'Small'),
#  (10583, 10, 'Small'),
#  (10583, 24, 'Medium'),
#  (10583, 10, 'Small'),
#  (10584, 50, 'Medium'),
#  (10585, 15, 'Small'),
#  (10586, 4, 'Small'),
#  (10587, 6, 'Small'),
#  (10587, 20, 'Medium'),
#  (10587, 20, 'Medium'),
#  (10588, 40, 'Medium'),
#  (10588, 100, 'Medium'),
#  (10589, 4, 'Small'),
#  (10590, 20, 'Medium'),
#  (10590, 60, 'Medium'),
#  (10591, 14, 'Small'),
#  (10591, 10, 'Small'),
#  (10591, 50, 'Medium'),
#  (10592, 25, 'Medium'),
#  (10592, 5, 'Small'),
#  (10593, 21, 'Medium'),
#  (10593, 20, 'Medium'),
#  (10593, 4, 'Small'),
#  (10594, 24, 'Medium'),
#  (10594, 30, 'Medium'),
#  (10595, 30, 'Medium'),
#  (10595, 120, 'Large'),
#  (10595, 65, 'Medium'),
#  (10596, 5, 'Small'),
#  (10596, 24, 'Medium'),
#  (10596, 30, 'Medium'),
#  (10597, 35, 'Medium'),
#  (10597, 20, 'Medium'),
#  (10597, 12, 'Small'),
#  (10598, 50, 'Medium'),
#  (10598, 9, 'Small'),
#  (10599, 10, 'Small'),
#  (10600, 4, 'Small'),
#  (10600, 30, 'Medium'),
#  (10601, 60, 'Medium'),
#  (10601, 35, 'Medium'),
#  (10602, 5, 'Small'),
#  (10603, 48, 'Medium'),
#  (10603, 25, 'Medium'),
#  (10604, 6, 'Small'),
#  (10604, 10, 'Small'),
#  (10605, 30, 'Medium'),
#  (10605, 20, 'Medium'),
#  (10605, 70, 'Medium'),
#  (10605, 15, 'Small'),
#  (10606, 20, 'Medium'),
#  (10606, 20, 'Medium'),
#  (10606, 10, 'Small'),
#  (10607, 45, 'Medium'),
#  (10607, 100, 'Medium'),
#  (10607, 14, 'Small'),
#  (10607, 42, 'Medium'),
#  (10607, 12, 'Small'),
#  (10608, 28, 'Medium'),
#  (10609, 3, 'Small'),
#  (10609, 10, 'Small'),
#  (10609, 6, 'Small'),
#  (10610, 21, 'Medium'),
#  (10611, 6, 'Small'),
#  (10611, 10, 'Small'),
#  (10611, 15, 'Small'),
#  (10612, 70, 'Medium'),
#  (10612, 55, 'Medium'),
#  (10612, 18, 'Small'),
#  (10612, 40, 'Medium'),
#  (10612, 80, 'Medium'),
#  (10613, 8, 'Small'),
#  (10613, 40, 'Medium'),
#  (10614, 14, 'Small'),
#  (10614, 8, 'Small'),
#  (10614, 5, 'Small'),
#  (10615, 5, 'Small'),
#  (10616, 15, 'Small'),
#  (10616, 14, 'Small'),
#  (10616, 15, 'Small'),
#  (10616, 15, 'Small'),
#  (10617, 30, 'Medium'),
#  (10618, 70, 'Medium'),
#  (10618, 20, 'Medium'),
#  (10618, 15, 'Small'),
#  (10619, 42, 'Medium'),
#  (10619, 40, 'Medium'),
#  (10620, 5, 'Small'),
#  (10620, 5, 'Small'),
#  (10621, 5, 'Small'),
#  (10621, 10, 'Small'),
#  (10621, 20, 'Medium'),
#  (10621, 15, 'Small'),
#  (10622, 20, 'Medium'),
#  (10622, 18, 'Small'),
#  (10623, 21, 'Medium'),
#  (10623, 15, 'Small'),
#  (10623, 25, 'Medium'),
#  (10623, 3, 'Small'),
#  (10623, 30, 'Medium'),
#  (10624, 10, 'Small'),
#  (10624, 6, 'Small'),
#  (10624, 10, 'Small'),
#  (10625, 3, 'Small'),
#  (10625, 5, 'Small'),
#  (10625, 10, 'Small'),
#  ...]

# %% [markdown]
# ### 3. Replace country if `NULL`
#
# Suppose some records in the `Customers` table have null values in the `Country` column. Write a SQL query that retrieves all customers, and if the country of a customer is `NULL`, replace it with the text 'Not Provided'.

# %%
# %%sql
# SELECT
# ContactName,
# IFNULL(Country,'Not Provided') AS New_Country
# FROM Customers;
# Out:
#  * sqlite:///Northwind.db
# Done.
# [('Maria Anders', 'Germany'),
#  ('Ana Trujillo', 'Mexico'),
#  ('Antonio Moreno', 'Mexico'),
#  ('Thomas Hardy', 'UK'),
#  ('Christina Berglund', 'Sweden'),
#  ('Hanna Moos', 'Germany'),
#  ('Frdrique Citeaux', 'France'),
#  ('Martn Sommer', 'Spain'),
#  ('Laurence Lebihan', 'France'),
#  ('Elizabeth Lincoln', 'Canada'),
#  ('Victoria Ashworth', 'UK'),
#  ('Patricio Simpson', 'Argentina'),
#  ('Francisco Chang', 'Mexico'),
#  ('Yang Wang', 'Switzerland'),
#  ('Pedro Afonso', 'Brazil'),
#  ('Elizabeth Brown', 'UK'),
#  ('Sven Ottlieb', 'Germany'),
#  ('Janine Labrune', 'France'),
#  ('Ann Devon', 'UK'),
#  ('Roland Mendel', 'Austria'),
#  ('Aria Cruz', 'Brazil'),
#  ('Diego Roel', 'Spain'),
#  ('Martine Ranc', 'France'),
#  ('Maria Larsson', 'Sweden'),
#  ('Peter Franken', 'Germany'),
#  ('Carine Schmitt', 'France'),
#  ('Paolo Accorti', 'Italy'),
#  ('Lino Rodriguez', 'Portugal'),
#  ('Eduardo Saavedra', 'Spain'),
#  ('Jos Pedro Freyre', 'Spain'),
#  ('Andr Fonseca', 'Brazil'),
#  ('Howard Snyder', 'USA'),
#  ('Manuel Pereira', 'Venezuela'),
#  ('Mario Pontes', 'Brazil'),
#  ('Carlos Hernndez', 'Venezuela'),
#  ('Yoshi Latimer', 'USA'),
#  ('Patricia McKenna', 'Ireland'),
#  ('Helen Bennett', 'UK'),
#  ('Philip Cramer', 'Germany'),
#  ('Daniel Tonini', 'France'),
#  ('Annette Roulet', 'France'),
#  ('Yoshi Tannamuri', 'Canada'),
#  ('John Steel', 'USA'),
#  ('Renate Messner', 'Germany'),
#  ('Jaime Yorres', 'USA'),
#  ('Carlos Gonzlez', 'Venezuela'),
#  ('Felipe Izquierdo', 'Venezuela'),
#  ('Fran Wilson', 'USA'),
#  ('Giovanni Rovelli', 'Italy'),
#  ('Catherine Dewey', 'Belgium'),
#  ('Jean Fresnire', 'Canada'),
#  ('Alexander Feuer', 'Germany'),
#  ('Simon Crowther', 'UK'),
#  ('Yvonne Moncada', 'Argentina'),
#  ('Rene Phillips', 'USA'),
#  ('Henriette Pfalzheim', 'Germany'),
#  ('Marie Bertrand', 'France'),
#  ('Guillermo Fernndez', 'Mexico'),
#  ('Georg Pipps', 'Austria'),
#  ('Isabel de Castro', 'Portugal'),
#  ('Bernardo Batista', 'Brazil'),
#  ('Lcia Carvalho', 'Brazil'),
#  ('Horst Kloss', 'Germany'),
#  ('Sergio Gutirrez', 'Argentina'),
#  ('Paula Wilson', 'USA'),
#  ('Maurizio Moroni', 'Italy'),
#  ('Janete Limeira', 'Brazil'),
#  ('Michael Holz', 'Switzerland'),
#  ('Alejandra Camino', 'Spain'),
#  ('Jonas Bergulfsen', 'Norway'),
#  ('Jose Pavarotti', 'USA'),
#  ('Hari Kumar', 'UK'),
#  ('Jytte Petersen', 'Denmark'),
#  ('Dominique Perrier', 'France'),
#  ('Art Braunschweiger', 'USA'),
#  ('Pascale Cartrain', 'Belgium'),
#  ('Liz Nixon', 'USA'),
#  ('Liu Wong', 'USA'),
#  ('Karin Josephs', 'Germany'),
#  ('Miguel Angel Paolino', 'Mexico'),
#  ('Anabela Domingues', 'Brazil'),
#  ('Helvetius Nagy', 'USA'),
#  ('Palle Ibsen', 'Denmark'),
#  ('Val2', 'Not Provided'),
#  ('Valon Hoti', 'Not Provided'),
#  ('Mary Saveley', 'France'),
#  ('Paul Henriot', 'France'),
#  ('Rita Mller', 'Germany'),
#  ('Pirkko Koskitalo', 'Finland'),
#  ('Paula Parente', 'Brazil'),
#  ('Karl Jablonski', 'USA'),
#  ('Matti Karttunen', 'Finland'),
#  ('Zbyszek Piestrzeniewicz', 'Poland')]

# %% [markdown]
# ### 4. Calculate the average price of products
#
# Using the `Products` table, write a SQL query that calculates the average unit price of all products. Then, for each product, show its name, unit price, and a column `Price Comparison` that shows whether its price is 'Below Average', 'Average', or 'Above Average'.

# %%
# %%sql
# SELECT
# PRODUCTId,
# ProductName,
# IF(UnitPrice < 28.866363636363637
# , 'Below Average',
#    IF(UnitPrice = 28.866363636363637
# , 'Average',
#       'Above Average'
#
#      )
#   )
# AS Price_camparison
# FROM products
# Out:
#  * sqlite:///Northwind.db
# Done.
# [(1, 'Chai', 'Below Average'),
#  (2, 'Chang', 'Below Average'),
#  (3, 'Aniseed Syrup', 'Below Average'),
#  (4, "Chef Anton's Cajun Seasoning", 'Below Average'),
#  (5, "Chef Anton's Gumbo Mix", 'Below Average'),
#  (6, "Grandma's Boysenberry Spread", 'Below Average'),
#  (7, "Uncle Bob's Organic Dried Pears", 'Above Average'),
#  (8, 'Northwoods Cranberry Sauce', 'Above Average'),
#  (9, 'Mishi Kobe Niku', 'Above Average'),
#  (10, 'Ikura', 'Above Average'),
#  (11, 'Queso Cabrales', 'Below Average'),
#  (12, 'Queso Manchego La Pastora', 'Above Average'),
#  (13, 'Konbu', 'Below Average'),
#  (14, 'Tofu', 'Below Average'),
#  (15, 'Genen Shouyu', 'Below Average'),
#  (16, 'Pavlova', 'Below Average'),
#  (17, 'Alice Mutton', 'Above Average'),
#  (18, 'Carnarvon Tigers', 'Above Average'),
#  (19, 'Teatime Chocolate Biscuits', 'Below Average'),
#  (20, "Sir Rodney's Marmalade", 'Above Average'),
#  (21, "Sir Rodney's Scones", 'Below Average'),
#  (22, "Gustaf's Knckebrd", 'Below Average'),
#  (23, 'Tunnbrd', 'Below Average'),
#  (24, 'Guaran Fantstica', 'Below Average'),
#  (25, 'NuNuCa Nu-Nougat-Creme', 'Below Average'),
#  (26, 'Gumbr Gummibrchen', 'Above Average'),
#  (27, 'Schoggi Schokolade', 'Above Average'),
#  (28, 'Rssle Sauerkraut', 'Above Average'),
#  (29, 'Thringer Rostbratwurst', 'Above Average'),
#  (30, 'Nord-Ost Matjeshering', 'Below Average'),
#  (31, 'Gorgonzola Telino', 'Below Average'),
#  (32, 'Mascarpone Fabioli', 'Above Average'),
#  (33, 'Geitost', 'Below Average'),
#  (34, 'Sasquatch Ale', 'Below Average'),
#  (35, 'Steeleye Stout', 'Below Average'),
#  (36, 'Inlagd Sill', 'Below Average'),
#  (37, 'Gravad lax', 'Below Average'),
#  (38, 'Cte de Blaye', 'Above Average'),
#  (39, 'Chartreuse verte', 'Below Average'),
#  (40, 'Boston Crab Meat', 'Below Average'),
#  (41, "Jack's New England Clam Chowder", 'Below Average'),
#  (42, 'Singaporean Hokkien Fried Mee', 'Below Average'),
#  (43, 'Ipoh Coffee', 'Above Average'),
#  (44, 'Gula Malacca', 'Below Average'),
#  (45, 'Rogede sild', 'Below Average'),
#  (46, 'Spegesild', 'Below Average'),
#  (47, 'Zaanse koeken', 'Below Average'),
#  (48, 'Chocolade', 'Below Average'),
#  (49, 'Maxilaku', 'Below Average'),
#  (50, 'Valkoinen suklaa', 'Below Average'),
#  (51, 'Manjimup Dried Apples', 'Above Average'),
#  (52, 'Filo Mix', 'Below Average'),
#  (53, 'Perth Pasties', 'Above Average'),
#  (54, 'Tourtire', 'Below Average'),
#  (55, 'Pt chinois', 'Below Average'),
#  (56, 'Gnocchi di nonna Alice', 'Above Average'),
#  (57, 'Ravioli Angelo', 'Below Average'),
#  (58, 'Escargots de Bourgogne', 'Below Average'),
#  (59, 'Raclette Courdavault', 'Above Average'),
#  (60, 'Camembert Pierrot', 'Above Average'),
#  (61, "Sirop d'rable", 'Below Average'),
#  (62, 'Tarte au sucre', 'Above Average'),
#  (63, 'Vegie-spread', 'Above Average'),
#  (64, 'Wimmers gute Semmelkndel', 'Above Average'),
#  (65, 'Louisiana Fiery Hot Pepper Sauce', 'Below Average'),
#  (66, 'Louisiana Hot Spiced Okra', 'Below Average'),
#  (67, 'Laughing Lumberjack Lager', 'Below Average'),
#  (68, 'Scottish Longbreads', 'Below Average'),
#  (69, 'Gudbrandsdalsost', 'Above Average'),
#  (70, 'Outback Lager', 'Below Average'),
#  (71, 'Flotemysost', 'Below Average'),
#  (72, 'Mozzarella di Giovanni', 'Above Average'),
#  (73, 'Rd Kaviar', 'Below Average'),
#  (74, 'Longlife Tofu', 'Below Average'),
#  (75, 'Rhnbru Klosterbier', 'Below Average'),
#  (76, 'Lakkalikri', 'Below Average'),
#  (77, 'Original Frankfurter grne Soe', 'Below Average')]

# %% [markdown]
# ### 5. Identify top management employees
#
# In the `Employees` table, assume the `ReportsTo` column has some null values which represent the highest-level employees (such as a CEO). Write a SQL query to list all employees and display a new column `Position` that labels the employee as 'Top Management' if the `ReportsTo` column is `NULL`, and 'Staff' otherwise.

# %%
# %%sql
# SELECT
# FirstName,
# LastName,
# IF(ReportsTo IS NULL,'Top Management','Staff') AS Position
# FROM Employees
# Out:
#  * sqlite:///Northwind.db
# Done.
# [('Nancy', 'Davolio', 'Staff'),
#  ('Andrew', 'Fuller', 'Top Management'),
#  ('Janet', 'Leverling', 'Staff'),
#  ('Margaret', 'Peacock', 'Staff'),
#  ('Steven', 'Buchanan', 'Staff'),
#  ('Michael', 'Suyama', 'Staff'),
#  ('Robert', 'King', 'Staff'),
#  ('Laura', 'Callahan', 'Staff'),
#  ('Anne', 'Dodsworth', 'Staff')]

# %% [markdown]
# ### Challenge question
#
# You are working with a products inventory database which has a Products table with the following columns:
#
# - `ProductID`
# - `ProductName`
# - `UnitPrice`
# - `UnitsInStock`
# - `ReorderLevel`
# - `SupplierCountry`
#
# Your manager wants to assess the company's stock levels and has asked for your assistance.

# %% [markdown]
# Write a SQL query that retrieves the following information:
#
# - `ProductName`
# - `UnitPrice`
# - `UnitsInStock`
# - A column `StockStatus` that categorises the stock level of each product as 'Low', 'Medium', or 'High' based on the `UnitsInStock` (Use a `CASE` statement to create this column where 'Low' is less than 20 units, 'Medium' is between 20 and 50 units, 'High' is over 50 units).
# - A column `PriceLevel` that categorises the price of each product as 'Cheap', 'Affordable', or 'Expensive' based on the `UnitPrice` (Use a `CASE` statement to create this column where 'Cheap' is less than \$10, 'Affordable' is between \$10 and \$50, 'Expensive' is over \$50).
#
# Your SQL query should consider the use of aggregation functions, date functions, control flow functions, and string functions.

# %%
# %%sql
# SELECT
# ProductName,
# UnitPrice,
# UnitsInStock,
# ReorderLevel,
# CASE WHEN UnitsInStock < 20
#      THEN 'Low'
#     WHEN UnitsInStock BETWEEN 20 AND 50
#     THEN 'Medium'
#     ELSE 'High'
# END AS StockStatus,
# CASE WHEN UnitPrice  > 10
#     THEN 'Cheap'
#     WHEN UnitPrice BETWEEN 10 AND 50
#     THEN 'Affordable'
#     ELSE 'Expensive'
# END AS PriceLevel
#
# FROM PRODUCTS;
# Out:
#  * sqlite:///Northwind.db
# Done.
# [('Chai', 18, 39, 10, 'Medium', 'Cheap'),
#  ('Chang', 19, 17, 25, 'Low', 'Cheap'),
#  ('Aniseed Syrup', 10, 13, 25, 'Low', 'Affordable'),
#  ("Chef Anton's Cajun Seasoning", 22, 53, 0, 'High', 'Cheap'),
#  ("Chef Anton's Gumbo Mix", 21.35, 0, 0, 'Low', 'Cheap'),
#  ("Grandma's Boysenberry Spread", 25, 120, 25, 'High', 'Cheap'),
#  ("Uncle Bob's Organic Dried Pears", 30, 15, 10, 'Low', 'Cheap'),
#  ('Northwoods Cranberry Sauce', 40, 6, 0, 'Low', 'Cheap'),
#  ('Mishi Kobe Niku', 97, 29, 0, 'Medium', 'Cheap'),
#  ('Ikura', 31, 31, 0, 'Medium', 'Cheap'),
#  ('Queso Cabrales', 21, 22, 30, 'Medium', 'Cheap'),
#  ('Queso Manchego La Pastora', 38, 86, 0, 'High', 'Cheap'),
#  ('Konbu', 6, 24, 5, 'Medium', 'Expensive'),
#  ('Tofu', 23.25, 35, 0, 'Medium', 'Cheap'),
#  ('Genen Shouyu', 15.5, 39, 5, 'Medium', 'Cheap'),
#  ('Pavlova', 17.45, 29, 10, 'Medium', 'Cheap'),
#  ('Alice Mutton', 39, 0, 0, 'Low', 'Cheap'),
#  ('Carnarvon Tigers', 62.5, 42, 0, 'Medium', 'Cheap'),
#  ('Teatime Chocolate Biscuits', 9.2, 25, 5, 'Medium', 'Expensive'),
#  ("Sir Rodney's Marmalade", 81, 40, 0, 'Medium', 'Cheap'),
#  ("Sir Rodney's Scones", 10, 3, 5, 'Low', 'Affordable'),
#  ("Gustaf's Knckebrd", 21, 104, 25, 'High', 'Cheap'),
#  ('Tunnbrd', 9, 61, 25, 'High', 'Expensive'),
#  ('Guaran Fantstica', 4.5, 20, 0, 'Medium', 'Expensive'),
#  ('NuNuCa Nu-Nougat-Creme', 14, 76, 30, 'High', 'Cheap'),
#  ('Gumbr Gummibrchen', 31.23, 15, 0, 'Low', 'Cheap'),
#  ('Schoggi Schokolade', 43.9, 49, 30, 'Medium', 'Cheap'),
#  ('Rssle Sauerkraut', 45.6, 26, 0, 'Medium', 'Cheap'),
#  ('Thringer Rostbratwurst', 123.79, 0, 0, 'Low', 'Cheap'),
#  ('Nord-Ost Matjeshering', 25.89, 10, 15, 'Low', 'Cheap'),
#  ('Gorgonzola Telino', 12.5, 0, 20, 'Low', 'Cheap'),
#  ('Mascarpone Fabioli', 32, 9, 25, 'Low', 'Cheap'),
#  ('Geitost', 2.5, 112, 20, 'High', 'Expensive'),
#  ('Sasquatch Ale', 14, 111, 15, 'High', 'Cheap'),
#  ('Steeleye Stout', 18, 20, 15, 'Medium', 'Cheap'),
#  ('Inlagd Sill', 19, 112, 20, 'High', 'Cheap'),
#  ('Gravad lax', 26, 11, 25, 'Low', 'Cheap'),
#  ('Cte de Blaye', 263.5, 17, 15, 'Low', 'Cheap'),
#  ('Chartreuse verte', 18, 69, 5, 'High', 'Cheap'),
#  ('Boston Crab Meat', 18.4, 123, 30, 'High', 'Cheap'),
#  ("Jack's New England Clam Chowder", 9.65, 85, 10, 'High', 'Expensive'),
#  ('Singaporean Hokkien Fried Mee', 14, 26, 0, 'Medium', 'Cheap'),
#  ('Ipoh Coffee', 46, 17, 25, 'Low', 'Cheap'),
#  ('Gula Malacca', 19.45, 27, 15, 'Medium', 'Cheap'),
#  ('Rogede sild', 9.5, 5, 15, 'Low', 'Expensive'),
#  ('Spegesild', 12, 95, 0, 'High', 'Cheap'),
#  ('Zaanse koeken', 9.5, 36, 0, 'Medium', 'Expensive'),
#  ('Chocolade', 12.75, 15, 25, 'Low', 'Cheap'),
#  ('Maxilaku', 20, 10, 15, 'Low', 'Cheap'),
#  ('Valkoinen suklaa', 16.25, 65, 30, 'High', 'Cheap'),
#  ('Manjimup Dried Apples', 53, 20, 10, 'Medium', 'Cheap'),
#  ('Filo Mix', 7, 38, 25, 'Medium', 'Expensive'),
#  ('Perth Pasties', 32.8, 0, 0, 'Low', 'Cheap'),
#  ('Tourtire', 7.45, 21, 10, 'Medium', 'Expensive'),
#  ('Pt chinois', 24, 115, 20, 'High', 'Cheap'),
#  ('Gnocchi di nonna Alice', 38, 21, 30, 'Medium', 'Cheap'),
#  ('Ravioli Angelo', 19.5, 36, 20, 'Medium', 'Cheap'),
#  ('Escargots de Bourgogne', 13.25, 62, 20, 'High', 'Cheap'),
#  ('Raclette Courdavault', 55, 79, 0, 'High', 'Cheap'),
#  ('Camembert Pierrot', 34, 19, 0, 'Low', 'Cheap'),
#  ("Sirop d'rable", 28.5, 113, 25, 'High', 'Cheap'),
#  ('Tarte au sucre', 49.3, 17, 0, 'Low', 'Cheap'),
#  ('Vegie-spread', 43.9, 24, 5, 'Medium', 'Cheap'),
#  ('Wimmers gute Semmelkndel', 33.25, 22, 30, 'Medium', 'Cheap'),
#  ('Louisiana Fiery Hot Pepper Sauce', 21.05, 76, 0, 'High', 'Cheap'),
#  ('Louisiana Hot Spiced Okra', 17, 4, 20, 'Low', 'Cheap'),
#  ('Laughing Lumberjack Lager', 14, 52, 10, 'High', 'Cheap'),
#  ('Scottish Longbreads', 12.5, 6, 15, 'Low', 'Cheap'),
#  ('Gudbrandsdalsost', 36, 26, 15, 'Medium', 'Cheap'),
#  ('Outback Lager', 15, 15, 30, 'Low', 'Cheap'),
#  ('Flotemysost', 21.5, 26, 0, 'Medium', 'Cheap'),
#  ('Mozzarella di Giovanni', 34.8, 14, 0, 'Low', 'Cheap'),
#  ('Rd Kaviar', 15, 101, 5, 'High', 'Cheap'),
#  ('Longlife Tofu', 10, 4, 5, 'Low', 'Affordable'),
#  ('Rhnbru Klosterbier', 7.75, 125, 25, 'High', 'Expensive'),
#  ('Lakkalikri', 18, 57, 20, 'High', 'Cheap'),
#  ('Original Frankfurter grne Soe', 13, 32, 15, 'Medium', 'Cheap')]

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### 1. Categorise employees based on salaries
#
# This query uses the `IIF` control function to check if each employee's salary is greater than 50,000. If it is, the function returns 'Yes', otherwise 'No'. This result is displayed in the new column `HighSalary`.
#
# Expected outcome: A table with columns `FirstName`, `LastName`, and `HighSalary`. The `HighSalary` column displays 'Yes' or 'No' depending on each employee's salary.
#
# **NOTE:** The `IF` function is not supported in SQLite, so we use the `IIF` function which is the SQLite equivalent for `IF`.

# %%
# %%sql
#
# SELECT
#        FirstName,
#        LastName,
#        IIF(Salary > 50000, 'Yes', 'No') AS HighSalary
# FROM
#        Employees;
# Out:
#  * sqlite:///Northwind.db
# Done.
# [('Nancy', 'Davolio', 'No'),
#  ('Andrew', 'Fuller', 'No'),
#  ('Janet', 'Leverling', 'No'),
#  ('Margaret', 'Peacock', 'No'),
#  ('Steven', 'Buchanan', 'No'),
#  ('Michael', 'Suyama', 'No'),
#  ('Robert', 'King', 'No'),
#  ('Laura', 'Callahan', 'No'),
#  ('Anne', 'Dodsworth', 'No')]

# %% [markdown]
# ### 2. Categorise orders based on quantity
#
# This query uses the `CASE` statement to categorise the size of each order. If the quantity of an order is less than 20, it's categorised as 'Small'. If it's between 20 and 100, it's 'Medium'. Otherwise, it's 'Large'.
#
# Expected outcome: A table with columns `OrderID` and `OrderSize`. The `OrderSize` column displays 'Small', 'Medium', or 'Large' depending on each order's quantity.

# %%
# %%sql
#
# SELECT
#     OrderID,
#     CASE
#         WHEN (Quantity < 20) THEN 'Small'
#         WHEN Quantity BETWEEN 20 AND 100 THEN 'Medium'
#         ELSE 'Large'
#     END as OrderSize
# FROM
#     OrderDetails;

# %% [markdown]
# ### 3. Replace country if `NULL`
#
# This query uses the `IFNULL` function to replace null values in the `Country` column with 'Not Provided'.
#
# Expected outcome: A table with columns `CustomerID`, `CompanyName`, and `Country`. The `Country` column displays the name of the country or 'Not Provided' if the original value was `NULL`.

# %%
# %%sql
#
# SELECT
#     CustomerID,
#     CompanyName,
#     IFNULL(Country, 'Not Provided') AS Country
# FROM
#     Customers;

# %% [markdown]
# ### 4. Calculate the average price of products
#
# This query calculates the average unit price of all products. Then, it compares the unit price of each product with this average and labels it as 'Below Average', 'Average', or 'Above Average' accordingly.
#
# Expected outcome: A table with columns `ProductName`, `UnitPrice`, and `PriceComparison`. The `PriceComparison` column displays 'Below Average', 'Average', or 'Above Average' depending on each product's unit price.

# %%
# %%sql
#
# SELECT
#     ProductName,
#     UnitPrice,
#     CASE
#         WHEN UnitPrice < (SELECT AVG(UnitPrice) FROM Products) THEN 'Below Average'
#         WHEN UnitPrice = (SELECT AVG(UnitPrice) FROM Products) THEN 'Average'
#         ELSE 'Above Average'
#     END as PriceComparison
# FROM
#     Products;

# %% [markdown]
# ### 5. Identify top management employees
#
# This query uses the `IIF` function to check if the `ReportsTo` field of an employee is `NULL`. If it is, the employee is labelled as 'Top Management', otherwise 'Staff'.
#
# Expected outcome: A table with columns `FirstName`, `LastName`, and `Position`. The `Position` column displays 'Top Management' or 'Staff' depending on the `ReportsTo` field of each employee.

# %%
# %%sql
#
# SELECT
#     FirstName,
#     LastName,
#     IIF(ReportsTo IS NULL, 'Top Management', 'Staff') as Position
# FROM
#     Employees;
# Out:
#  * sqlite:///Northwind.db
# Done.
# [('Nancy', 'Davolio', 'Staff'),
#  ('Andrew', 'Fuller', 'Top Management'),
#  ('Janet', 'Leverling', 'Staff'),
#  ('Margaret', 'Peacock', 'Staff'),
#  ('Steven', 'Buchanan', 'Staff'),
#  ('Michael', 'Suyama', 'Staff'),
#  ('Robert', 'King', 'Staff'),
#  ('Laura', 'Callahan', 'Staff'),
#  ('Anne', 'Dodsworth', 'Staff')]

# %% [markdown]
# ### Challenge question
#
# This problem requires the integration of SQL querying with some basic logic and control flow.
#
# Here is a step-by-step breakdown of how to approach solving this problem:

# %% [markdown]
# 1. **Identify required fields:** The first part of the problem is straightforward. We're being asked to retrieve `ProductName`, `UnitsInStock`, and `UnitPrice` from our `Products` table. These fields can be directly selected in our SQL query.
#
# 2. **Categorise stock levels:** We need to create a new field, `StockStatus`, that categorises the stock level based on the `UnitsInStock`. This requires the use of a control flow function – specifically, a `CASE` statement. The `CASE` statement allows us to conditionally return results based on the value of another field. In this case, we will categorise `UnitsInStock` as 'Low' if less than 20, 'Medium' if between 20 and 50, and 'High' if more than 50.
#
# 3. **Categorise price levels:** Similarly, we need to create another field, `PriceLevel`, that categorises the price of a product based on the `UnitPrice`. We'll again use a `CASE` statement to accomplish this. We will categorise `UnitPrice` as *Cheap* if less than \$10, *Affordable* if between \$10 and \$50, and *Expensive* if more than \$50.

# %% [markdown]
# So, to solve the problem, we would write a SQL query that selects the required fields and uses `CASE` statements to create the new `StockStatus` and `PriceLevel` fields based on the conditions described above.
#
# In SQL, this would look something like:

# %%
# %%sql
#
# SELECT
#     ProductName,
#     UnitsInStock,
#     UnitPrice,
#     CASE
#         WHEN UnitsInStock < 20 THEN 'Low'
#         WHEN UnitsInStock BETWEEN 20 AND 50 THEN 'Medium'
#         ELSE 'High'
#     END AS StockStatus,
#     CASE
#         WHEN UnitPrice < 10 THEN 'Cheap'
#         WHEN UnitPrice BETWEEN 10 AND 50 THEN 'Affordable'
#         ELSE 'Expensive'
#     END AS PriceLevel
# FROM
#     Products;

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/refs/heads/master/ALX_banners/ALX_Navy.png"  style="width:100px"  ;/>
# </div>
