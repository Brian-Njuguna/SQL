# %%
# %load_ext sql

# %%
# %sql mysql+pymysql://root:HardThings25@localhost:3306/md_water_services

# %%
# %%sql
# SHOW
# Tables
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 10 rows affected.
# [('data_dictionary',),
#  ('employee',),
#  ('global_water_access',),
#  ('location',),
#  ('quality_score',),
#  ('sample_rec',),
#  ('visits',),
#  ('water_quality',),
#  ('water_source',),
#  ('well_pollution',)]

# %%
# %%sql
# SELECT
#     Employee_name,
#     CONCAT(
#    LOWER(REPLACE(employee_name,' ', '.')), '@ndogowater.gov') AS new_email
# FROM
# Employee
# limit 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [('Amara Jengo', 'amara.jengo@ndogowater.gov'),
#  ('Bello Azibo', 'bello.azibo@ndogowater.gov'),
#  ('Bakari Iniko', 'bakari.iniko@ndogowater.gov'),
#  ('Malachi Mavuso', 'malachi.mavuso@ndogowater.gov'),
#  ('Cheche Buhle', 'cheche.buhle@ndogowater.gov')]

# %%
# %%sql
# UPDATE employee
# SET email = CONCAT(
#
#    LOWER(REPLACE(employee_name,' ', '.')), '@ndogowater.gov')
# limit 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# []

# %%
# %%sql
# SELECT
# *
# FROM
# Employee
# limit 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [(0, 'Amara Jengo', '+99637993287', 'amara.jengo@ndogowater.gov', '36 Pwani Mchangani Road', 'Sokoto', 'Ilanga', 'Field Surveyor'),
#  (1, 'Bello Azibo', '+99643864786', 'bello.azibo@ndogowater.gov', '129 Ziwa La Kioo Road', 'Kilimani', 'Rural', 'Field Surveyor'),
#  (2, 'Bakari Iniko', '+99222599041', 'bakari.iniko@ndogowater.gov', '18 Mlima Tazama Avenue', 'Hawassa', 'Rural', 'Field Surveyor'),
#  (3, 'Malachi Mavuso', '+99945849900', 'malachi.mavuso@ndogowater.gov', '100 Mogadishu Road', 'Akatsi', 'Lusaka', 'Field Surveyor'),
#  (4, 'Cheche Buhle', '+99381679640', 'cheche.buhle@ndogowater.gov', '1 Savanna Street', 'Akatsi', 'Rural', 'Field Surveyor')]

# %%
# %%sql
# SHOW COLUMNS FROM Employee
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 8 rows affected.
# [('assigned_employee_id', 'int', 'NO', 'PRI', None, ''),
#  ('employee_name', 'varchar(255)', 'YES', '', None, ''),
#  ('phone_number', 'varchar(15)', 'YES', '', None, ''),
#  ('email', 'varchar(255)', 'YES', '', None, ''),
#  ('address', 'varchar(255)', 'YES', '', None, ''),
#  ('province_name', 'varchar(255)', 'YES', '', None, ''),
#  ('town_name', 'varchar(255)', 'YES', '', None, ''),
#  ('position', 'varchar(255)', 'YES', '', None, '')]

# %%
# %%sql
# SELECT
#     Phone_Number,
#     (LENGTH(Phone_number)) AS length
# FROM employee
# Limit 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [('+99637993287', 12),
#  ('+99643864786', 12),
#  ('+99222599041', 12),
#  ('+99945849900', 12),
#  ('+99381679640', 12)]

# %%
# %%sql
# UPDATE Employee
# SET
# Phone_number = TRIM(Phone_number)
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 56 rows affected.
# []

# %%
# %%sql
# SELECT
#     Town_name,
#     province_name,
#     COUNT(Employee_name) AS No_of_employees
# FROM
# Employee
# GROUP BY Town_name,province_name
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 15 rows affected.
# [('Ilanga', 'Sokoto', 2),
#  ('Rural', 'Kilimani', 9),
#  ('Rural', 'Hawassa', 7),
#  ('Lusaka', 'Akatsi', 4),
#  ('Rural', 'Akatsi', 5),
#  ('Zanzibar', 'Hawassa', 4),
#  ('Dahabu', 'Amanzi', 6),
#  ('Rural', 'Sokoto', 7),
#  ('Kintampo', 'Akatsi', 1),
#  ('Harare', 'Akatsi', 3),
#  ('Ilanga', 'Kilimani', 1),
#  ('Yaounde', 'Hawassa', 1),
#  ('Serowe', 'Hawassa', 3),
#  ('Harare', 'Kilimani', 2),
#  ('Rural', 'Amanzi', 1)]

# %%
# %%sql
# SELECT
#  assigned_employee_id,
#  COUNT(visit_count)  AS no_of_visits
# FROM visits
# GROUP BY assigned_employee_id
# ORDER BY no_of_visits DESC;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 29 rows affected.
# [(1, 3708),
#  (30, 3676),
#  (34, 3539),
#  (3, 3420),
#  (10, 3407),
#  (8, 3351),
#  (5, 3284),
#  (36, 3249),
#  (48, 2933),
#  (28, 2762),
#  (12, 2561),
#  (42, 2496),
#  (40, 2344),
#  (38, 2121),
#  (2, 2033),
#  (24, 2015),
#  (32, 1852),
#  (18, 1749),
#  (46, 1632),
#  (14, 1441),
#  (7, 1259),
#  (6, 1182),
#  (4, 1136),
#  (0, 1099),
#  (16, 802),
#  (26, 719),
#  (44, 218),
#  (22, 143),
#  (20, 15)]

# %%
# %%sql
# SELECT
# assigned_employee_id,
# employee_name,
# email,
# Phone_number
# FROM
# employee
# WHERE assigned_employee_id IN(22,20)
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 2 rows affected.
# [(20, 'Kunto Asha', 'kunto.asha@ndogowater.gov', '+99176320477'),
#  (22, 'Lesedi Kofi', 'lesedi.kofi@ndogowater.gov', '+99611183730')]

# %%
# %%sql
# SELECT
#
# COUNT(Location_id) AS Records_per_town ,
# Town_name
# FROM
# Location
#
#
# GROUP BY Town_name
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 25 rows affected.
# [(1650, 'Harare'),
#  (780, 'Kintampo'),
#  (1070, 'Lusaka'),
#  (23740, 'Rural'),
#  (400, 'Abidjan'),
#  (1090, 'Amina'),
#  (930, 'Asmara'),
#  (400, 'Bello'),
#  (930, 'Dahabu'),
#  (520, 'Pwani'),
#  (350, 'Deka'),
#  (310, 'Djenne'),
#  (480, 'Serowe'),
#  (270, 'Yaounde'),
#  (300, 'Zanzibar'),
#  (710, 'Amara'),
#  (770, 'Isiqalo'),
#  (990, 'Mrembo'),
#  (750, 'Zuri'),
#  (470, 'Bahari'),
#  (370, 'Cheche'),
#  (780, 'Ilanga'),
#  (510, 'Kofi'),
#  (620, 'Majengo'),
#  (460, 'Marang')]

# %%
# %%sql
# SELECT
#
# COUNT(Location_id) AS Records_per_province ,
# province_name
# FROM
# Location
#
#
# GROUP BY Province_name
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [(8940, 'Akatsi'),
#  (6950, 'Amanzi'),
#  (6030, 'Hawassa'),
#  (9510, 'Kilimani'),
#  (8220, 'Sokoto')]

# %%
# %%sql
# SELECT
# province_name,
# Town_name,
# COUNT(Location_id) AS Records_per_province
# FROM
# Location
# GROUP BY town_name,Province_name;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 31 rows affected.
# [('Akatsi', 'Harare', 800),
#  ('Akatsi', 'Kintampo', 780),
#  ('Akatsi', 'Lusaka', 1070),
#  ('Akatsi', 'Rural', 6290),
#  ('Amanzi', 'Abidjan', 400),
#  ('Amanzi', 'Amina', 670),
#  ('Amanzi', 'Asmara', 930),
#  ('Amanzi', 'Bello', 400),
#  ('Amanzi', 'Dahabu', 930),
#  ('Amanzi', 'Pwani', 520),
#  ('Amanzi', 'Rural', 3100),
#  ('Hawassa', 'Amina', 420),
#  ('Hawassa', 'Deka', 350),
#  ('Hawassa', 'Djenne', 310),
#  ('Hawassa', 'Rural', 3900),
#  ('Hawassa', 'Serowe', 480),
#  ('Hawassa', 'Yaounde', 270),
#  ('Hawassa', 'Zanzibar', 300),
#  ('Kilimani', 'Amara', 710),
#  ('Kilimani', 'Harare', 850),
#  ('Kilimani', 'Isiqalo', 770),
#  ('Kilimani', 'Mrembo', 990),
#  ('Kilimani', 'Rural', 5440),
#  ('Kilimani', 'Zuri', 750),
#  ('Sokoto', 'Bahari', 470),
#  ('Sokoto', 'Cheche', 370),
#  ('Sokoto', 'Ilanga', 780),
#  ('Sokoto', 'Kofi', 510),
#  ('Sokoto', 'Majengo', 620),
#  ('Sokoto', 'Marang', 460),
# ...

# %%
# %%sql
# SELECT
# COUNT(Location_id) AS num_sources,
# Location_type
# FROM
# Location
# GROUP BY location_type
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 2 rows affected.
# [(15910, 'Urban'), (23740, 'Rural')]

# %%
# %%sql
# SELECT ROUND(23740/(15910 + 23740) * 100) AS pct_rural
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 1 rows affected.
# [(Decimal('60'),)]

# %%
# %%sql
# SHOW COLUMNS FROM water_source
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 3 rows affected.
# [('source_id', 'varchar(510)', 'NO', 'PRI', None, ''),
#  ('type_of_water_source', 'varchar(255)', 'YES', '', None, ''),
#  ('number_of_people_served', 'int', 'YES', '', None, '')]

# %%
# %%sql
# SELECT
# *
# FROM
# water_source
# limit 10;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 10 rows affected.
# [('AkHa00000224', 'tap_in_home', 956),
#  ('AkHa00001224', 'tap_in_home_broken', 930),
#  ('AkHa00002224', 'tap_in_home_broken', 486),
#  ('AkHa00003224', 'well', 364),
#  ('AkHa00004224', 'tap_in_home_broken', 942),
#  ('AkHa00005224', 'tap_in_home', 736),
#  ('AkHa00006224', 'tap_in_home', 882),
#  ('AkHa00007224', 'tap_in_home', 554),
#  ('AkHa00008224', 'well', 398),
#  ('AkHa00009224', 'well', 346)]

# %%
# %%sql
# SELECT
# SUM(number_of_people_served)
# FROM water_source
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 1 rows affected.
# [(Decimal('27628140'),)]

# %%
# %%sql
# SELECT
# type_of_water_source,
# COUNT(source_id) AS total_no
#
# FROM water_source
# GROUP BY type_of_water_source
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [('tap_in_home', 7265),
#  ('tap_in_home_broken', 5856),
#  ('well', 17383),
#  ('shared_tap', 5767),
#  ('river', 3379)]

# %%
# %%sql
# SELECT
# Type_of_water_source,
# ROUND(AVG(number_of_people_served)) AS AVG_people_per_source
# FROM water_source
# GROUP By Type_of_water_source
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [('tap_in_home', Decimal('644')),
#  ('tap_in_home_broken', Decimal('649')),
#  ('well', Decimal('279')),
#  ('shared_tap', Decimal('2071')),
#  ('river', Decimal('699'))]

# %%
# %%sql
# SELECT
# Type_of_water_source,
# SUM(number_of_people_served) AS Sum_people_per_source
# FROM water_source
# GROUP By Type_of_water_source
# ORDER BY Sum_people_per_source DESC;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [('shared_tap', Decimal('11945272')),
#  ('well', Decimal('4841724')),
#  ('tap_in_home', Decimal('4678880')),
#  ('tap_in_home_broken', Decimal('3799720')),
#  ('river', Decimal('2362544'))]

# %%
# %%sql
# SELECT
#     Type_of_water_source,
#   ROUND( SUM(number_of_people_served) * 100.0
#         / SUM(SUM(number_of_people_served)) OVER (),0) AS percentage_served
# FROM water_source
# GROUP BY Type_of_water_source
# ORDER BY percentage_served DESC;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [('shared_tap', Decimal('43')),
#  ('well', Decimal('18')),
#  ('tap_in_home', Decimal('17')),
#  ('tap_in_home_broken', Decimal('14')),
#  ('river', Decimal('9'))]

# %%
# %%sql
# SELECT
# Type_of_water_source,
# SUM(number_of_people_served) AS Sum_people_per_source,
# RANK() OVER (
#     ORDER BY SUM(number_of_people_served) DESC
# ) AS rank_of_source
# FROM water_source
# GROUP By Type_of_water_source
# ORDER BY Sum_people_per_source DESC;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [('shared_tap', Decimal('11945272'), 1),
#  ('well', Decimal('4841724'), 2),
#  ('tap_in_home', Decimal('4678880'), 3),
#  ('tap_in_home_broken', Decimal('3799720'), 4),
#  ('river', Decimal('2362544'), 5)]

# %%
# %%sql
# SELECT
#     source_id,
#     type_of_water_source,
#     number_of_people_served,
#     DENSE_RANK() OVER(
#         ORDER BY (number_of_people_served) DESC
#     )
# AS priority_rank
# FROM
#     Water_Source
#
# limit 100;
# Out:
# UsageError: Cell magic `%%sql` not found.

# %%
# %%sql
# SELECT
#     MAX(time_of_record) AS Last_day_of_record,
#     MIN(time_of_record) AS first_day_of_record,
#     TIMESTAMPDIFF(DAY,MIN(time_of_record),MAX(time_of_record)) AS total_days_of_survey
# FROM visits

# %%
# %%sql
# SELECT
#     ROUND(AVG(NULLIF(time_in_queue,0))) AS total_avg
# FROM visits
# Limit 10;

# %%
# %%sql
# SELECT
#     DAYNAME(time_of_record) AS day_of_week,
#    ROUND( AVG(time_in_queue)) AS avg_queue_time
# FROM visits
# GROUP BY DAYNAME(time_of_record);

# %%
# %%sql
# SELECT
#     TIME_FORMAT(TIME(time_of_record), '%H:00') AS hour_of_day,
#    ROUND( AVG(time_in_queue)) AS avg_queue_time
# FROM visits
# GROUP BY TIME_FORMAT(TIME(time_of_record), '%H:00')
# ORDER BY hour_of_day;

# %%
# %%sql
# SELECT
#     TIME_FORMAT(TIME(time_of_record), '%H:00') AS hour_of_day,
#     ROUND(AVG(CASE WHEN DAYNAME(time_of_record) = 'Sunday' THEN time_in_queue ELSE NULL END),0) AS avg_sunday_queue,
#     ROUND(AVG(
#     CASE
#     WHEN DAYNAME(time_of_record) = 'Monday' THEN time_in_queue
#     ELSE NULL
#     END),0) AS Monday,
#     ROUND(AVG(
#     CASE
#     WHEN DAYNAME(time_of_record) = 'Tuesday' THEN time_in_queue
#     ELSE NULL
#     END),0) AS Tuesday,
#     ROUND(AVG(
#     CASE
#     WHEN DAYNAME(time_of_record) = 'Wednesday' THEN time_in_queue
#     ELSE NULL
#     END),0) AS Wednesday,
#     ROUND(AVG(
#     CASE
#     WHEN DAYNAME(time_of_record) = 'Thursday' THEN time_in_queue
#     ELSE NULL
#     END),0) AS Thursday,
#     ROUND(AVG(
#     CASE
#     WHEN DAYNAME(time_of_record) = 'Friday' THEN time_in_queue
#     ELSE NULL
#     END),0) AS Friday,
#     ROUND(AVG(
#     CASE
#     WHEN DAYNAME(time_of_record) = 'Saturday' THEN time_in_queue
#     ELSE NULL
#     END),0) AS Saturday
# FROM visits
# WHERE time_in_queue != 0
# GROUP BY hour_of_day
# ORDER BY hour_of_day;
